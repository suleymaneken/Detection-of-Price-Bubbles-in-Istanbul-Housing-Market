# %%
import time
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

#plotting
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
sns.set_style("whitegrid")

# %%
from sklearn.model_selection import KFold, GridSearchCV, cross_val_score, train_test_split # Model evaluation
from sklearn.preprocessing import MinMaxScaler # Data normalization
from xgboost import XGBRegressor, DMatrix, plot_importance # XGBoost

# %%
# pip install tensorflow==2
import tensorflow as tf
from tensorflow.keras.layers import Input, Dropout, Dense, LSTM, TimeDistributed, RepeatVector
from tensorflow.keras.models import Model
from tensorflow.keras import regularizers
# Out:
# /home/ipcvlab/anaconda2/envs/data_science/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /home/ipcvlab/anaconda2/envs/data_science/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /home/ipcvlab/anaconda2/envs/data_science/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:528: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /home/ipcvlab/anaconda2/envs/data_science/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:529: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /home/ipcvlab/anaconda2/envs/data_science/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:530: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /home/ipcvlab/anaconda2/envs/data_science/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:535: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %%
df_train = pd.read_excel("/home/ipcvlab/Downloads/ilceler/ceyrek-full-sütun/basaksehir_ceyrek_tum_veriler.xlsx", index_col = 0) 
cols_list = list(df_train.columns)

# %%
df_train.head()
# Out:
#          HouseEndex      bist  USD/TRY  Aylık_Mevduat_Faizi   Konut_Kredisi  \
# Tarih
# 2007-06       100.0  47093.67   1.3215                 17.59          18.03
# 2007-09       103.6  54044.22   1.2674                 17.34          17.58
# 2007-12       104.9  55538.13   1.1786                 16.35          16.53
# 2008-03       105.3  39015.44   1.2383                 15.78          17.28
# 2008-06       100.5  35089.53   1.2337                 16.75          17.60
#
#          ic_borc_maliyet  tufe_endeks  guven_endeksi    BME    GDP  kira endex
# Tarih
# 2007-06            18.42       139.69          80.95  59.70  67.48       100.0
# 2007-09            18.25       140.13          83.89  59.77  66.52       101.1
# 2007-12            16.54       145.77          80.67  60.09  69.90       104.0
# 2008-03            17.59       150.27          68.74  65.89  72.71       106.0
# 2008-06            21.54       154.51          61.79  73.01  69.04        99.8

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 51 entries, 2007-06 to 2019-12
# Data columns (total 11 columns):
# HouseEndex              51 non-null float64
# bist                    51 non-null float64
# USD/TRY                 51 non-null float64
# Aylık_Mevduat_Faizi     51 non-null float64
# Konut_Kredisi           51 non-null float64
# ic_borc_maliyet         51 non-null float64
# tufe_endeks             51 non-null float64
# guven_endeksi           51 non-null float64
# BME                     51 non-null float64
# GDP                     51 non-null float64
# kira endex              51 non-null float64
# dtypes: float64(11)
# memory usage: 4.8+ KB

# %%
df_train.describe()
# Out:
#        HouseEndex           bist    USD/TRY  Aylık_Mevduat_Faizi   \
# count   51.000000      51.000000  51.000000             51.000000
# mean   156.954902   71876.040784   2.611547             10.961569
# std     61.870042   22471.523840   1.422405              4.433174
# min     80.600000   25764.830000   1.178600              5.390000
# 25%    104.600000   56038.250000   1.562550              7.720000
# 50%    122.000000   74205.470000   2.020800              9.270000
# 75%    224.350000   85810.060000   3.241200             12.815000
# max    272.400000  115333.010000   6.378300             22.170000
#
#        Konut_Kredisi  ic_borc_maliyet  tufe_endeks  guven_endeksi         BME  \
# count      51.000000        51.000000    51.000000      51.000000   51.000000
# mean       13.941569        12.201765   244.600000      70.168235  100.841961
# std         4.025200         4.638079    82.739765       7.519964   39.499889
# min         8.300000         5.770000   139.690000      55.140000   59.700000
# 25%        11.180000         9.045000   178.345000      65.345000   69.635000
# 50%        12.870000        10.340000   223.910000      71.310000   86.570000
# 75%        15.560000        14.810000   287.405000      74.940000  115.490000
# max        27.820000        25.270000   440.500000      83.890000  193.770000
#
#               GDP  kira endex
# count   51.000000   51.000000
# mean    89.811373  110.154706
# std     17.741740   28.254826
# min     63.610000   74.500000
# 25%     72.265000   85.085000
# 50%     90.900000  103.900000
# 75%    104.940000  135.900000
# max    117.530000  177.400000

# %% [markdown]
# ### display Missing values

# %%
label_nas = []
for col in df_train.columns.tolist():
    if np.sum(df_train[col].isnull() ) != 0:
        label_nas.append(col)
    else:
        label_nas.append("")

plt.figure(figsize=(12,7))
plt.suptitle('Missing Values in the Training Set')
sns.heatmap(df_train.isnull(), yticklabels=False, xticklabels=label_nas ,cbar = False, cmap='viridis')
plt.show()

# %%
replace = True # True: replace null in guven_endeksi with average. False: guven_endeksi kullanmadan
if replace:
    df_train = df_train.fillna(df_train.mean())
else:
    df_train.drop('guven_endeksi', axis=1, inplace=True)

# %%
# Correlation matrix
corr_mat = df_train.corr().abs()
# Find most important features relative to target
corr_mat.sort_values(by=["HouseEndex"], ascending = False, inplace = True)
print(corr_mat.HouseEndex)
# Out:
# HouseEndex              1.000000
# GDP                     0.960834
# kira endex              0.950934
# tufe_endeks             0.947776
# BME                     0.925599
# USD/TRY                 0.916008
# bist                    0.860828
# guven_endeksi           0.530756
# Aylık_Mevduat_Faizi     0.299239
# ic_borc_maliyet         0.256085
# Konut_Kredisi           0.170182
# Name: HouseEndex, dtype: float64

# %%
#Correlation matrix between features
corr_mat = df_train.corr().abs()

# %%
#Plot the heatmap with seaborn
plt.figure(figsize=(7,7)) 

mask = np.zeros_like(corr_mat)
mask[np.triu_indices_from(mask)] = True

sns.heatmap(corr_mat, mask=mask,
        xticklabels=corr_mat.columns,
        yticklabels=corr_mat.columns)

# %%
#List the highly correlated columns
corr_tmp = corr_mat.unstack()
corr_tmp = corr_tmp.sort_values(kind="quicksort")

print(corr_tmp[-len(corr_mat)-10:-len(corr_mat)])
# Out:
# ic_borc_maliyet       Aylık_Mevduat_Faizi     0.959686
# Aylık_Mevduat_Faizi   ic_borc_maliyet         0.959686
# GDP                   HouseEndex              0.960834
# HouseEndex            GDP                     0.960834
# tufe_endeks           USD/TRY                 0.976848
# USD/TRY               tufe_endeks             0.976848
# BME                   USD/TRY                 0.988005
# USD/TRY               BME                     0.988005
# tufe_endeks           BME                     0.988033
# BME                   tufe_endeks             0.988033
# dtype: float64

# %%
# Find most important features relative to target
corr_mat.sort_values(["HouseEndex"], ascending = False, inplace = True)
print(corr_mat.HouseEndex)
# Out:
# HouseEndex              1.000000
# GDP                     0.960834
# kira endex              0.950934
# tufe_endeks             0.947776
# BME                     0.925599
# USD/TRY                 0.916008
# bist                    0.860828
# guven_endeksi           0.530756
# Aylık_Mevduat_Faizi     0.299239
# ic_borc_maliyet         0.256085
# Konut_Kredisi           0.170182
# Name: HouseEndex, dtype: float64

# %% [markdown]
# # Skewness

# %%
#Check the skewness of HouseEndeks
for col in cols_list:
    plt.figure(figsize=(10, 5))
    skewness = df_train[col].skew()
    df_train[col].plot.hist(edgecolor='white', bins=30, 
                                    label=col + ' skew =' + str(round(skewness,2)))
    plt.suptitle("{} distribution".format(col))
    plt.legend()
    plt.show()

# %% [markdown]
# # Box plots

# %%
for col in cols_list:
    plt.figure(figsize=(10, 5))
    # Create the boxplot
    ax = sns.boxplot(x=col, data=df_train)
    # Set the `xlim`
    #ax.set(xlim=(0, 100))
    # Add title
    ax.set_title(col)
    # Show the plot
    plt.show()

# %%
for col in cols_list:    
    y_axis = col
    count = df_train[y_axis].count()
    value=df_train[y_axis]

    plt.figure(figsize=(10, 5))
    sns.regplot(np.linspace(0, count, count), df_train[y_axis], fit_reg=True,
                scatter_kws={'facecolors':np.where( value==True , "red", 'darkviolet'),
               'edgecolor':np.where(value==True , "red", 'darkviolet')},
               line_kws = {'color': 'darkblue'})
    plt.title(col, fontsize=24)
    plt.xlabel('-', fontsize=18)
    plt.ylabel(col, fontsize=18)
    # plt.savefig('figures/Standardised_SalePrice_GrLivArea.png')

# %% [markdown]
# # HouseEndex vs other

# %%
# Displays A Scatter Plot with Regression Line + Outliers in Red

for col in cols_list:
    x_axis = col
    y_axis = 'HouseEndex'
    value=(df_train[y_axis] > 107)
    value2=(df_train[y_axis][:-15] > 107)

    plt.figure(figsize=(10, 5))
    sns.regplot(df_train[x_axis], df_train[y_axis], fit_reg=True,
                scatter_kws={'facecolors':np.where( value==True , "red", 'darkviolet'),
               'edgecolor':np.where(value==True , "red", 'darkviolet')},
               line_kws = {'color': 'darkred'})
    
    sns.regplot(df_train[x_axis][:-15], df_train[y_axis][:-15], fit_reg=True,
                scatter_kws={'facecolors':np.where( value2==True , "red", 'darkviolet'),
               'edgecolor':np.where(value2==True , "red", 'darkviolet')},
               line_kws = {'color': 'darkblue'})
    
    plt.title('HouseEndex vs. {}'.format(x_axis), fontsize=24)
    plt.xlabel(x_axis, fontsize=18)
    plt.ylabel('HouseEndex', fontsize=18)
    # plt.savefig('figures/Standardised_SalePrice_GrLivArea.png')

# %% [markdown]
# # XGBoost

# %%
#y_full = df_train['HouseEndex']
#X_full = df_train.drop(columns=["HouseEndex"])

y_full = df_train['HouseEndex'][:-5]
X_full = df_train.drop(columns=["HouseEndex"])[:-5]

y_test = df_train['HouseEndex'][-5:]
X_test = df_train.drop(columns=["HouseEndex"])[-5:]

X_train, X_val, y_train, y_val = train_test_split(X_full, y_full, test_size=0.2, random_state=123)

# %%
# final model with tuned parameters
model = XGBRegressor(max_depth=6, #dflt 6
                     learning_rate=0.1, #dflt 100
                     n_estimators=1000, #dflt 0.1
                     verbosity = 3,
                     objective='reg:linear',
                     n_jobs=-1,
                     gamma=0, #dflt: 0
                     min_child_weight=3, #0 dflt: 1
                     subsample=0.5,
                     colsample_bytree=1,
                     reg_lambda=0.99994, #dflt: 1
                     reg_alpha=0.00003, #dflt: 0
                     tree_method='exact',
                     scale_pos_weight=1, # dflt: 1
                     random_state=123)

# %%
tick=time.time()

fitted_model = model.fit(X_train, y_train,
                         eval_set=[(X_val, y_val)],
                         eval_metric='rmse', # Equivalent to RMSLE since we have log1p(SalePrice)
                         early_stopping_rounds=1000,
                         verbose=True)

print("Duration: {}s".format(time.time()-tick))
# Out:
# [21:43:45] WARNING: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [21:43:45] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 2 extra nodes, 0 pruned nodes, max_depth=1
# [0]	validation_0-rmse:99.6464
# Will train until validation_0-rmse hasn't improved in 1000 rounds.
# [21:43:45] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 2 extra nodes, 0 pruned nodes, max_depth=1
# [1]	validation_0-rmse:90.9339
# [21:43:45] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 2 extra nodes, 0 pruned nodes, max_depth=1
# [2]	validation_0-rmse:83.2172
# [21:43:45] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 2 extra nodes, 0 pruned nodes, max_depth=1
# [3]	validation_0-rmse:74.2151
# [21:43:45] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 2 extra nodes, 0 pruned nodes, max_depth=1
# [4]	validation_0-rmse:66.0607
# [21:43:45] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 2 extra nodes, 0 pruned nodes, max_depth=1
# [5]	validation_0-rmse:60.2551
# [21:43:45] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [6]	validation_0-rmse:55.3917
# [21:43:45] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 2 extra nodes, 0 pruned nodes, max_depth=1
# [7]	validation_0-rmse:50.6507
# [21:43:45] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 2 extra nodes, 0 pruned nodes, max_depth=1
# [8]	validation_0-rmse:45.7623
# [21:43:45] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 2 extra nodes, 0 pruned nodes, max_depth=1
# [9]	validation_0-rmse:41.9414
# [21:43:45] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 2 extra nodes, 0 pruned nodes, max_depth=1
# [10]	validation_0-rmse:37.3319
# [21:43:45] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [11]	validation_0-rmse:34.0974
# [21:43:45] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 2 extra nodes, 0 pruned nodes, max_depth=1
# [12]	validation_0-rmse:30.9251
# [21:43:45] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [13]	validation_0-rmse:28.3226
# [21:43:45] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 2 extra nodes, 0 pruned nodes, max_depth=1
# [14]	validation_0-rmse:26.2766
# [21:43:45] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [15]	validation_0-rmse:24.3711
# [21:43:45] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 2 extra nodes, 0 pruned nodes, max_depth=1
# [16]	validation_0-rmse:22.1322
# [21:43:45] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [17]	validation_0-rmse:20.0574
# [21:43:45] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [18]	validation_0-rmse:18.1067
# [21:43:45] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [19]	validation_0-rmse:16.4291
# [21:43:45] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [20]	validation_0-rmse:14.8711
# [21:43:45] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [21]	validation_0-rmse:13.729
# [21:43:45] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [22]	validation_0-rmse:12.7502
# [21:43:45] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [23]	validation_0-rmse:12.4113
# [21:43:45] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [24]	validation_0-rmse:11.7286
# [21:43:45] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 2 extra nodes, 0 pruned nodes, max_depth=1
# [25]	validation_0-rmse:10.5388
# [21:43:45] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [26]	validation_0-rmse:10.0657
# [21:43:45] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [27]	validation_0-rmse:9.39997
# [21:43:45] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=4
# [28]	validation_0-rmse:9.0116
# [21:43:45] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [29]	validation_0-rmse:8.82944
# [21:43:45] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [30]	validation_0-rmse:8.53681
# [21:43:45] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=3
# [31]	validation_0-rmse:8.51053
# [21:43:45] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=3
# [32]	validation_0-rmse:8.49654
# [21:43:45] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [33]	validation_0-rmse:8.55043
# [21:43:45] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [34]	validation_0-rmse:8.33405
# [21:43:45] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=3
# [35]	validation_0-rmse:8.13611
# [21:43:45] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [36]	validation_0-rmse:8.07851
# [21:43:45] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [37]	validation_0-rmse:7.86194
# [21:43:45] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [38]	validation_0-rmse:7.7019
# [21:43:45] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [39]	validation_0-rmse:7.39656
# [21:43:45] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [40]	validation_0-rmse:7.26791
# [21:43:45] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [41]	validation_0-rmse:7.13778
# [21:43:45] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=3
# [42]	validation_0-rmse:7.21592
# [21:43:45] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [43]	validation_0-rmse:7.02851
# [21:43:45] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [44]	validation_0-rmse:6.94592
# [21:43:45] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [45]	validation_0-rmse:6.7835
# /home/ipcvlab/anaconda2/envs/data_science/lib/python3.6/site-packages/xgboost/core.py:587: FutureWarning: Series.base is deprecated and will be removed in a future version
#   if getattr(data, 'base', None) is not None and \
# [21:43:45] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=3
# [46]	validation_0-rmse:6.92837
# [21:43:45] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [47]	validation_0-rmse:7.02656
# [21:43:45] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=6
# [48]	validation_0-rmse:6.94868
# [21:43:45] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [49]	validation_0-rmse:6.974
# [21:43:45] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [50]	validation_0-rmse:7.01949
# [21:43:45] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 0 pruned nodes, max_depth=5
# [51]	validation_0-rmse:7.07336
# [21:43:45] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [52]	validation_0-rmse:6.97918
# [21:43:45] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [53]	validation_0-rmse:6.95005
# [21:43:45] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 0 pruned nodes, max_depth=5
# [54]	validation_0-rmse:7.05422
# [21:43:45] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [55]	validation_0-rmse:6.98361
# [21:43:45] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=3
# [56]	validation_0-rmse:7.08374
# [21:43:45] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=3
# [57]	validation_0-rmse:7.04662
# [21:43:45] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 0 pruned nodes, max_depth=4
# [58]	validation_0-rmse:6.95156
# [21:43:45] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [59]	validation_0-rmse:6.89382
# [21:43:45] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 0 pruned nodes, max_depth=4
# [60]	validation_0-rmse:6.83606
# [21:43:45] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=3
# [61]	validation_0-rmse:6.81064
# [21:43:45] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 0 pruned nodes, max_depth=5
# [62]	validation_0-rmse:6.77042
# [21:43:45] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [63]	validation_0-rmse:6.79034
# [21:43:45] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=3
# [64]	validation_0-rmse:6.78062
# [21:43:45] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=4
# [65]	validation_0-rmse:6.79404
# [21:43:45] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=4
# [66]	validation_0-rmse:6.78733
# [21:43:45] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=4
# [67]	validation_0-rmse:6.81541
# [21:43:45] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [68]	validation_0-rmse:6.82091
# [21:43:45] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=4
# [69]	validation_0-rmse:6.7959
# [21:43:45] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=4
# [70]	validation_0-rmse:6.75692
# [21:43:45] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [71]	validation_0-rmse:6.69345
# [21:43:45] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [72]	validation_0-rmse:6.61262
# [21:43:45] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=4
# [73]	validation_0-rmse:6.5684
# [21:43:45] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 0 pruned nodes, max_depth=5
# [74]	validation_0-rmse:6.50108
# [21:43:45] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [75]	validation_0-rmse:6.52651
# [21:43:45] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=4
# [76]	validation_0-rmse:6.5287
# [21:43:45] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 0 pruned nodes, max_depth=4
# [77]	validation_0-rmse:6.56552
# [21:43:45] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 0 pruned nodes, max_depth=3
# [78]	validation_0-rmse:6.56241
# [21:43:45] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=3
# [79]	validation_0-rmse:6.5577
# [21:43:45] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [80]	validation_0-rmse:6.5858
# [21:43:45] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=3
# [81]	validation_0-rmse:6.62988
# [21:43:45] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [82]	validation_0-rmse:6.64092
# [21:43:45] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [83]	validation_0-rmse:6.6516
# [21:43:45] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [84]	validation_0-rmse:6.69152
# [21:43:45] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=3
# [85]	validation_0-rmse:6.71932
# [21:43:45] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=3
# [86]	validation_0-rmse:6.69491
# [21:43:45] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=3
# [87]	validation_0-rmse:6.70871
# [21:43:45] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=4
# [88]	validation_0-rmse:6.71194
# [21:43:45] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=4
# [89]	validation_0-rmse:6.72276
# [21:43:45] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [90]	validation_0-rmse:6.69341
# [21:43:45] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=3
# [91]	validation_0-rmse:6.69885
# [21:43:45] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [92]	validation_0-rmse:6.75923
# [21:43:45] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [93]	validation_0-rmse:6.7955
# [21:43:45] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [94]	validation_0-rmse:6.76368
# [21:43:45] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=3
# [95]	validation_0-rmse:6.73976
# [21:43:45] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=3
# [96]	validation_0-rmse:6.71811
# [21:43:45] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 0 pruned nodes, max_depth=3
# [97]	validation_0-rmse:6.71151
# [21:43:45] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [98]	validation_0-rmse:6.70375
# [21:43:45] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=4
# [99]	validation_0-rmse:6.70861
# [21:43:45] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=4
# [100]	validation_0-rmse:6.66582
# [21:43:45] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=3
# [101]	validation_0-rmse:6.6654
# [21:43:45] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 0 pruned nodes, max_depth=4
# [102]	validation_0-rmse:6.62869
# [21:43:45] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [103]	validation_0-rmse:6.62284
# [21:43:45] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=3
# [104]	validation_0-rmse:6.57755
# [21:43:45] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [105]	validation_0-rmse:6.59363
# [21:43:45] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 0 pruned nodes, max_depth=4
# [106]	validation_0-rmse:6.57205
# [21:43:45] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=3
# [107]	validation_0-rmse:6.55771
# [21:43:45] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=3
# [108]	validation_0-rmse:6.47613
# [21:43:45] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [109]	validation_0-rmse:6.44511
# [21:43:45] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=3
# [110]	validation_0-rmse:6.43849
# [21:43:45] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=4
# [111]	validation_0-rmse:6.46101
# [21:43:45] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=3
# [112]	validation_0-rmse:6.5028
# [21:43:45] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=3
# [113]	validation_0-rmse:6.45387
# [21:43:45] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [114]	validation_0-rmse:6.43709
# [21:43:45] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [115]	validation_0-rmse:6.40795
# [21:43:45] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [116]	validation_0-rmse:6.40571
# [21:43:45] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 0 pruned nodes, max_depth=5
# [117]	validation_0-rmse:6.42492
# [21:43:45] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=4
# [118]	validation_0-rmse:6.43209
# [21:43:45] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=3
# [119]	validation_0-rmse:6.40717
# [21:43:45] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=4
# [120]	validation_0-rmse:6.37582
# [21:43:45] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=3
# [121]	validation_0-rmse:6.36696
# [21:43:45] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 0 pruned nodes, max_depth=3
# [122]	validation_0-rmse:6.37246
# [21:43:45] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=3
# [123]	validation_0-rmse:6.35424
# [21:43:45] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [124]	validation_0-rmse:6.34354
# [21:43:46] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [125]	validation_0-rmse:6.3354
# [21:43:46] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 0 pruned nodes, max_depth=3
# [126]	validation_0-rmse:6.36124
# [21:43:46] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=3
# [127]	validation_0-rmse:6.40248
# [21:43:46] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [128]	validation_0-rmse:6.41445
# [21:43:46] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 0 pruned nodes, max_depth=3
# [129]	validation_0-rmse:6.38492
# [21:43:46] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=4
# [130]	validation_0-rmse:6.38456
# [21:43:46] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=3
# [131]	validation_0-rmse:6.3869
# [21:43:46] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=4
# [132]	validation_0-rmse:6.38601
# [21:43:46] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [133]	validation_0-rmse:6.40646
# [21:43:46] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [134]	validation_0-rmse:6.40525
# [21:43:46] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [135]	validation_0-rmse:6.44159
# [21:43:46] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=3
# [136]	validation_0-rmse:6.42488
# [21:43:46] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=3
# [137]	validation_0-rmse:6.4063
# [21:43:46] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=3
# [138]	validation_0-rmse:6.41564
# [21:43:46] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 0 pruned nodes, max_depth=4
# [139]	validation_0-rmse:6.43964
# [21:43:46] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [140]	validation_0-rmse:6.42962
# [21:43:46] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [141]	validation_0-rmse:6.43468
# [21:43:46] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 0 pruned nodes, max_depth=3
# [142]	validation_0-rmse:6.41452
# [21:43:46] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=4
# [143]	validation_0-rmse:6.42607
# [21:43:46] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 0 pruned nodes, max_depth=3
# [144]	validation_0-rmse:6.39694
# [21:43:46] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=3
# [145]	validation_0-rmse:6.39801
# [21:43:46] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=3
# [146]	validation_0-rmse:6.38847
# [21:43:46] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 0 pruned nodes, max_depth=4
# [147]	validation_0-rmse:6.37361
# [21:43:46] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [148]	validation_0-rmse:6.38585
# [21:43:46] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=4
# [149]	validation_0-rmse:6.4098
# [21:43:46] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=4
# [150]	validation_0-rmse:6.43019
# [21:43:46] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 0 pruned nodes, max_depth=5
# [151]	validation_0-rmse:6.44453
# [21:43:46] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=3
# [152]	validation_0-rmse:6.43151
# [21:43:46] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=4
# [153]	validation_0-rmse:6.43995
# [21:43:46] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=3
# [154]	validation_0-rmse:6.41819
# [21:43:46] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=3
# [155]	validation_0-rmse:6.41065
# [21:43:46] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=3
# [156]	validation_0-rmse:6.40505
# [21:43:46] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [157]	validation_0-rmse:6.41553
# [21:43:46] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 0 pruned nodes, max_depth=5
# [158]	validation_0-rmse:6.42023
# [21:43:46] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 0 pruned nodes, max_depth=3
# [159]	validation_0-rmse:6.39753
# [21:43:46] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=3
# [160]	validation_0-rmse:6.40185
# [21:43:46] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=3
# [161]	validation_0-rmse:6.39576
# [21:43:46] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 0 pruned nodes, max_depth=4
# [162]	validation_0-rmse:6.37673
# [21:43:46] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 0 pruned nodes, max_depth=4
# [163]	validation_0-rmse:6.38384
# [21:43:46] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 0 pruned nodes, max_depth=5
# [164]	validation_0-rmse:6.37788
# [21:43:46] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=3
# [165]	validation_0-rmse:6.38442
# [21:43:46] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=4
# [166]	validation_0-rmse:6.37416
# [21:43:46] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=4
# [167]	validation_0-rmse:6.37443
# [21:43:46] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [168]	validation_0-rmse:6.37349
# [21:43:46] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [169]	validation_0-rmse:6.36411
# [21:43:46] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=3
# [170]	validation_0-rmse:6.3667
# [21:43:46] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [171]	validation_0-rmse:6.36657
# [21:43:46] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [172]	validation_0-rmse:6.37584
# [21:43:46] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 0 pruned nodes, max_depth=4
# [173]	validation_0-rmse:6.38595
# [21:43:46] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=4
# [174]	validation_0-rmse:6.38367
# [21:43:46] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [175]	validation_0-rmse:6.38092
# [21:43:46] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=5
# [176]	validation_0-rmse:6.37884
# [21:43:46] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 0 pruned nodes, max_depth=5
# [177]	validation_0-rmse:6.38484
# [21:43:46] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 0 pruned nodes, max_depth=5
# [178]	validation_0-rmse:6.38912
# [21:43:46] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=3
# [179]	validation_0-rmse:6.38499
# [21:43:46] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [180]	validation_0-rmse:6.38321
# [21:43:46] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=4
# [181]	validation_0-rmse:6.38304
# [21:43:46] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 0 pruned nodes, max_depth=4
# [182]	validation_0-rmse:6.37444
# [21:43:46] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=4
# [183]	validation_0-rmse:6.36822
# [21:43:46] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [184]	validation_0-rmse:6.37398
# [21:43:46] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [185]	validation_0-rmse:6.36767
# [21:43:46] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [186]	validation_0-rmse:6.37191
# [21:43:46] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=3
# [187]	validation_0-rmse:6.37813
# [21:43:46] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [188]	validation_0-rmse:6.37258
# [21:43:46] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=3
# [189]	validation_0-rmse:6.36258
# [21:43:46] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [190]	validation_0-rmse:6.36484
# [21:43:46] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [191]	validation_0-rmse:6.36937
# [21:43:46] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [192]	validation_0-rmse:6.36763
# [21:43:46] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 0 pruned nodes, max_depth=5
# [193]	validation_0-rmse:6.36788
# [21:43:46] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=4
# [194]	validation_0-rmse:6.36924
# [21:43:46] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [195]	validation_0-rmse:6.37161
# [21:43:46] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [196]	validation_0-rmse:6.37871
# [21:43:46] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 0 pruned nodes, max_depth=3
# [197]	validation_0-rmse:6.37971
# [21:43:46] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=4
# [198]	validation_0-rmse:6.39155
# [21:43:46] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=4
# [199]	validation_0-rmse:6.39236
# [21:43:46] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=5
# [200]	validation_0-rmse:6.39641
# [21:43:46] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [201]	validation_0-rmse:6.37709
# [21:43:46] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [202]	validation_0-rmse:6.38615
# [21:43:46] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=4
# [203]	validation_0-rmse:6.3898
# [21:43:46] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=4
# [204]	validation_0-rmse:6.37821
# [21:43:46] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [205]	validation_0-rmse:6.37699
# [21:43:46] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=3
# [206]	validation_0-rmse:6.37057
# [21:43:46] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=4
# [207]	validation_0-rmse:6.36999
# [21:43:46] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=5
# [208]	validation_0-rmse:6.36978
# [21:43:46] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=4
# [209]	validation_0-rmse:6.36642
# [21:43:46] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [210]	validation_0-rmse:6.36586
# [21:43:46] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=4
# [211]	validation_0-rmse:6.37339
# [21:43:46] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 0 pruned nodes, max_depth=4
# [212]	validation_0-rmse:6.37673
# [21:43:46] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 0 pruned nodes, max_depth=3
# [213]	validation_0-rmse:6.37202
# [21:43:46] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 0 pruned nodes, max_depth=3
# [214]	validation_0-rmse:6.3629
# [21:43:46] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=3
# [215]	validation_0-rmse:6.37512
# [21:43:46] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=3
# [216]	validation_0-rmse:6.37881
# ...
# [927]	validation_0-rmse:6.28224
# [21:43:49] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [928]	validation_0-rmse:6.28227
# [21:43:49] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [929]	validation_0-rmse:6.28233
# [21:43:49] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [930]	validation_0-rmse:6.28233
# [21:43:49] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [931]	validation_0-rmse:6.28225
# [21:43:49] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [932]	validation_0-rmse:6.28231
# [21:43:49] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [933]	validation_0-rmse:6.28236
# [21:43:49] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [934]	validation_0-rmse:6.28239
# [21:43:49] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [935]	validation_0-rmse:6.2824
# [21:43:49] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [936]	validation_0-rmse:6.28242
# [21:43:49] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 2 extra nodes, 0 pruned nodes, max_depth=1
# [937]	validation_0-rmse:6.28242
# [21:43:49] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [938]	validation_0-rmse:6.28244
# [21:43:49] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [939]	validation_0-rmse:6.28245
# [21:43:49] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [940]	validation_0-rmse:6.28247
# [21:43:49] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [941]	validation_0-rmse:6.28256
# [21:43:49] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [942]	validation_0-rmse:6.28241
# [21:43:49] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 2 extra nodes, 0 pruned nodes, max_depth=1
# [943]	validation_0-rmse:6.2824
# [21:43:49] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [944]	validation_0-rmse:6.28236
# [21:43:49] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [945]	validation_0-rmse:6.28238
# [21:43:49] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=4
# [946]	validation_0-rmse:6.2824
# [21:43:49] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [947]	validation_0-rmse:6.28241
# [21:43:49] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [948]	validation_0-rmse:6.28239
# [21:43:49] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=3
# [949]	validation_0-rmse:6.2825
# [21:43:49] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [950]	validation_0-rmse:6.28259
# [21:43:49] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [951]	validation_0-rmse:6.28247
# [21:43:49] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 2 extra nodes, 0 pruned nodes, max_depth=1
# [952]	validation_0-rmse:6.28247
# [21:43:49] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [953]	validation_0-rmse:6.28252
# [21:43:49] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=3
# [954]	validation_0-rmse:6.28253
# [21:43:49] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [955]	validation_0-rmse:6.28252
# [21:43:49] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=4
# [956]	validation_0-rmse:6.28252
# [21:43:49] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [957]	validation_0-rmse:6.28249
# [21:43:49] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=4
# [958]	validation_0-rmse:6.28241
# [21:43:49] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [959]	validation_0-rmse:6.28244
# [21:43:49] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [960]	validation_0-rmse:6.28247
# [21:43:49] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [961]	validation_0-rmse:6.28251
# [21:43:49] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 2 extra nodes, 0 pruned nodes, max_depth=1
# [962]	validation_0-rmse:6.28249
# [21:43:49] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 2 extra nodes, 0 pruned nodes, max_depth=1
# [963]	validation_0-rmse:6.28247
# [21:43:49] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [964]	validation_0-rmse:6.28249
# [21:43:49] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [965]	validation_0-rmse:6.28254
# [21:43:49] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [966]	validation_0-rmse:6.28252
# [21:43:49] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [967]	validation_0-rmse:6.28252
# [21:43:49] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 2 extra nodes, 0 pruned nodes, max_depth=1
# [968]	validation_0-rmse:6.28251
# [21:43:49] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [969]	validation_0-rmse:6.28248
# [21:43:49] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [970]	validation_0-rmse:6.28252
# [21:43:49] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=4
# [971]	validation_0-rmse:6.28252
# [21:43:49] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 2 extra nodes, 0 pruned nodes, max_depth=1
# [972]	validation_0-rmse:6.28251
# [21:43:49] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [973]	validation_0-rmse:6.2825
# [21:43:49] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 2 extra nodes, 0 pruned nodes, max_depth=1
# [974]	validation_0-rmse:6.28256
# [21:43:49] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 2 extra nodes, 0 pruned nodes, max_depth=1
# [975]	validation_0-rmse:6.28256
# [21:43:49] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [976]	validation_0-rmse:6.28256
# [21:43:49] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [977]	validation_0-rmse:6.28257
# [21:43:49] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 2 extra nodes, 0 pruned nodes, max_depth=1
# [978]	validation_0-rmse:6.28259
# [21:43:49] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=4
# [979]	validation_0-rmse:6.2826
# [21:43:49] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=4
# [980]	validation_0-rmse:6.28259
# [21:43:49] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 2 extra nodes, 0 pruned nodes, max_depth=1
# [981]	validation_0-rmse:6.2826
# [21:43:49] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 2 extra nodes, 0 pruned nodes, max_depth=1
# [982]	validation_0-rmse:6.2826
# [21:43:49] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [983]	validation_0-rmse:6.28263
# [21:43:49] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=4
# [984]	validation_0-rmse:6.28262
# [21:43:49] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=4
# [985]	validation_0-rmse:6.28252
# [21:43:49] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 2 extra nodes, 0 pruned nodes, max_depth=1
# [986]	validation_0-rmse:6.28249
# [21:43:49] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [987]	validation_0-rmse:6.28238
# [21:43:49] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [988]	validation_0-rmse:6.28242
# [21:43:49] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [989]	validation_0-rmse:6.28242
# [21:43:49] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 2 extra nodes, 0 pruned nodes, max_depth=1
# [990]	validation_0-rmse:6.28242
# [21:43:49] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [991]	validation_0-rmse:6.2825
# [21:43:49] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [992]	validation_0-rmse:6.28256
# [21:43:49] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=4
# [993]	validation_0-rmse:6.2826
# [21:43:49] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=4
# [994]	validation_0-rmse:6.28271
# [21:43:49] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [995]	validation_0-rmse:6.28265
# [21:43:49] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [996]	validation_0-rmse:6.28264
# [21:43:49] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [997]	validation_0-rmse:6.2827
# [21:43:49] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 2 extra nodes, 0 pruned nodes, max_depth=1
# [998]	validation_0-rmse:6.28271
# [21:43:49] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [999]	validation_0-rmse:6.2827
# Duration: 4.392889976501465s

# %%
# Plot feature importance
figsize=(7,7)
fig, ax = plt.subplots(1,1,figsize=figsize)
plot_importance(model, ax=ax,height = 1)

# %%
# predict sales in test dataset
test_predictions = model.predict(X_test).flatten()

# scatter plot of True vs Predicted values
plt.scatter(y_test, test_predictions)
plt.xlabel('True Values $')
plt.ylabel('Predictions $')
plt.axis('equal')
plt.axis('square')
plt.xlim([100,plt.xlim()[1]])
plt.ylim([100,plt.ylim()[1]])
_ = plt.plot([0, 1000], [0, 1000])

# %%
# Histogram of error values
error = test_predictions - y_test
plt.hist(error, bins = 25)
plt.xlabel("Prediction Error $")
_ = plt.ylabel("Count")

# %% [markdown]
# # Anomaly detection approach

# %%
# Data normalization
scaler = MinMaxScaler(feature_range=(0, 1))
X_train = scaler.fit_transform(df_train[:-5]) 
X_test = scaler.fit_transform(df_train[-5:])

# %%
X_train.shape
# Out:
# (46, 11)

# %%
# Reshape for LSTM
X_train = X_train.reshape(X_train.shape[0], 1, X_train.shape[1])
X_test = X_test.reshape(X_test.shape[0], 1, X_test.shape[1])

# %%
# define the autoencoder network model
def autoencoder_model(X):
    inputs = Input(shape=(X.shape[1], X.shape[2]))
    L1 = LSTM(16, activation='relu', return_sequences=True, 
              kernel_regularizer=regularizers.l2(0.00))(inputs)
    L2 = LSTM(4, activation='relu', return_sequences=False)(L1)
    L3 = RepeatVector(X.shape[1])(L2)
    L4 = LSTM(4, activation='relu', return_sequences=True)(L3)
    L5 = LSTM(16, activation='relu', return_sequences=True)(L4)
    output = TimeDistributed(Dense(X.shape[2]))(L5)    
    model = Model(inputs=inputs, outputs=output)
    return model

# %%
# create the autoencoder model
model = autoencoder_model(X_train)
model.compile(optimizer='adam', loss='mae')
model.summary()
# Out:
# WARNING:tensorflow:From /home/ipcvlab/anaconda2/envs/data_science/lib/python3.6/site-packages/tensorflow/python/ops/resource_variable_ops.py:435: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 1, 11)             0
# _________________________________________________________________
# lstm (LSTM)                  (None, 1, 16)             1792
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 4)                 336
# _________________________________________________________________
# repeat_vector (RepeatVector) (None, 1, 4)              0
# _________________________________________________________________
# lstm_2 (LSTM)                (None, 1, 4)              144
# _________________________________________________________________
# lstm_3 (LSTM)                (None, 1, 16)             1344
# _________________________________________________________________
# time_distributed (TimeDistri (None, 1, 11)             187
# =================================================================
# Total params: 3,803
# Trainable params: 3,803
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = model.fit(X_train, X_train, epochs=100, batch_size=10,
                    validation_split=0.05).history
# Out:
# Train on 43 samples, validate on 3 samples
# WARNING:tensorflow:From /home/ipcvlab/anaconda2/envs/data_science/lib/python3.6/site-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Epoch 1/100
# 43/43 [==============================] - 5s 128ms/sample - loss: 0.3344 - val_loss: 0.7691
# Epoch 2/100
# 43/43 [==============================] - 0s 2ms/sample - loss: 0.3294 - val_loss: 0.7638
# Epoch 3/100
# 43/43 [==============================] - 0s 2ms/sample - loss: 0.3245 - val_loss: 0.7584
# Epoch 4/100
# 43/43 [==============================] - 0s 6ms/sample - loss: 0.3195 - val_loss: 0.7531
# Epoch 5/100
# 43/43 [==============================] - 0s 4ms/sample - loss: 0.3147 - val_loss: 0.7476
# Epoch 6/100
# 43/43 [==============================] - 0s 2ms/sample - loss: 0.3098 - val_loss: 0.7422
# Epoch 7/100
# 43/43 [==============================] - 0s 1ms/sample - loss: 0.3050 - val_loss: 0.7367
# Epoch 8/100
# 43/43 [==============================] - 0s 3ms/sample - loss: 0.3003 - val_loss: 0.7313
# Epoch 9/100
# 43/43 [==============================] - 0s 2ms/sample - loss: 0.2956 - val_loss: 0.7258
# Epoch 10/100
# 43/43 [==============================] - 0s 2ms/sample - loss: 0.2912 - val_loss: 0.7201
# Epoch 11/100
# 43/43 [==============================] - 0s 2ms/sample - loss: 0.2867 - val_loss: 0.7145
# Epoch 12/100
# 43/43 [==============================] - 0s 2ms/sample - loss: 0.2821 - val_loss: 0.7089
# Epoch 13/100
# 43/43 [==============================] - 0s 2ms/sample - loss: 0.2776 - val_loss: 0.7030
# Epoch 14/100
# 43/43 [==============================] - 0s 3ms/sample - loss: 0.2731 - val_loss: 0.6968
# Epoch 15/100
# 43/43 [==============================] - 0s 2ms/sample - loss: 0.2688 - val_loss: 0.6904
# Epoch 16/100
# 43/43 [==============================] - 0s 2ms/sample - loss: 0.2644 - val_loss: 0.6840
# Epoch 17/100
# 43/43 [==============================] - 0s 3ms/sample - loss: 0.2600 - val_loss: 0.6774
# Epoch 18/100
# 43/43 [==============================] - 0s 2ms/sample - loss: 0.2558 - val_loss: 0.6700
# Epoch 19/100
# 43/43 [==============================] - 0s 2ms/sample - loss: 0.2514 - val_loss: 0.6616
# Epoch 20/100
# 43/43 [==============================] - 0s 2ms/sample - loss: 0.2471 - val_loss: 0.6508
# Epoch 21/100
# 43/43 [==============================] - 0s 2ms/sample - loss: 0.2425 - val_loss: 0.6363
# Epoch 22/100
# 43/43 [==============================] - 0s 2ms/sample - loss: 0.2376 - val_loss: 0.6148
# Epoch 23/100
# 43/43 [==============================] - 0s 2ms/sample - loss: 0.2321 - val_loss: 0.5804
# Epoch 24/100
# 43/43 [==============================] - 0s 2ms/sample - loss: 0.2268 - val_loss: 0.5336
# Epoch 25/100
# 43/43 [==============================] - 0s 2ms/sample - loss: 0.2208 - val_loss: 0.4685
# Epoch 26/100
# 43/43 [==============================] - 0s 7ms/sample - loss: 0.2130 - val_loss: 0.3873
# Epoch 27/100
# 43/43 [==============================] - 0s 2ms/sample - loss: 0.2056 - val_loss: 0.3282
# Epoch 28/100
# 43/43 [==============================] - 0s 2ms/sample - loss: 0.1954 - val_loss: 0.3492
# Epoch 29/100
# 43/43 [==============================] - 0s 2ms/sample - loss: 0.1862 - val_loss: 0.4458
# Epoch 30/100
# 43/43 [==============================] - 0s 2ms/sample - loss: 0.1797 - val_loss: 0.4101
# Epoch 31/100
# 43/43 [==============================] - 0s 2ms/sample - loss: 0.1738 - val_loss: 0.3638
# Epoch 32/100
# 43/43 [==============================] - 0s 2ms/sample - loss: 0.1681 - val_loss: 0.3100
# Epoch 33/100
# 43/43 [==============================] - 0s 2ms/sample - loss: 0.1619 - val_loss: 0.3023
# Epoch 34/100
# 43/43 [==============================] - 0s 2ms/sample - loss: 0.1566 - val_loss: 0.2958
# Epoch 35/100
# 43/43 [==============================] - 0s 2ms/sample - loss: 0.1507 - val_loss: 0.2995
# Epoch 36/100
# 43/43 [==============================] - 0s 2ms/sample - loss: 0.1444 - val_loss: 0.3207
# Epoch 37/100
# 43/43 [==============================] - 0s 2ms/sample - loss: 0.1375 - val_loss: 0.3389
# Epoch 38/100
# 43/43 [==============================] - 0s 1ms/sample - loss: 0.1312 - val_loss: 0.3683
# Epoch 39/100
# 43/43 [==============================] - 0s 2ms/sample - loss: 0.1274 - val_loss: 0.3740
# Epoch 40/100
# 43/43 [==============================] - 0s 2ms/sample - loss: 0.1241 - val_loss: 0.3987
# Epoch 41/100
# 43/43 [==============================] - 0s 1ms/sample - loss: 0.1218 - val_loss: 0.3767
# Epoch 42/100
# 43/43 [==============================] - 0s 2ms/sample - loss: 0.1197 - val_loss: 0.3656
# Epoch 43/100
# 43/43 [==============================] - 0s 2ms/sample - loss: 0.1183 - val_loss: 0.3393
# Epoch 44/100
# 43/43 [==============================] - 0s 2ms/sample - loss: 0.1174 - val_loss: 0.3443
# Epoch 45/100
# 43/43 [==============================] - 0s 1ms/sample - loss: 0.1158 - val_loss: 0.3589
# Epoch 46/100
# 43/43 [==============================] - 0s 1ms/sample - loss: 0.1150 - val_loss: 0.3537
# Epoch 47/100
# 43/43 [==============================] - 0s 2ms/sample - loss: 0.1140 - val_loss: 0.3298
# Epoch 48/100
# 43/43 [==============================] - 0s 1ms/sample - loss: 0.1136 - val_loss: 0.3311
# Epoch 49/100
# 43/43 [==============================] - 0s 2ms/sample - loss: 0.1126 - val_loss: 0.3432
# Epoch 50/100
# 43/43 [==============================] - 0s 2ms/sample - loss: 0.1120 - val_loss: 0.3533
# Epoch 51/100
# 43/43 [==============================] - 0s 2ms/sample - loss: 0.1113 - val_loss: 0.3418
# Epoch 52/100
# 43/43 [==============================] - 0s 2ms/sample - loss: 0.1105 - val_loss: 0.3279
# Epoch 53/100
# 43/43 [==============================] - 0s 6ms/sample - loss: 0.1100 - val_loss: 0.3202
# Epoch 54/100
# 43/43 [==============================] - 0s 2ms/sample - loss: 0.1093 - val_loss: 0.3280
# Epoch 55/100
# 43/43 [==============================] - 0s 2ms/sample - loss: 0.1086 - val_loss: 0.3120
# Epoch 56/100
# 43/43 [==============================] - 0s 2ms/sample - loss: 0.1082 - val_loss: 0.2835
# Epoch 57/100
# 43/43 [==============================] - 0s 2ms/sample - loss: 0.1078 - val_loss: 0.2847
# Epoch 58/100
# 43/43 [==============================] - 0s 1ms/sample - loss: 0.1068 - val_loss: 0.3011
# Epoch 59/100
# 43/43 [==============================] - 0s 1ms/sample - loss: 0.1067 - val_loss: 0.2957
# Epoch 60/100
# 43/43 [==============================] - 0s 1ms/sample - loss: 0.1059 - val_loss: 0.2827
# Epoch 61/100
# 43/43 [==============================] - 0s 1ms/sample - loss: 0.1055 - val_loss: 0.2671
# Epoch 62/100
# 43/43 [==============================] - 0s 1ms/sample - loss: 0.1049 - val_loss: 0.2778
# Epoch 63/100
# 43/43 [==============================] - 0s 2ms/sample - loss: 0.1045 - val_loss: 0.2982
# Epoch 64/100
# 43/43 [==============================] - 0s 1ms/sample - loss: 0.1038 - val_loss: 0.2833
# Epoch 65/100
# 43/43 [==============================] - 0s 2ms/sample - loss: 0.1030 - val_loss: 0.2728
# Epoch 66/100
# 43/43 [==============================] - 0s 1ms/sample - loss: 0.1028 - val_loss: 0.2706
# Epoch 67/100
# 43/43 [==============================] - 0s 2ms/sample - loss: 0.1020 - val_loss: 0.2812
# Epoch 68/100
# 43/43 [==============================] - 0s 2ms/sample - loss: 0.1016 - val_loss: 0.2874
# Epoch 69/100
# 43/43 [==============================] - 0s 2ms/sample - loss: 0.1014 - val_loss: 0.2800
# Epoch 70/100
# 43/43 [==============================] - 0s 2ms/sample - loss: 0.1007 - val_loss: 0.2691
# Epoch 71/100
# 43/43 [==============================] - 0s 2ms/sample - loss: 0.1003 - val_loss: 0.2618
# Epoch 72/100
# 43/43 [==============================] - 0s 1ms/sample - loss: 0.0999 - val_loss: 0.2677
# Epoch 73/100
# 43/43 [==============================] - 0s 1ms/sample - loss: 0.0993 - val_loss: 0.2608
# Epoch 74/100
# 43/43 [==============================] - 0s 1ms/sample - loss: 0.0990 - val_loss: 0.2585
# Epoch 75/100
# 43/43 [==============================] - 0s 1ms/sample - loss: 0.0987 - val_loss: 0.2485
# Epoch 76/100
# 43/43 [==============================] - 0s 1ms/sample - loss: 0.0981 - val_loss: 0.2600
# Epoch 77/100
# 43/43 [==============================] - 0s 1ms/sample - loss: 0.0984 - val_loss: 0.2560
# Epoch 78/100
# 43/43 [==============================] - 0s 2ms/sample - loss: 0.0976 - val_loss: 0.2350
# Epoch 79/100
# 43/43 [==============================] - 0s 1ms/sample - loss: 0.0976 - val_loss: 0.2513
# Epoch 80/100
# 43/43 [==============================] - 0s 1ms/sample - loss: 0.0970 - val_loss: 0.2474
# Epoch 81/100
# 43/43 [==============================] - 0s 2ms/sample - loss: 0.0964 - val_loss: 0.2361
# Epoch 82/100
# 43/43 [==============================] - 0s 7ms/sample - loss: 0.0963 - val_loss: 0.2397
# Epoch 83/100
# 43/43 [==============================] - 0s 2ms/sample - loss: 0.0957 - val_loss: 0.2410
# Epoch 84/100
# 43/43 [==============================] - 0s 2ms/sample - loss: 0.0956 - val_loss: 0.2454
# Epoch 85/100
# 43/43 [==============================] - 0s 2ms/sample - loss: 0.0950 - val_loss: 0.2329
# Epoch 86/100
# 43/43 [==============================] - 0s 2ms/sample - loss: 0.0946 - val_loss: 0.2403
# Epoch 87/100
# 43/43 [==============================] - 0s 2ms/sample - loss: 0.0941 - val_loss: 0.2439
# Epoch 88/100
# 43/43 [==============================] - 0s 2ms/sample - loss: 0.0938 - val_loss: 0.2514
# Epoch 89/100
# 43/43 [==============================] - 0s 2ms/sample - loss: 0.0936 - val_loss: 0.2546
# Epoch 90/100
# 43/43 [==============================] - 0s 2ms/sample - loss: 0.0931 - val_loss: 0.2476
# Epoch 91/100
# 43/43 [==============================] - 0s 2ms/sample - loss: 0.0927 - val_loss: 0.2548
# Epoch 92/100
# 43/43 [==============================] - 0s 2ms/sample - loss: 0.0925 - val_loss: 0.2527
# Epoch 93/100
# 43/43 [==============================] - 0s 2ms/sample - loss: 0.0922 - val_loss: 0.2515
# Epoch 94/100
# 43/43 [==============================] - 0s 1ms/sample - loss: 0.0924 - val_loss: 0.2433
# Epoch 95/100
# 43/43 [==============================] - 0s 2ms/sample - loss: 0.0918 - val_loss: 0.2648
# Epoch 96/100
# 43/43 [==============================] - 0s 1ms/sample - loss: 0.0926 - val_loss: 0.2624
# Epoch 97/100
# 43/43 [==============================] - 0s 1ms/sample - loss: 0.0920 - val_loss: 0.2576
# Epoch 98/100
# 43/43 [==============================] - 0s 2ms/sample - loss: 0.0912 - val_loss: 0.2311
# Epoch 99/100
# 43/43 [==============================] - 0s 2ms/sample - loss: 0.0914 - val_loss: 0.2332
# Epoch 100/100
# 43/43 [==============================] - 0s 1ms/sample - loss: 0.0907 - val_loss: 0.2480

# %%
# plot the training losses
fig, ax = plt.subplots(figsize=(14, 6), dpi=80)
ax.plot(history['loss'], 'b', label='Train', linewidth=2)
ax.plot(history['val_loss'], 'r', label='Validation', linewidth=2)
ax.set_title('Model loss', fontsize=16)
ax.set_ylabel('Loss (mae)')
ax.set_xlabel('Epoch')
ax.legend(loc='upper right')
plt.show()

# %%
# plot the loss distribution of the training set
X_pred = model.predict(X_train)
X_pred = X_pred.reshape(X_pred.shape[0], X_pred.shape[2])
X_pred = pd.DataFrame(X_pred, columns=df_train.columns)
X_pred.index = df_train[:-5].index

scored = pd.DataFrame(index=df_train[:-5].index)
Xtrain = X_train.reshape(X_train.shape[0], X_train.shape[2])
scored['Loss_mae'] = np.mean(np.abs(X_pred-Xtrain), axis = 1)
plt.figure(figsize=(16,9), dpi=80)
plt.title('Loss Distribution', fontsize=16)
sns.distplot(scored['Loss_mae'], bins = 20, kde= True, color = 'blue');
plt.xlim([0.0,.5])

#Out[17]:
#(0.0, 0.5)
# Out:
# (0.0, 0.5)

# %%
# calculate the loss on the test set
X_pred = model.predict(X_test)
X_pred = X_pred.reshape(X_pred.shape[0], X_pred.shape[2])
X_pred = pd.DataFrame(X_pred, columns=df_train.columns)
X_pred.index = df_train[-5:].index

scored = pd.DataFrame(index=df_train[-5:].index)
Xtest = X_test.reshape(X_test.shape[0], X_test.shape[2])
scored['Loss_mae'] = np.mean(np.abs(X_pred-Xtest), axis = 1)
scored['Threshold'] = 0.2
scored['Anomaly'] = scored['Loss_mae'] > scored['Threshold']
scored.head()
# Out:
#          Loss_mae  Threshold  Anomaly
# Tarih
# 2018-12  0.274083        0.2     True
# 2019-03  0.302982        0.2     True
# 2019-06  0.418642        0.2     True
# 2019-09  0.219051        0.2     True
# 2019-12  0.269110        0.2     True

# %%
# calculate the same metrics for the training set 
# and merge all data in a single dataframe for plotting
X_pred_train = model.predict(X_train)
X_pred_train = X_pred_train.reshape(X_pred_train.shape[0], X_pred_train.shape[2])
X_pred_train = pd.DataFrame(X_pred_train, columns=df_train[:-5].columns)
X_pred_train.index = df_train[:-5].index

scored_train = pd.DataFrame(index=df_train[:-5].index)
scored_train['Loss_mae'] = np.mean(np.abs(X_pred_train-Xtrain), axis = 1)
scored_train['Threshold'] = 0.2
scored_train['Anomaly'] = scored_train['Loss_mae'] > scored_train['Threshold']
scored = pd.concat([scored_train, scored])
scored
scored.to_csv("/home/ipcvlab/Desktop/output.csv")

# %%
# plot bearing failure time plot
scored.plot(logy=True,  figsize=(16,9), ylim=[1e-2,1e2], color=['blue','red'])
