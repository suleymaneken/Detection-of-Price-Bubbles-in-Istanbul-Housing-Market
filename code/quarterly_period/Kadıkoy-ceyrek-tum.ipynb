# %%
import time
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

#plotting
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
sns.set_style("whitegrid")

# %%
from sklearn.model_selection import KFold, GridSearchCV, cross_val_score, train_test_split # Model evaluation
from sklearn.preprocessing import MinMaxScaler # Data normalization
from xgboost import XGBRegressor, DMatrix, plot_importance # XGBoost

# %%
# pip install tensorflow==2
import tensorflow as tf
from tensorflow.keras.layers import Input, Dropout, Dense, LSTM, TimeDistributed, RepeatVector
from tensorflow.keras.models import Model
from tensorflow.keras import regularizers
# Out:
# /home/ipcvlab/anaconda2/envs/data_science/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /home/ipcvlab/anaconda2/envs/data_science/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /home/ipcvlab/anaconda2/envs/data_science/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:528: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /home/ipcvlab/anaconda2/envs/data_science/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:529: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /home/ipcvlab/anaconda2/envs/data_science/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:530: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /home/ipcvlab/anaconda2/envs/data_science/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:535: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %%
df_train = pd.read_excel("/home/ipcvlab/Downloads/ilceler/ceyrek-full-sütun/kadıkoy_ceyrek_tum_veriler.xlsx", index_col = 0) 
cols_list = list(df_train.columns)

# %%
df_train.head()
# Out:
#          HouseEndex      bist  USD/TRY  Aylık_Mevduat_Faizi   Konut_Kredisi  \
# Tarih
# 2007-06      100.00  47093.67   1.3215                 17.59          18.03
# 2007-09      100.60  54044.22   1.2674                 17.34          17.58
# 2007-12      100.10  55538.13   1.1786                 16.35          16.53
# 2008-03      100.10  39015.44   1.2383                 15.78          17.28
# 2008-06       90.69  35089.53   1.2337                 16.75          17.60
#
#          ic_borc_maliyet  tufe_endeks  guven_endeksi    BME    GDP  kira endex
# Tarih
# 2007-06            18.42       139.69          80.95  59.70  67.48      100.00
# 2007-09            18.25       140.13          83.89  59.77  66.52       99.57
# 2007-12            16.54       145.77          80.67  60.09  69.90       97.95
# 2008-03            17.59       150.27          68.74  65.89  72.71       94.30
# 2008-06            21.54       154.51          61.79  73.01  69.04       90.68

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 51 entries, 2007-06 to 2019-12
# Data columns (total 11 columns):
# HouseEndex              51 non-null float64
# bist                    51 non-null float64
# USD/TRY                 51 non-null float64
# Aylık_Mevduat_Faizi     51 non-null float64
# Konut_Kredisi           51 non-null float64
# ic_borc_maliyet         51 non-null float64
# tufe_endeks             51 non-null float64
# guven_endeksi           51 non-null float64
# BME                     51 non-null float64
# GDP                     51 non-null float64
# kira endex              51 non-null float64
# dtypes: float64(11)
# memory usage: 4.8+ KB

# %%
df_train.describe()
# Out:
#        HouseEndex           bist    USD/TRY  Aylık_Mevduat_Faizi   \
# count   51.000000      51.000000  51.000000             51.000000
# mean   237.224902   71876.040784   2.611547             10.961569
# std    124.915850   22471.523840   1.422405              4.433174
# min     79.320000   25764.830000   1.178600              5.390000
# 25%    100.800000   56038.250000   1.562550              7.720000
# 50%    221.800000   74205.470000   2.020800              9.270000
# 75%    370.350000   85810.060000   3.241200             12.815000
# max    392.700000  115333.010000   6.378300             22.170000
#
#        Konut_Kredisi  ic_borc_maliyet  tufe_endeks  guven_endeksi         BME  \
# count      51.000000        51.000000    51.000000      51.000000   51.000000
# mean       13.941569        12.201765   244.600000      70.168235  100.841961
# std         4.025200         4.638079    82.739765       7.519964   39.499889
# min         8.300000         5.770000   139.690000      55.140000   59.700000
# 25%        11.180000         9.045000   178.345000      65.345000   69.635000
# 50%        12.870000        10.340000   223.910000      71.310000   86.570000
# 75%        15.560000        14.810000   287.405000      74.940000  115.490000
# max        27.820000        25.270000   440.500000      83.890000  193.770000
#
#               GDP  kira endex
# count   51.000000   51.000000
# mean    89.811373  168.948627
# std     17.741740   63.259431
# min     63.610000   88.670000
# 25%     72.265000   99.785000
# 50%     90.900000  170.800000
# 75%    104.940000  235.200000
# max    117.530000  253.300000

# %% [markdown]
# ### display Missing values

# %%
label_nas = []
for col in df_train.columns.tolist():
    if np.sum(df_train[col].isnull() ) != 0:
        label_nas.append(col)
    else:
        label_nas.append("")

plt.figure(figsize=(12,7))
plt.suptitle('Missing Values in the Training Set')
sns.heatmap(df_train.isnull(), yticklabels=False, xticklabels=label_nas ,cbar = False, cmap='viridis')
plt.show()

# %%
replace = True # True: replace null in guven_endeksi with average. False: guven_endeksi kullanmadan
if replace:
    df_train = df_train.fillna(df_train.mean())
else:
    df_train.drop('guven_endeksi', axis=1, inplace=True)

# %%
# Correlation matrix
corr_mat = df_train.corr().abs()
# Find most important features relative to target
corr_mat.sort_values(by=["HouseEndex"], ascending = False, inplace = True)
print(corr_mat.HouseEndex)
# Out:
# HouseEndex              1.000000
# kira endex              0.994648
# GDP                     0.965101
# tufe_endeks             0.868512
# bist                    0.855080
# BME                     0.808043
# USD/TRY                 0.797193
# guven_endeksi           0.471540
# Aylık_Mevduat_Faizi     0.107823
# ic_borc_maliyet         0.062933
# Konut_Kredisi           0.008105
# Name: HouseEndex, dtype: float64

# %%
#Correlation matrix between features
corr_mat = df_train.corr().abs()

# %%
#Plot the heatmap with seaborn
plt.figure(figsize=(7,7)) 

mask = np.zeros_like(corr_mat)
mask[np.triu_indices_from(mask)] = True

sns.heatmap(corr_mat, mask=mask,
        xticklabels=corr_mat.columns,
        yticklabels=corr_mat.columns)

# %%
#List the highly correlated columns
corr_tmp = corr_mat.unstack()
corr_tmp = corr_tmp.sort_values(kind="quicksort")

print(corr_tmp[-len(corr_mat)-10:-len(corr_mat)])
# Out:
# GDP          HouseEndex     0.965101
# HouseEndex   GDP            0.965101
# USD/TRY      tufe_endeks    0.976848
# tufe_endeks  USD/TRY        0.976848
# USD/TRY      BME            0.988005
# BME          USD/TRY        0.988005
# tufe_endeks  BME            0.988033
# BME          tufe_endeks    0.988033
# kira endex   HouseEndex     0.994648
# HouseEndex   kira endex     0.994648
# dtype: float64

# %%
# Find most important features relative to target
corr_mat.sort_values(["HouseEndex"], ascending = False, inplace = True)
print(corr_mat.HouseEndex)
# Out:
# HouseEndex              1.000000
# kira endex              0.994648
# GDP                     0.965101
# tufe_endeks             0.868512
# bist                    0.855080
# BME                     0.808043
# USD/TRY                 0.797193
# guven_endeksi           0.471540
# Aylık_Mevduat_Faizi     0.107823
# ic_borc_maliyet         0.062933
# Konut_Kredisi           0.008105
# Name: HouseEndex, dtype: float64

# %% [markdown]
# # Skewness

# %%
#Check the skewness of HouseEndeks
for col in cols_list:
    plt.figure(figsize=(10, 5))
    skewness = df_train[col].skew()
    df_train[col].plot.hist(edgecolor='white', bins=30, 
                                    label=col + ' skew =' + str(round(skewness,2)))
    plt.suptitle("{} distribution".format(col))
    plt.legend()
    plt.show()

# %% [markdown]
# # Box plots

# %%
for col in cols_list:
    plt.figure(figsize=(10, 5))
    # Create the boxplot
    ax = sns.boxplot(x=col, data=df_train)
    # Set the `xlim`
    #ax.set(xlim=(0, 100))
    # Add title
    ax.set_title(col)
    # Show the plot
    plt.show()

# %%
for col in cols_list:    
    y_axis = col
    count = df_train[y_axis].count()
    value=df_train[y_axis]

    plt.figure(figsize=(10, 5))
    sns.regplot(np.linspace(0, count, count), df_train[y_axis], fit_reg=True,
                scatter_kws={'facecolors':np.where( value==True , "red", 'darkviolet'),
               'edgecolor':np.where(value==True , "red", 'darkviolet')},
               line_kws = {'color': 'darkblue'})
    plt.title(col, fontsize=24)
    plt.xlabel('-', fontsize=18)
    plt.ylabel(col, fontsize=18)
    # plt.savefig('figures/Standardised_SalePrice_GrLivArea.png')

# %% [markdown]
# # HouseEndex vs other

# %% [markdown]
# - Kirmizi: bubble fiyatlari iceren regresyon cizgi
# - Mavi: bubble fiyatlari iceren regresyon cizgi
#
# mavi ve kirmizi cizgi arasinda buyuk bir fark varsa, bubble/anomaly mi demek?

# %%
# Displays A Scatter Plot with Regression Line + Outliers in Red

for col in cols_list:
    x_axis = col
    y_axis = 'HouseEndex'
    value=(df_train[y_axis] > 107)
    value2=(df_train[y_axis][:-15] > 107)

    plt.figure(figsize=(10, 5))
    sns.regplot(df_train[x_axis], df_train[y_axis], fit_reg=True,
                scatter_kws={'facecolors':np.where( value==True , "red", 'darkviolet'),
               'edgecolor':np.where(value==True , "red", 'darkviolet')},
               line_kws = {'color': 'darkred'})
    
    sns.regplot(df_train[x_axis][:-15], df_train[y_axis][:-15], fit_reg=True,
                scatter_kws={'facecolors':np.where( value2==True , "red", 'darkviolet'),
               'edgecolor':np.where(value2==True , "red", 'darkviolet')},
               line_kws = {'color': 'darkblue'})
    
    plt.title('HouseEndex vs. {}'.format(x_axis), fontsize=24)
    plt.xlabel(x_axis, fontsize=18)
    plt.ylabel('HouseEndex', fontsize=18)
    # plt.savefig('figures/Standardised_SalePrice_GrLivArea.png')

# %% [markdown]
# # XGBoost
#
# hiç faydası yok bu konuda, eğitimde kullandığımız verileri göre sonuç veriyor, ama şişik olup olmadığını gösteremez

# %%
#y_full = df_train['HouseEndex']
#X_full = df_train.drop(columns=["HouseEndex"])

y_full = df_train['HouseEndex'][:-5]
X_full = df_train.drop(columns=["HouseEndex"])[:-5]

y_test = df_train['HouseEndex'][-5:]
X_test = df_train.drop(columns=["HouseEndex"])[-5:]

X_train, X_val, y_train, y_val = train_test_split(X_full, y_full, test_size=0.2, random_state=123)

# %%
# final model with tuned parameters
model = XGBRegressor(max_depth=6, #dflt 6
                     learning_rate=0.1, #dflt 100
                     n_estimators=1000, #dflt 0.1
                     verbosity = 3,
                     objective='reg:linear',
                     n_jobs=-1,
                     gamma=0, #dflt: 0
                     min_child_weight=3, #0 dflt: 1
                     subsample=0.5,
                     colsample_bytree=1,
                     reg_lambda=0.99994, #dflt: 1
                     reg_alpha=0.00003, #dflt: 0
                     tree_method='exact',
                     scale_pos_weight=1, # dflt: 1
                     random_state=123)

# %%
tick=time.time()

fitted_model = model.fit(X_train, y_train,
                         eval_set=[(X_val, y_val)],
                         eval_metric='rmse', # Equivalent to RMSLE since we have log1p(SalePrice)
                         early_stopping_rounds=1000,
                         verbose=True)

print("Duration: {}s".format(time.time()-tick))
# Out:
# [21:51:43] WARNING: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [21:51:43] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 2 extra nodes, 0 pruned nodes, max_depth=1
# [0]	validation_0-rmse:151.641
# Will train until validation_0-rmse hasn't improved in 1000 rounds.
# [21:51:43] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [1]	validation_0-rmse:142.165
# [21:51:43] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [2]	validation_0-rmse:128.055
# [21:51:43] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 2 extra nodes, 0 pruned nodes, max_depth=1
# [3]	validation_0-rmse:115.247
# [21:51:43] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [4]	validation_0-rmse:104.075
# [21:51:43] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [5]	validation_0-rmse:97.4359
# [21:51:43] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [6]	validation_0-rmse:88.0992
# [21:51:43] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 2 extra nodes, 0 pruned nodes, max_depth=1
# [7]	validation_0-rmse:82.5711
# [21:51:43] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [8]	validation_0-rmse:75.279
# [21:51:43] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [9]	validation_0-rmse:67.5635
# [21:51:43] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [10]	validation_0-rmse:61.1762
# [21:51:43] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [11]	validation_0-rmse:55.746
# [21:51:43] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [12]	validation_0-rmse:50.5431
# [21:51:43] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 2 extra nodes, 0 pruned nodes, max_depth=1
# [13]	validation_0-rmse:46.9854
# [21:51:43] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [14]	validation_0-rmse:44.6292
# [21:51:43] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [15]	validation_0-rmse:40.5583
# [21:51:43] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [16]	validation_0-rmse:36.8234
# [21:51:43] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [17]	validation_0-rmse:33.8394
# [21:51:43] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 2 extra nodes, 0 pruned nodes, max_depth=1
# [18]	validation_0-rmse:30.9694
# [21:51:43] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [19]	validation_0-rmse:27.9688
# [21:51:43] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [20]	validation_0-rmse:25.4457
# [21:51:43] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [21]	validation_0-rmse:24.0227
# [21:51:43] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [22]	validation_0-rmse:22.9504
# [21:51:43] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [23]	validation_0-rmse:22.4886
# [21:51:43] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [24]	validation_0-rmse:21.5183
# [21:51:43] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [25]	validation_0-rmse:20.3775
# [21:51:43] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [26]	validation_0-rmse:19.4423
# [21:51:43] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [27]	validation_0-rmse:18.6508
# [21:51:44] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=3
# [28]	validation_0-rmse:18.3411
# [21:51:44] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [29]	validation_0-rmse:17.6787
# [21:51:44] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [30]	validation_0-rmse:17.3205
# [21:51:44] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [31]	validation_0-rmse:17.0259
# [21:51:44] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=3
# [32]	validation_0-rmse:16.5759
# [21:51:44] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [33]	validation_0-rmse:16.1231
# [21:51:44] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=4
# [34]	validation_0-rmse:15.9979
# [21:51:44] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [35]	validation_0-rmse:15.7901
# [21:51:44] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [36]	validation_0-rmse:15.5991
# [21:51:44] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=4
# [37]	validation_0-rmse:15.3462
# [21:51:44] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [38]	validation_0-rmse:15.1348
# [21:51:44] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [39]	validation_0-rmse:14.9059
# [21:51:44] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [40]	validation_0-rmse:14.6718
# [21:51:44] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [41]	validation_0-rmse:14.5456
# [21:51:44] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=3
# [42]	validation_0-rmse:14.3783
# [21:51:44] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [43]	validation_0-rmse:14.4419
# [21:51:44] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [44]	validation_0-rmse:14.1778
# [21:51:44] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [45]	validation_0-rmse:14.1421
# [21:51:44] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [46]	validation_0-rmse:14.0136
# [21:51:44] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=3
# [47]	validation_0-rmse:13.9952
# [21:51:44] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 0 pruned nodes, max_depth=5
# [48]	validation_0-rmse:13.986
# [21:51:44] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [49]	validation_0-rmse:13.996
# [21:51:44] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [50]	validation_0-rmse:13.9332
# /home/ipcvlab/anaconda2/envs/data_science/lib/python3.6/site-packages/xgboost/core.py:587: FutureWarning: Series.base is deprecated and will be removed in a future version
#   if getattr(data, 'base', None) is not None and \
# [21:51:44] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [51]	validation_0-rmse:13.8026
# [21:51:44] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [52]	validation_0-rmse:13.7684
# [21:51:44] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [53]	validation_0-rmse:13.8376
# [21:51:44] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=4
# [54]	validation_0-rmse:13.7841
# [21:51:44] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=3
# [55]	validation_0-rmse:13.7901
# [21:51:44] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=3
# [56]	validation_0-rmse:13.8153
# [21:51:44] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [57]	validation_0-rmse:13.7891
# [21:51:44] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=3
# [58]	validation_0-rmse:13.7177
# [21:51:44] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [59]	validation_0-rmse:13.6979
# [21:51:44] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=4
# [60]	validation_0-rmse:13.7383
# [21:51:44] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=4
# [61]	validation_0-rmse:13.7784
# [21:51:44] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=4
# [62]	validation_0-rmse:13.8722
# [21:51:44] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [63]	validation_0-rmse:13.9185
# [21:51:44] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [64]	validation_0-rmse:13.9765
# [21:51:44] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [65]	validation_0-rmse:13.9934
# [21:51:44] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=3
# [66]	validation_0-rmse:13.94
# [21:51:44] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [67]	validation_0-rmse:13.8908
# [21:51:44] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [68]	validation_0-rmse:13.982
# [21:51:44] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [69]	validation_0-rmse:13.9377
# [21:51:44] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [70]	validation_0-rmse:13.9901
# [21:51:44] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [71]	validation_0-rmse:13.9583
# [21:51:44] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [72]	validation_0-rmse:13.9574
# [21:51:44] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=4
# [73]	validation_0-rmse:13.9866
# [21:51:44] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=4
# [74]	validation_0-rmse:14.0388
# [21:51:44] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [75]	validation_0-rmse:13.9724
# [21:51:44] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=4
# [76]	validation_0-rmse:14.0331
# [21:51:44] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 0 pruned nodes, max_depth=5
# [77]	validation_0-rmse:13.9651
# [21:51:44] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=4
# [78]	validation_0-rmse:14.0023
# [21:51:44] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=3
# [79]	validation_0-rmse:13.9809
# [21:51:44] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [80]	validation_0-rmse:13.926
# [21:51:44] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=4
# [81]	validation_0-rmse:13.9255
# [21:51:44] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [82]	validation_0-rmse:13.9989
# [21:51:44] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=4
# [83]	validation_0-rmse:13.875
# [21:51:44] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [84]	validation_0-rmse:13.9397
# [21:51:44] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [85]	validation_0-rmse:13.9952
# [21:51:44] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=3
# [86]	validation_0-rmse:14.0492
# [21:51:44] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [87]	validation_0-rmse:13.9423
# [21:51:44] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [88]	validation_0-rmse:13.9162
# [21:51:44] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [89]	validation_0-rmse:13.853
# [21:51:44] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [90]	validation_0-rmse:13.8928
# [21:51:44] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 0 pruned nodes, max_depth=5
# [91]	validation_0-rmse:13.8546
# [21:51:44] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [92]	validation_0-rmse:13.8268
# [21:51:44] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [93]	validation_0-rmse:13.7741
# [21:51:44] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [94]	validation_0-rmse:13.8329
# [21:51:44] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [95]	validation_0-rmse:13.7765
# [21:51:44] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=3
# [96]	validation_0-rmse:13.8103
# [21:51:44] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [97]	validation_0-rmse:13.7742
# [21:51:44] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [98]	validation_0-rmse:13.7534
# [21:51:44] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [99]	validation_0-rmse:13.7284
# [21:51:44] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 0 pruned nodes, max_depth=5
# [100]	validation_0-rmse:13.7479
# [21:51:44] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [101]	validation_0-rmse:13.7751
# [21:51:44] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 0 pruned nodes, max_depth=4
# [102]	validation_0-rmse:13.7452
# [21:51:44] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [103]	validation_0-rmse:13.7956
# [21:51:44] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=4
# [104]	validation_0-rmse:13.7898
# [21:51:44] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [105]	validation_0-rmse:13.739
# [21:51:44] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=4
# [106]	validation_0-rmse:13.7474
# [21:51:44] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=3
# [107]	validation_0-rmse:13.6556
# [21:51:44] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 0 pruned nodes, max_depth=5
# [108]	validation_0-rmse:13.7074
# [21:51:44] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=4
# [109]	validation_0-rmse:13.7206
# [21:51:44] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [110]	validation_0-rmse:13.7359
# [21:51:44] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [111]	validation_0-rmse:13.7488
# [21:51:44] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=4
# [112]	validation_0-rmse:13.7553
# [21:51:44] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 0 pruned nodes, max_depth=5
# [113]	validation_0-rmse:13.8049
# [21:51:44] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [114]	validation_0-rmse:13.7462
# [21:51:44] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [115]	validation_0-rmse:13.782
# [21:51:44] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [116]	validation_0-rmse:13.7568
# [21:51:44] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=3
# [117]	validation_0-rmse:13.7663
# [21:51:44] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=4
# [118]	validation_0-rmse:13.6798
# [21:51:44] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 0 pruned nodes, max_depth=5
# [119]	validation_0-rmse:13.6383
# [21:51:44] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [120]	validation_0-rmse:13.6755
# [21:51:44] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=3
# [121]	validation_0-rmse:13.642
# [21:51:44] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [122]	validation_0-rmse:13.6589
# [21:51:44] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=3
# [123]	validation_0-rmse:13.6537
# [21:51:44] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [124]	validation_0-rmse:13.6341
# [21:51:44] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [125]	validation_0-rmse:13.5549
# [21:51:44] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 0 pruned nodes, max_depth=4
# [126]	validation_0-rmse:13.5266
# [21:51:44] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=4
# [127]	validation_0-rmse:13.4856
# [21:51:44] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=3
# [128]	validation_0-rmse:13.4974
# [21:51:44] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=4
# [129]	validation_0-rmse:13.4937
# [21:51:44] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=4
# [130]	validation_0-rmse:13.4682
# [21:51:44] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [131]	validation_0-rmse:13.4903
# [21:51:44] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=5
# [132]	validation_0-rmse:13.462
# [21:51:44] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [133]	validation_0-rmse:13.4203
# [21:51:44] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [134]	validation_0-rmse:13.4462
# [21:51:44] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [135]	validation_0-rmse:13.3925
# [21:51:44] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [136]	validation_0-rmse:13.4187
# [21:51:44] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [137]	validation_0-rmse:13.3919
# [21:51:44] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [138]	validation_0-rmse:13.3987
# [21:51:44] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 0 pruned nodes, max_depth=3
# [139]	validation_0-rmse:13.3221
# [21:51:44] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [140]	validation_0-rmse:13.328
# [21:51:44] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=4
# [141]	validation_0-rmse:13.3585
# [21:51:44] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [142]	validation_0-rmse:13.3134
# [21:51:44] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=3
# [143]	validation_0-rmse:13.3247
# [21:51:44] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=3
# [144]	validation_0-rmse:13.3608
# [21:51:44] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=4
# [145]	validation_0-rmse:13.3605
# [21:51:44] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=4
# [146]	validation_0-rmse:13.4193
# [21:51:44] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 0 pruned nodes, max_depth=3
# [147]	validation_0-rmse:13.3991
# [21:51:44] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=4
# [148]	validation_0-rmse:13.4092
# [21:51:44] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [149]	validation_0-rmse:13.3934
# [21:51:44] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 0 pruned nodes, max_depth=4
# [150]	validation_0-rmse:13.3701
# [21:51:44] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 0 pruned nodes, max_depth=5
# [151]	validation_0-rmse:13.3731
# [21:51:44] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=3
# [152]	validation_0-rmse:13.3923
# [21:51:44] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 0 pruned nodes, max_depth=4
# [153]	validation_0-rmse:13.4001
# [21:51:44] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [154]	validation_0-rmse:13.491
# [21:51:44] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=4
# [155]	validation_0-rmse:13.5415
# [21:51:44] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=4
# [156]	validation_0-rmse:13.4961
# [21:51:44] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [157]	validation_0-rmse:13.4901
# [21:51:44] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=4
# [158]	validation_0-rmse:13.5272
# [21:51:44] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=4
# [159]	validation_0-rmse:13.575
# [21:51:44] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=3
# [160]	validation_0-rmse:13.5728
# [21:51:44] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=4
# [161]	validation_0-rmse:13.5621
# [21:51:44] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=4
# [162]	validation_0-rmse:13.5152
# [21:51:44] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 0 pruned nodes, max_depth=5
# [163]	validation_0-rmse:13.5245
# [21:51:44] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [164]	validation_0-rmse:13.4988
# [21:51:44] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 0 pruned nodes, max_depth=5
# [165]	validation_0-rmse:13.4788
# [21:51:44] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [166]	validation_0-rmse:13.4699
# [21:51:44] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=3
# [167]	validation_0-rmse:13.4826
# [21:51:44] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [168]	validation_0-rmse:13.422
# [21:51:44] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [169]	validation_0-rmse:13.4616
# [21:51:44] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [170]	validation_0-rmse:13.4323
# [21:51:44] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [171]	validation_0-rmse:13.3671
# [21:51:44] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=3
# [172]	validation_0-rmse:13.3593
# [21:51:44] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=3
# [173]	validation_0-rmse:13.3764
# [21:51:44] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=3
# [174]	validation_0-rmse:13.3888
# [21:51:44] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [175]	validation_0-rmse:13.4277
# [21:51:44] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=6
# [176]	validation_0-rmse:13.4407
# [21:51:44] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 0 pruned nodes, max_depth=4
# [177]	validation_0-rmse:13.4354
# [21:51:44] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 0 pruned nodes, max_depth=4
# [178]	validation_0-rmse:13.4282
# [21:51:44] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=3
# [179]	validation_0-rmse:13.4423
# [21:51:44] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [180]	validation_0-rmse:13.4689
# [21:51:44] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 0 pruned nodes, max_depth=3
# [181]	validation_0-rmse:13.47
# [21:51:44] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=4
# [182]	validation_0-rmse:13.4902
# [21:51:44] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [183]	validation_0-rmse:13.5121
# [21:51:44] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [184]	validation_0-rmse:13.5135
# [21:51:44] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [185]	validation_0-rmse:13.4762
# [21:51:44] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [186]	validation_0-rmse:13.4369
# [21:51:44] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [187]	validation_0-rmse:13.4258
# [21:51:44] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [188]	validation_0-rmse:13.4076
# [21:51:44] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=4
# [189]	validation_0-rmse:13.4246
# [21:51:44] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=4
# [190]	validation_0-rmse:13.4122
# [21:51:44] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [191]	validation_0-rmse:13.3921
# [21:51:44] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [192]	validation_0-rmse:13.3582
# [21:51:44] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 0 pruned nodes, max_depth=3
# [193]	validation_0-rmse:13.3806
# [21:51:44] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [194]	validation_0-rmse:13.3873
# [21:51:44] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [195]	validation_0-rmse:13.4105
# [21:51:44] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [196]	validation_0-rmse:13.4103
# [21:51:44] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=3
# [197]	validation_0-rmse:13.4383
# [21:51:44] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=4
# [198]	validation_0-rmse:13.4605
# [21:51:44] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=4
# [199]	validation_0-rmse:13.4627
# [21:51:44] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 0 pruned nodes, max_depth=5
# [200]	validation_0-rmse:13.4501
# [21:51:44] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [201]	validation_0-rmse:13.4605
# [21:51:44] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=3
# [202]	validation_0-rmse:13.4653
# [21:51:44] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=4
# [203]	validation_0-rmse:13.4856
# [21:51:44] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=3
# [204]	validation_0-rmse:13.4726
# [21:51:44] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=4
# [205]	validation_0-rmse:13.4719
# [21:51:44] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=4
# [206]	validation_0-rmse:13.4507
# [21:51:44] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=4
# [207]	validation_0-rmse:13.4582
# [21:51:44] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=5
# [208]	validation_0-rmse:13.458
# [21:51:44] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [209]	validation_0-rmse:13.4434
# [21:51:44] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [210]	validation_0-rmse:13.426
# [21:51:44] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [211]	validation_0-rmse:13.4157
# [21:51:44] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=3
# [212]	validation_0-rmse:13.376
# [21:51:44] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=4
# [213]	validation_0-rmse:13.3952
# [21:51:44] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 0 pruned nodes, max_depth=4
# [214]	validation_0-rmse:13.3618
# [21:51:44] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=4
# [215]	validation_0-rmse:13.3646
# [21:51:44] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=4
# [216]	validation_0-rmse:13.3581
# ...
# [927]	validation_0-rmse:13.1401
# [21:51:46] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 0 pruned nodes, max_depth=5
# [928]	validation_0-rmse:13.1401
# [21:51:46] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 0 pruned nodes, max_depth=4
# [929]	validation_0-rmse:13.1402
# [21:51:46] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=5
# [930]	validation_0-rmse:13.1401
# [21:51:46] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=4
# [931]	validation_0-rmse:13.1401
# [21:51:46] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [932]	validation_0-rmse:13.1399
# [21:51:46] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [933]	validation_0-rmse:13.1399
# [21:51:46] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=4
# [934]	validation_0-rmse:13.1398
# [21:51:46] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=4
# [935]	validation_0-rmse:13.1397
# [21:51:46] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=3
# [936]	validation_0-rmse:13.1399
# [21:51:46] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [937]	validation_0-rmse:13.1397
# [21:51:46] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [938]	validation_0-rmse:13.1398
# [21:51:46] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=4
# [939]	validation_0-rmse:13.1398
# [21:51:46] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 0 pruned nodes, max_depth=5
# [940]	validation_0-rmse:13.1398
# [21:51:46] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 0 pruned nodes, max_depth=5
# [941]	validation_0-rmse:13.1398
# [21:51:46] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 0 pruned nodes, max_depth=5
# [942]	validation_0-rmse:13.1397
# [21:51:46] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=4
# [943]	validation_0-rmse:13.1396
# [21:51:46] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=4
# [944]	validation_0-rmse:13.1394
# [21:51:46] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 0 pruned nodes, max_depth=5
# [945]	validation_0-rmse:13.1394
# [21:51:46] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=4
# [946]	validation_0-rmse:13.1396
# [21:51:46] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 0 pruned nodes, max_depth=5
# [947]	validation_0-rmse:13.1394
# [21:51:46] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=3
# [948]	validation_0-rmse:13.1394
# [21:51:46] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 0 pruned nodes, max_depth=5
# [949]	validation_0-rmse:13.1392
# [21:51:46] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=6
# [950]	validation_0-rmse:13.1392
# [21:51:46] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 0 pruned nodes, max_depth=4
# [951]	validation_0-rmse:13.1392
# [21:51:46] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [952]	validation_0-rmse:13.1391
# [21:51:46] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 0 pruned nodes, max_depth=5
# [953]	validation_0-rmse:13.139
# [21:51:46] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=4
# [954]	validation_0-rmse:13.1391
# [21:51:46] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 0 pruned nodes, max_depth=4
# [955]	validation_0-rmse:13.1389
# [21:51:46] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 0 pruned nodes, max_depth=5
# [956]	validation_0-rmse:13.1388
# [21:51:46] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [957]	validation_0-rmse:13.1386
# [21:51:46] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=5
# [958]	validation_0-rmse:13.1387
# [21:51:46] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 0 pruned nodes, max_depth=5
# [959]	validation_0-rmse:13.1384
# [21:51:46] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=4
# [960]	validation_0-rmse:13.1384
# [21:51:46] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 0 pruned nodes, max_depth=5
# [961]	validation_0-rmse:13.1384
# [21:51:46] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [962]	validation_0-rmse:13.1383
# [21:51:46] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [963]	validation_0-rmse:13.1382
# [21:51:46] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [964]	validation_0-rmse:13.1381
# [21:51:46] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=4
# [965]	validation_0-rmse:13.1384
# [21:51:46] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [966]	validation_0-rmse:13.1384
# [21:51:46] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [967]	validation_0-rmse:13.1384
# [21:51:46] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [968]	validation_0-rmse:13.1383
# [21:51:46] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=4
# [969]	validation_0-rmse:13.1382
# [21:51:46] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=4
# [970]	validation_0-rmse:13.1382
# [21:51:46] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 0 pruned nodes, max_depth=4
# [971]	validation_0-rmse:13.1384
# [21:51:46] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=4
# [972]	validation_0-rmse:13.1383
# [21:51:46] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [973]	validation_0-rmse:13.1383
# [21:51:46] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=4
# [974]	validation_0-rmse:13.1382
# [21:51:46] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [975]	validation_0-rmse:13.1383
# [21:51:46] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 0 pruned nodes, max_depth=5
# [976]	validation_0-rmse:13.1382
# [21:51:46] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=4
# [977]	validation_0-rmse:13.1381
# [21:51:46] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [978]	validation_0-rmse:13.1381
# [21:51:46] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=4
# [979]	validation_0-rmse:13.1382
# [21:51:46] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 0 pruned nodes, max_depth=5
# [980]	validation_0-rmse:13.1382
# [21:51:46] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [981]	validation_0-rmse:13.1381
# [21:51:47] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [982]	validation_0-rmse:13.1381
# [21:51:47] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [983]	validation_0-rmse:13.1382
# [21:51:47] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 0 pruned nodes, max_depth=5
# [984]	validation_0-rmse:13.1382
# [21:51:47] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=4
# [985]	validation_0-rmse:13.1382
# [21:51:47] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [986]	validation_0-rmse:13.1382
# [21:51:47] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 0 pruned nodes, max_depth=5
# [987]	validation_0-rmse:13.1385
# [21:51:47] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 0 pruned nodes, max_depth=5
# [988]	validation_0-rmse:13.1385
# [21:51:47] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [989]	validation_0-rmse:13.1385
# [21:51:47] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [990]	validation_0-rmse:13.1384
# [21:51:47] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [991]	validation_0-rmse:13.1384
# [21:51:47] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [992]	validation_0-rmse:13.1385
# [21:51:47] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [993]	validation_0-rmse:13.1385
# [21:51:47] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 0 pruned nodes, max_depth=5
# [994]	validation_0-rmse:13.1385
# [21:51:47] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [995]	validation_0-rmse:13.1381
# [21:51:47] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 0 pruned nodes, max_depth=4
# [996]	validation_0-rmse:13.138
# [21:51:47] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=4
# [997]	validation_0-rmse:13.1381
# [21:51:47] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [998]	validation_0-rmse:13.1381
# [21:51:47] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [999]	validation_0-rmse:13.1381
# Duration: 3.1754982471466064s

# %%
# Plot feature importance
figsize=(7,7)
fig, ax = plt.subplots(1,1,figsize=figsize)
plot_importance(model, ax=ax,height = 1)

# %%
# predict sales in test dataset
test_predictions = model.predict(X_test).flatten()

# scatter plot of True vs Predicted values
plt.scatter(y_test, test_predictions)
plt.xlabel('True Values $')
plt.ylabel('Predictions $')
plt.axis('equal')
plt.axis('square')
plt.xlim([100,plt.xlim()[1]])
plt.ylim([100,plt.ylim()[1]])
_ = plt.plot([0, 1000], [0, 1000])

# %%
# Histogram of error values
error = test_predictions - y_test
plt.hist(error, bins = 25)
plt.xlabel("Prediction Error $")
_ = plt.ylabel("Count")

# %% [markdown]
# # Anomaly detection approach
#
# Loss > Threshold ise = anomaly > bubble mi demek?

# %%
# Data normalization
scaler = MinMaxScaler(feature_range=(0, 1))
X_train = scaler.fit_transform(df_train[:-5]) # Healthy/normal data
X_test = scaler.fit_transform(df_train[-5:]) # Unhealthy/anomaly data

# %%
X_train.shape
# Out:
# (46, 11)

# %%
# Reshape for LSTM
X_train = X_train.reshape(X_train.shape[0], 1, X_train.shape[1])
X_test = X_test.reshape(X_test.shape[0], 1, X_test.shape[1])

# %%
# define the autoencoder network model
def autoencoder_model(X):
    inputs = Input(shape=(X.shape[1], X.shape[2]))
    L1 = LSTM(16, activation='relu', return_sequences=True, 
              kernel_regularizer=regularizers.l2(0.00))(inputs)
    L2 = LSTM(4, activation='relu', return_sequences=False)(L1)
    L3 = RepeatVector(X.shape[1])(L2)
    L4 = LSTM(4, activation='relu', return_sequences=True)(L3)
    L5 = LSTM(16, activation='relu', return_sequences=True)(L4)
    output = TimeDistributed(Dense(X.shape[2]))(L5)    
    model = Model(inputs=inputs, outputs=output)
    return model

# %%
# create the autoencoder model
model = autoencoder_model(X_train)
model.compile(optimizer='adam', loss='mae')
model.summary()
# Out:
# WARNING:tensorflow:From /home/ipcvlab/anaconda2/envs/data_science/lib/python3.6/site-packages/tensorflow/python/ops/resource_variable_ops.py:435: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 1, 11)             0
# _________________________________________________________________
# lstm (LSTM)                  (None, 1, 16)             1792
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 4)                 336
# _________________________________________________________________
# repeat_vector (RepeatVector) (None, 1, 4)              0
# _________________________________________________________________
# lstm_2 (LSTM)                (None, 1, 4)              144
# _________________________________________________________________
# lstm_3 (LSTM)                (None, 1, 16)             1344
# _________________________________________________________________
# time_distributed (TimeDistri (None, 1, 11)             187
# =================================================================
# Total params: 3,803
# Trainable params: 3,803
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = model.fit(X_train, X_train, epochs=100, batch_size=10,
                    validation_split=0.05).history
# Out:
# Train on 43 samples, validate on 3 samples
# WARNING:tensorflow:From /home/ipcvlab/anaconda2/envs/data_science/lib/python3.6/site-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Epoch 1/100
# 43/43 [==============================] - 5s 119ms/sample - loss: 0.3450 - val_loss: 0.7599
# Epoch 2/100
# 43/43 [==============================] - 0s 1ms/sample - loss: 0.3397 - val_loss: 0.7541
# Epoch 3/100
# 43/43 [==============================] - 0s 1ms/sample - loss: 0.3344 - val_loss: 0.7482
# Epoch 4/100
# 43/43 [==============================] - 0s 1ms/sample - loss: 0.3292 - val_loss: 0.7422
# Epoch 5/100
# 43/43 [==============================] - 0s 2ms/sample - loss: 0.3239 - val_loss: 0.7361
# Epoch 6/100
# 43/43 [==============================] - 0s 2ms/sample - loss: 0.3186 - val_loss: 0.7299
# Epoch 7/100
# 43/43 [==============================] - 0s 1ms/sample - loss: 0.3134 - val_loss: 0.7234
# Epoch 8/100
# 43/43 [==============================] - 0s 1ms/sample - loss: 0.3080 - val_loss: 0.7167
# Epoch 9/100
# 43/43 [==============================] - 0s 7ms/sample - loss: 0.3026 - val_loss: 0.7099
# Epoch 10/100
# 43/43 [==============================] - 0s 2ms/sample - loss: 0.2975 - val_loss: 0.7030
# Epoch 11/100
# 43/43 [==============================] - 0s 2ms/sample - loss: 0.2923 - val_loss: 0.6960
# Epoch 12/100
# 43/43 [==============================] - 0s 2ms/sample - loss: 0.2875 - val_loss: 0.6886
# Epoch 13/100
# 43/43 [==============================] - 0s 2ms/sample - loss: 0.2823 - val_loss: 0.6814
# Epoch 14/100
# 43/43 [==============================] - 0s 2ms/sample - loss: 0.2774 - val_loss: 0.6737
# Epoch 15/100
# 43/43 [==============================] - 0s 2ms/sample - loss: 0.2724 - val_loss: 0.6661
# Epoch 16/100
# 43/43 [==============================] - 0s 2ms/sample - loss: 0.2676 - val_loss: 0.6580
# Epoch 17/100
# 43/43 [==============================] - 0s 2ms/sample - loss: 0.2624 - val_loss: 0.6500
# Epoch 18/100
# 43/43 [==============================] - 0s 2ms/sample - loss: 0.2577 - val_loss: 0.6416
# Epoch 19/100
# 43/43 [==============================] - 0s 2ms/sample - loss: 0.2528 - val_loss: 0.6318
# Epoch 20/100
# 43/43 [==============================] - 0s 2ms/sample - loss: 0.2482 - val_loss: 0.6201
# Epoch 21/100
# 43/43 [==============================] - 0s 2ms/sample - loss: 0.2433 - val_loss: 0.6062
# Epoch 22/100
# 43/43 [==============================] - 0s 2ms/sample - loss: 0.2382 - val_loss: 0.5900
# Epoch 23/100
# 43/43 [==============================] - 0s 2ms/sample - loss: 0.2336 - val_loss: 0.5702
# Epoch 24/100
# 43/43 [==============================] - 0s 2ms/sample - loss: 0.2280 - val_loss: 0.5477
# Epoch 25/100
# 43/43 [==============================] - 0s 2ms/sample - loss: 0.2226 - val_loss: 0.5169
# Epoch 26/100
# 43/43 [==============================] - 0s 2ms/sample - loss: 0.2168 - val_loss: 0.4697
# Epoch 27/100
# 43/43 [==============================] - 0s 2ms/sample - loss: 0.2103 - val_loss: 0.3970
# Epoch 28/100
# 43/43 [==============================] - 0s 3ms/sample - loss: 0.2019 - val_loss: 0.3110
# Epoch 29/100
# 43/43 [==============================] - 0s 2ms/sample - loss: 0.1943 - val_loss: 0.2688
# Epoch 30/100
# 43/43 [==============================] - 0s 2ms/sample - loss: 0.1861 - val_loss: 0.3633
# Epoch 31/100
# 43/43 [==============================] - 0s 2ms/sample - loss: 0.1769 - val_loss: 0.5918
# Epoch 32/100
# 43/43 [==============================] - 0s 7ms/sample - loss: 0.1750 - val_loss: 0.5680
# Epoch 33/100
# 43/43 [==============================] - 0s 2ms/sample - loss: 0.1658 - val_loss: 0.4142
# Epoch 34/100
# 43/43 [==============================] - 0s 2ms/sample - loss: 0.1620 - val_loss: 0.3649
# Epoch 35/100
# 43/43 [==============================] - 0s 2ms/sample - loss: 0.1585 - val_loss: 0.4169
# Epoch 36/100
# 43/43 [==============================] - 0s 2ms/sample - loss: 0.1541 - val_loss: 0.5339
# Epoch 37/100
# 43/43 [==============================] - 0s 2ms/sample - loss: 0.1520 - val_loss: 0.5824
# Epoch 38/100
# 43/43 [==============================] - 0s 2ms/sample - loss: 0.1500 - val_loss: 0.5290
# Epoch 39/100
# 43/43 [==============================] - 0s 2ms/sample - loss: 0.1466 - val_loss: 0.4698
# Epoch 40/100
# 43/43 [==============================] - 0s 2ms/sample - loss: 0.1442 - val_loss: 0.4487
# Epoch 41/100
# 43/43 [==============================] - 0s 1ms/sample - loss: 0.1427 - val_loss: 0.4486
# Epoch 42/100
# 43/43 [==============================] - 0s 2ms/sample - loss: 0.1410 - val_loss: 0.4622
# Epoch 43/100
# 43/43 [==============================] - 0s 2ms/sample - loss: 0.1397 - val_loss: 0.4848
# Epoch 44/100
# 43/43 [==============================] - 0s 2ms/sample - loss: 0.1397 - val_loss: 0.4809
# Epoch 45/100
# 43/43 [==============================] - 0s 2ms/sample - loss: 0.1374 - val_loss: 0.3819
# Epoch 46/100
# 43/43 [==============================] - 0s 2ms/sample - loss: 0.1368 - val_loss: 0.3760
# Epoch 47/100
# 43/43 [==============================] - 0s 2ms/sample - loss: 0.1348 - val_loss: 0.3958
# Epoch 48/100
# 43/43 [==============================] - 0s 2ms/sample - loss: 0.1333 - val_loss: 0.4069
# Epoch 49/100
# 43/43 [==============================] - 0s 2ms/sample - loss: 0.1324 - val_loss: 0.3859
# Epoch 50/100
# 43/43 [==============================] - 0s 2ms/sample - loss: 0.1312 - val_loss: 0.3413
# Epoch 51/100
# 43/43 [==============================] - 0s 2ms/sample - loss: 0.1309 - val_loss: 0.3354
# Epoch 52/100
# 43/43 [==============================] - 0s 2ms/sample - loss: 0.1300 - val_loss: 0.3535
# Epoch 53/100
# 43/43 [==============================] - 0s 2ms/sample - loss: 0.1278 - val_loss: 0.3512
# Epoch 54/100
# 43/43 [==============================] - 0s 7ms/sample - loss: 0.1271 - val_loss: 0.3557
# Epoch 55/100
# 43/43 [==============================] - 0s 2ms/sample - loss: 0.1262 - val_loss: 0.3381
# Epoch 56/100
# 43/43 [==============================] - 0s 3ms/sample - loss: 0.1249 - val_loss: 0.3394
# Epoch 57/100
# 43/43 [==============================] - 0s 2ms/sample - loss: 0.1241 - val_loss: 0.3350
# Epoch 58/100
# 43/43 [==============================] - 0s 3ms/sample - loss: 0.1234 - val_loss: 0.3109
# Epoch 59/100
# 43/43 [==============================] - 0s 3ms/sample - loss: 0.1220 - val_loss: 0.3217
# Epoch 60/100
# 43/43 [==============================] - 0s 2ms/sample - loss: 0.1207 - val_loss: 0.3175
# Epoch 61/100
# 43/43 [==============================] - 0s 3ms/sample - loss: 0.1198 - val_loss: 0.3030
# Epoch 62/100
# 43/43 [==============================] - 0s 2ms/sample - loss: 0.1185 - val_loss: 0.2961
# Epoch 63/100
# 43/43 [==============================] - 0s 2ms/sample - loss: 0.1173 - val_loss: 0.2858
# Epoch 64/100
# 43/43 [==============================] - 0s 2ms/sample - loss: 0.1161 - val_loss: 0.2875
# Epoch 65/100
# 43/43 [==============================] - 0s 2ms/sample - loss: 0.1150 - val_loss: 0.2917
# Epoch 66/100
# 43/43 [==============================] - 0s 2ms/sample - loss: 0.1146 - val_loss: 0.2907
# Epoch 67/100
# 43/43 [==============================] - 0s 2ms/sample - loss: 0.1129 - val_loss: 0.2690
# Epoch 68/100
# 43/43 [==============================] - 0s 3ms/sample - loss: 0.1123 - val_loss: 0.2681
# Epoch 69/100
# 43/43 [==============================] - 0s 2ms/sample - loss: 0.1111 - val_loss: 0.2802
# Epoch 70/100
# 43/43 [==============================] - 0s 2ms/sample - loss: 0.1102 - val_loss: 0.2673
# Epoch 71/100
# 43/43 [==============================] - 0s 2ms/sample - loss: 0.1088 - val_loss: 0.2616
# Epoch 72/100
# 43/43 [==============================] - 0s 2ms/sample - loss: 0.1076 - val_loss: 0.2606
# Epoch 73/100
# 43/43 [==============================] - 0s 2ms/sample - loss: 0.1065 - val_loss: 0.2628
# Epoch 74/100
# 43/43 [==============================] - 0s 2ms/sample - loss: 0.1054 - val_loss: 0.2611
# Epoch 75/100
# 43/43 [==============================] - 0s 7ms/sample - loss: 0.1043 - val_loss: 0.2589
# Epoch 76/100
# 43/43 [==============================] - 0s 2ms/sample - loss: 0.1033 - val_loss: 0.2573
# Epoch 77/100
# 43/43 [==============================] - 0s 1ms/sample - loss: 0.1024 - val_loss: 0.2521
# Epoch 78/100
# 43/43 [==============================] - 0s 2ms/sample - loss: 0.1014 - val_loss: 0.2522
# Epoch 79/100
# 43/43 [==============================] - 0s 2ms/sample - loss: 0.1004 - val_loss: 0.2517
# Epoch 80/100
# 43/43 [==============================] - 0s 2ms/sample - loss: 0.0996 - val_loss: 0.2506
# Epoch 81/100
# 43/43 [==============================] - 0s 2ms/sample - loss: 0.0988 - val_loss: 0.2473
# Epoch 82/100
# 43/43 [==============================] - 0s 2ms/sample - loss: 0.0982 - val_loss: 0.2480
# Epoch 83/100
# 43/43 [==============================] - 0s 2ms/sample - loss: 0.0974 - val_loss: 0.2484
# Epoch 84/100
# 43/43 [==============================] - 0s 2ms/sample - loss: 0.0971 - val_loss: 0.2509
# Epoch 85/100
# 43/43 [==============================] - 0s 2ms/sample - loss: 0.0965 - val_loss: 0.2503
# Epoch 86/100
# 43/43 [==============================] - 0s 2ms/sample - loss: 0.0958 - val_loss: 0.2468
# Epoch 87/100
# 43/43 [==============================] - 0s 2ms/sample - loss: 0.0956 - val_loss: 0.2450
# Epoch 88/100
# 43/43 [==============================] - 0s 2ms/sample - loss: 0.0952 - val_loss: 0.2455
# Epoch 89/100
# 43/43 [==============================] - 0s 2ms/sample - loss: 0.0945 - val_loss: 0.2494
# Epoch 90/100
# 43/43 [==============================] - 0s 2ms/sample - loss: 0.0940 - val_loss: 0.2504
# Epoch 91/100
# 43/43 [==============================] - 0s 2ms/sample - loss: 0.0936 - val_loss: 0.2512
# Epoch 92/100
# 43/43 [==============================] - 0s 2ms/sample - loss: 0.0932 - val_loss: 0.2504
# Epoch 93/100
# 43/43 [==============================] - 0s 1ms/sample - loss: 0.0929 - val_loss: 0.2533
# Epoch 94/100
# 43/43 [==============================] - 0s 1ms/sample - loss: 0.0924 - val_loss: 0.2567
# Epoch 95/100
# 43/43 [==============================] - 0s 1ms/sample - loss: 0.0921 - val_loss: 0.2576
# Epoch 96/100
# 43/43 [==============================] - 0s 1ms/sample - loss: 0.0918 - val_loss: 0.2590
# Epoch 97/100
# 43/43 [==============================] - 0s 1ms/sample - loss: 0.0915 - val_loss: 0.2574
# Epoch 98/100
# 43/43 [==============================] - 0s 1ms/sample - loss: 0.0912 - val_loss: 0.2585
# Epoch 99/100
# 43/43 [==============================] - 0s 1ms/sample - loss: 0.0908 - val_loss: 0.2571
# Epoch 100/100
# 43/43 [==============================] - 0s 2ms/sample - loss: 0.0905 - val_loss: 0.2561

# %%
# plot the training losses
fig, ax = plt.subplots(figsize=(14, 6), dpi=80)
ax.plot(history['loss'], 'b', label='Train', linewidth=2)
ax.plot(history['val_loss'], 'r', label='Validation', linewidth=2)
ax.set_title('Model loss', fontsize=16)
ax.set_ylabel('Loss (mae)')
ax.set_xlabel('Epoch')
ax.legend(loc='upper right')
plt.show()

# %%
# plot the loss distribution of the training set
X_pred = model.predict(X_train)
X_pred = X_pred.reshape(X_pred.shape[0], X_pred.shape[2])
X_pred = pd.DataFrame(X_pred, columns=df_train.columns)
X_pred.index = df_train[:-5].index

scored = pd.DataFrame(index=df_train[:-5].index)
Xtrain = X_train.reshape(X_train.shape[0], X_train.shape[2])
scored['Loss_mae'] = np.mean(np.abs(X_pred-Xtrain), axis = 1)
plt.figure(figsize=(16,9), dpi=80)
plt.title('Loss Distribution', fontsize=16)
sns.distplot(scored['Loss_mae'], bins = 20, kde= True, color = 'blue');
plt.xlim([0.0,.5])

#Out[17]:
#(0.0, 0.5)
# Out:
# (0.0, 0.5)

# %%
# calculate the loss on the test set
X_pred = model.predict(X_test)
X_pred = X_pred.reshape(X_pred.shape[0], X_pred.shape[2])
X_pred = pd.DataFrame(X_pred, columns=df_train.columns)
X_pred.index = df_train[-5:].index

scored = pd.DataFrame(index=df_train[-5:].index)
Xtest = X_test.reshape(X_test.shape[0], X_test.shape[2])
scored['Loss_mae'] = np.mean(np.abs(X_pred-Xtest), axis = 1)
scored['Threshold'] = 0.2
scored['Anomaly'] = scored['Loss_mae'] > scored['Threshold']
scored.head()
# Out:
#          Loss_mae  Threshold  Anomaly
# Tarih
# 2018-12  0.286887        0.2     True
# 2019-03  0.295380        0.2     True
# 2019-06  0.432345        0.2     True
# 2019-09  0.325382        0.2     True
# 2019-12  0.240115        0.2     True

# %%
# calculate the same metrics for the training set 
# and merge all data in a single dataframe for plotting
X_pred_train = model.predict(X_train)
X_pred_train = X_pred_train.reshape(X_pred_train.shape[0], X_pred_train.shape[2])
X_pred_train = pd.DataFrame(X_pred_train, columns=df_train[:-5].columns)
X_pred_train.index = df_train[:-5].index

scored_train = pd.DataFrame(index=df_train[:-5].index)
scored_train['Loss_mae'] = np.mean(np.abs(X_pred_train-Xtrain), axis = 1)
scored_train['Threshold'] = 0.2
scored_train['Anomaly'] = scored_train['Loss_mae'] > scored_train['Threshold']
scored = pd.concat([scored_train, scored])
scored
scored.to_csv("/home/ipcvlab/Desktop/output.csv")

# %%
# plot bearing failure time plot
scored.plot(logy=True,  figsize=(16,9), ylim=[1e-2,1e2], color=['blue','red'])
