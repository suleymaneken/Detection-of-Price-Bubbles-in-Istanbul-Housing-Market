# %%
import time
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

#plotting
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
sns.set_style("whitegrid")

# %%
from sklearn.model_selection import KFold, GridSearchCV, cross_val_score, train_test_split # Model evaluation
from sklearn.preprocessing import MinMaxScaler # Data normalization
from xgboost import XGBRegressor, DMatrix, plot_importance # XGBoost

# %%
# pip install tensorflow==2
import tensorflow as tf
from tensorflow.keras.layers import Input, Dropout, Dense, LSTM, TimeDistributed, RepeatVector
from tensorflow.keras.models import Model
from tensorflow.keras import regularizers
# Out:
# /home/ipcvlab/anaconda2/envs/data_science/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /home/ipcvlab/anaconda2/envs/data_science/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /home/ipcvlab/anaconda2/envs/data_science/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:528: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /home/ipcvlab/anaconda2/envs/data_science/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:529: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /home/ipcvlab/anaconda2/envs/data_science/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:530: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /home/ipcvlab/anaconda2/envs/data_science/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:535: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %%
df_train = pd.read_excel("/home/ipcvlab/Downloads/ilceler/v3_sisikEv/ceyrek-full-sütun/istanbul_ceyrek_tum_veriler.xlsx", index_col = 0) 
cols_list = list(df_train.columns)

# %%
df_train.head()
# Out:
#          HousingSaleIndex      BIST  USD/TRY  MonthlyDepositInterest  \
# Date
# 2007-06            100.00  47093.67   1.3215                   17.59
# 2007-09            102.20  54044.22   1.2674                   17.34
# 2007-12            102.80  55538.13   1.1786                   16.35
# 2008-03            102.30  39015.44   1.2383                   15.78
# 2008-06             97.44  35089.53   1.2337                   16.75
#
#          MortgageInterestRates   GDDS  ConsumerPriceIndex  \
# Date
# 2007-06                  18.03  18.42              139.69
# 2007-09                  17.58  18.25              140.13
# 2007-12                  16.53  16.54              145.77
# 2008-03                  17.28  17.59              150.27
# 2008-06                  17.60  21.54              154.51
#
#          ConsumerConfidenceIndex  BuildingConstructionCostIndex    GDP  \
# Date
# 2007-06                    80.95                          59.70  67.48
# 2007-09                    83.89                          59.77  66.52
# 2007-12                    80.67                          60.09  69.90
# 2008-03                    68.74                          65.89  72.71
# 2008-06                    61.79                          73.01  69.04
#
#          HousingRentIndex
# Date
# 2007-06            100.00
# 2007-09            100.60
# 2007-12            101.90
# 2008-03            102.20
# 2008-06             97.72

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 51 entries, 2007-06 to 2019-12
# Data columns (total 11 columns):
# HousingSaleIndex                 51 non-null float64
# BIST                             51 non-null float64
# USD/TRY                          51 non-null float64
# MonthlyDepositInterest           51 non-null float64
# MortgageInterestRates            51 non-null float64
# GDDS                             51 non-null float64
# ConsumerPriceIndex               51 non-null float64
# ConsumerConfidenceIndex          51 non-null float64
# BuildingConstructionCostIndex    51 non-null float64
# GDP                              51 non-null float64
# HousingRentIndex                 51 non-null float64
# dtypes: float64(11)
# memory usage: 4.8+ KB

# %%
df_train.describe()
# Out:
#        HousingSaleIndex           BIST    USD/TRY  MonthlyDepositInterest  \
# count         51.000000      51.000000  51.000000               51.000000
# mean         175.265490   71876.040784   2.611547               10.961569
# std           78.907248   22471.523840   1.422405                4.433174
# min           83.170000   25764.830000   1.178600                5.390000
# 25%          100.900000   56038.250000   1.562550                7.720000
# 50%          151.900000   74205.470000   2.020800                9.270000
# 75%          256.800000   85810.060000   3.241200               12.815000
# max          295.600000  115333.010000   6.378300               22.170000
#
#        MortgageInterestRates       GDDS  ConsumerPriceIndex  \
# count              51.000000  51.000000           51.000000
# mean               13.941569  12.201765          244.600000
# std                 4.025200   4.638079           82.739765
# min                 8.300000   5.770000          139.690000
# 25%                11.180000   9.045000          178.345000
# 50%                12.870000  10.340000          223.910000
# 75%                15.560000  14.810000          287.405000
# max                27.820000  25.270000          440.500000
#
#        ConsumerConfidenceIndex  BuildingConstructionCostIndex         GDP  \
# count                51.000000                      51.000000   51.000000
# mean                 70.168235                     100.841961   89.811373
# std                   7.519964                      39.499889   17.741740
# min                  55.140000                      59.700000   63.610000
# 25%                  65.345000                      69.635000   72.265000
# 50%                  71.310000                      86.570000   90.900000
# 75%                  74.940000                     115.490000  104.940000
# max                  83.890000                     193.770000  117.530000
#
#        HousingRentIndex
# count         51.000000
# mean         148.744314
# std           52.189168
# min           86.210000
# 25%           98.860000
# 50%          135.500000
# 75%          208.700000
# max          228.300000

# %% [markdown]
# ### display Missing values

# %%
label_nas = []
for col in df_train.columns.tolist():
    if np.sum(df_train[col].isnull() ) != 0:
        label_nas.append(col)
    else:
        label_nas.append("")

plt.figure(figsize=(12,7))
plt.suptitle('Missing Values in the Training Set')
sns.heatmap(df_train.isnull(), yticklabels=False, xticklabels=label_nas ,cbar = False, cmap='viridis')
plt.show()

# %%
replace = True # True: replace null in guven_endeksi with average. False: guven_endeksi kullanmadan
if replace:
    df_train = df_train.fillna(df_train.mean())
else:
    df_train.drop('ConsumerConfidenceIndex', axis=1, inplace=True)

# %%
# Correlation matrix
corr_mat = df_train.corr().abs()
# Find most important features relative to target
corr_mat.sort_values(by=["HousingSaleIndex"], ascending = False, inplace = True)
print(corr_mat.HousingSaleIndex)
# Out:
# HousingSaleIndex                 1.000000
# HousingRentIndex                 0.996663
# GDP                              0.977458
# ConsumerPriceIndex               0.938681
# BuildingConstructionCostIndex    0.906560
# USD/TRY                          0.895967
# BIST                             0.874981
# ConsumerConfidenceIndex          0.532446
# MonthlyDepositInterest           0.264804
# GDDS                             0.222637
# MortgageInterestRates            0.141718
# Name: HousingSaleIndex, dtype: float64

# %%
#Correlation matrix between features
corr_mat = df_train.corr().abs()

# %%
#Plot the heatmap with seaborn
plt.figure(figsize=(7,7)) 

mask = np.zeros_like(corr_mat)
mask[np.triu_indices_from(mask)] = True

sns.heatmap(corr_mat, mask=mask,
        xticklabels=corr_mat.columns,
        yticklabels=corr_mat.columns)

# %%
#List the highly correlated columns
corr_tmp = corr_mat.unstack()
corr_tmp = corr_tmp.sort_values(kind="quicksort")

print(corr_tmp[-len(corr_mat)-10:-len(corr_mat)])
# Out:
# ConsumerPriceIndex             USD/TRY                          0.976848
# USD/TRY                        ConsumerPriceIndex               0.976848
# GDP                            HousingSaleIndex                 0.977458
# HousingSaleIndex               GDP                              0.977458
# BuildingConstructionCostIndex  USD/TRY                          0.988005
# USD/TRY                        BuildingConstructionCostIndex    0.988005
# ConsumerPriceIndex             BuildingConstructionCostIndex    0.988033
# BuildingConstructionCostIndex  ConsumerPriceIndex               0.988033
# HousingRentIndex               HousingSaleIndex                 0.996663
# HousingSaleIndex               HousingRentIndex                 0.996663
# dtype: float64

# %%
# Find most important features relative to target
corr_mat.sort_values(["HousingSaleIndex"], ascending = False, inplace = True)
print(corr_mat.HousingSaleIndex)
# Out:
# HousingSaleIndex                 1.000000
# HousingRentIndex                 0.996663
# GDP                              0.977458
# ConsumerPriceIndex               0.938681
# BuildingConstructionCostIndex    0.906560
# USD/TRY                          0.895967
# BIST                             0.874981
# ConsumerConfidenceIndex          0.532446
# MonthlyDepositInterest           0.264804
# GDDS                             0.222637
# MortgageInterestRates            0.141718
# Name: HousingSaleIndex, dtype: float64

# %% [markdown]
# # Skewness

# %%
#Check the skewness of HouseEndeks
for col in cols_list:
    plt.figure(figsize=(10, 5))
    skewness = df_train[col].skew()
    df_train[col].plot.hist(edgecolor='white', bins=30, 
                                    label=col + ' skew =' + str(round(skewness,2)))
    plt.suptitle("{} distribution".format(col))
    plt.legend()
    plt.show()

# %% [markdown]
# # Box plots

# %%
for col in cols_list:
    plt.figure(figsize=(10, 5))
    # Create the boxplot
    ax = sns.boxplot(x=col, data=df_train)
    # Set the `xlim`
    #ax.set(xlim=(0, 100))
    # Add title
    ax.set_title(col)
    # Show the plot
    plt.show()

# %%
for col in cols_list:    
    y_axis = col
    count = df_train[y_axis].count()
    value=df_train[y_axis]

    plt.figure(figsize=(10, 5))
    sns.regplot(np.linspace(0, count, count), df_train[y_axis], fit_reg=True,
                scatter_kws={'facecolors':np.where( value==True , "red", 'darkviolet'),
               'edgecolor':np.where(value==True , "red", 'darkviolet')},
               line_kws = {'color': 'darkblue'})
    plt.title(col, fontsize=24)
    plt.xlabel('-', fontsize=18)
    plt.ylabel(col, fontsize=18)
    # plt.savefig('figures/Standardised_SalePrice_GrLivArea.png')

# %% [markdown]
# # HouseEndex vs other

# %% [markdown]
# - Kirmizi: bubble fiyatlari iceren regresyon cizgi
# - Mavi: bubble fiyatlari iceren regresyon cizgi
#
# mavi ve kirmizi cizgi arasinda buyuk bir fark varsa, bubble/anomaly mi demek?

# %%
# Displays A Scatter Plot with Regression Line + Outliers in Red

for col in cols_list:
    x_axis = col
    y_axis = 'HousingSaleIndex'
    value=(df_train[y_axis] > 107)
    value2=(df_train[y_axis][:-15] > 107)

    plt.figure(figsize=(10, 5))
    sns.regplot(df_train[x_axis], df_train[y_axis], fit_reg=True,
                scatter_kws={'facecolors':np.where( value==True , "red", 'darkviolet'),
               'edgecolor':np.where(value==True , "red", 'darkviolet')},
               line_kws = {'color': 'darkred'})
    
    sns.regplot(df_train[x_axis][:-15], df_train[y_axis][:-15], fit_reg=True,
                scatter_kws={'facecolors':np.where( value2==True , "red", 'darkviolet'),
               'edgecolor':np.where(value2==True , "red", 'darkviolet')},
               line_kws = {'color': 'darkblue'})
    
    plt.title('HousingSaleIndex vs. {}'.format(x_axis), fontsize=24)
    plt.xlabel(x_axis, fontsize=18)
    plt.ylabel('HousingSaleIndex', fontsize=18)
    # plt.savefig('figures/Standardised_SalePrice_GrLivArea.png')

# %% [markdown]
# # XGBoost
#
# hiç faydası yok bu konuda, eğitimde kullandığımız verileri göre sonuç veriyor, ama şişik olup olmadığını gösteremez

# %%
#y_full = df_train['HouseEndex']
#X_full = df_train.drop(columns=["HouseEndex"])

y_full = df_train['HousingSaleIndex'][:-5]
X_full = df_train.drop(columns=["HousingSaleIndex"])[:-5]

y_test = df_train['HousingSaleIndex'][-5:]
X_test = df_train.drop(columns=["HousingSaleIndex"])[-5:]

X_train, X_val, y_train, y_val = train_test_split(X_full, y_full, test_size=0.2, random_state=123)

# %%
# final model with tuned parameters
model = XGBRegressor(max_depth=6, #dflt 6
                     learning_rate=0.1, #dflt 100
                     n_estimators=1000, #dflt 0.1
                     verbosity = 3,
                     objective='reg:linear',
                     n_jobs=-1,
                     gamma=0, #dflt: 0
                     min_child_weight=3, #0 dflt: 1
                     subsample=0.5,
                     colsample_bytree=1,
                     reg_lambda=0.99994, #dflt: 1
                     reg_alpha=0.00003, #dflt: 0
                     tree_method='exact',
                     scale_pos_weight=1, # dflt: 1
                     random_state=123)

# %%
tick=time.time()

fitted_model = model.fit(X_train, y_train,
                         eval_set=[(X_val, y_val)],
                         eval_metric='rmse', # Equivalent to RMSLE since we have log1p(SalePrice)
                         early_stopping_rounds=1000,
                         verbose=True)

print("Duration: {}s".format(time.time()-tick))
# Out:
# [14:27:16] WARNING: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [14:27:16] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 2 extra nodes, 0 pruned nodes, max_depth=1
# [0]	validation_0-rmse:109.152
# Will train until validation_0-rmse hasn't improved in 1000 rounds.
# [14:27:16] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 2 extra nodes, 0 pruned nodes, max_depth=1
# [1]	validation_0-rmse:100.318
# [14:27:17] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 2 extra nodes, 0 pruned nodes, max_depth=1
# [2]	validation_0-rmse:92.2872
# [14:27:17] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 2 extra nodes, 0 pruned nodes, max_depth=1
# [3]	validation_0-rmse:82.5958
# [14:27:17] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 2 extra nodes, 0 pruned nodes, max_depth=1
# [4]	validation_0-rmse:73.6315
# [14:27:17] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 2 extra nodes, 0 pruned nodes, max_depth=1
# [5]	validation_0-rmse:67.8991
# [14:27:17] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 2 extra nodes, 0 pruned nodes, max_depth=1
# [6]	validation_0-rmse:60.7802
# [14:27:17] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 2 extra nodes, 0 pruned nodes, max_depth=1
# [7]	validation_0-rmse:54.5047
# [14:27:17] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 2 extra nodes, 0 pruned nodes, max_depth=1
# [8]	validation_0-rmse:48.1734
# [14:27:17] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [9]	validation_0-rmse:44.3692
# [14:27:17] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [10]	validation_0-rmse:39.6231
# [14:27:17] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 2 extra nodes, 0 pruned nodes, max_depth=1
# [11]	validation_0-rmse:35.1622
# [14:27:17] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [12]	validation_0-rmse:32.1423
# [14:27:17] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [13]	validation_0-rmse:29.1298
# [14:27:17] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [14]	validation_0-rmse:27.1158
# [14:27:17] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [15]	validation_0-rmse:25.3297
# [14:27:17] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 2 extra nodes, 0 pruned nodes, max_depth=1
# [16]	validation_0-rmse:22.9603
# [14:27:17] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [17]	validation_0-rmse:21.3281
# [14:27:17] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 2 extra nodes, 0 pruned nodes, max_depth=1
# [18]	validation_0-rmse:19.2294
# [14:27:17] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 2 extra nodes, 0 pruned nodes, max_depth=1
# [19]	validation_0-rmse:17.0868
# [14:27:17] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [20]	validation_0-rmse:15.0278
# [14:27:17] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [21]	validation_0-rmse:13.9325
# [14:27:17] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [22]	validation_0-rmse:12.8297
# [14:27:17] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [23]	validation_0-rmse:12.4326
# [14:27:17] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [24]	validation_0-rmse:11.7281
# [14:27:17] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [25]	validation_0-rmse:10.7572
# [14:27:17] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=3
# [26]	validation_0-rmse:10.1283
# [14:27:17] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [27]	validation_0-rmse:9.53135
# [14:27:17] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=3
# [28]	validation_0-rmse:8.99996
# /home/ipcvlab/anaconda2/envs/data_science/lib/python3.6/site-packages/xgboost/core.py:587: FutureWarning: Series.base is deprecated and will be removed in a future version
#   if getattr(data, 'base', None) is not None and \
# [14:27:17] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [29]	validation_0-rmse:8.68873
# [14:27:17] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [30]	validation_0-rmse:8.15609
# [14:27:17] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=4
# [31]	validation_0-rmse:8.00765
# [14:27:17] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [32]	validation_0-rmse:7.65596
# [14:27:17] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [33]	validation_0-rmse:7.49591
# [14:27:17] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [34]	validation_0-rmse:7.18019
# [14:27:17] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 0 pruned nodes, max_depth=4
# [35]	validation_0-rmse:6.95045
# [14:27:17] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [36]	validation_0-rmse:6.49828
# [14:27:17] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [37]	validation_0-rmse:6.1299
# [14:27:17] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [38]	validation_0-rmse:5.97108
# [14:27:17] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=3
# [39]	validation_0-rmse:5.86461
# [14:27:17] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [40]	validation_0-rmse:5.83957
# [14:27:17] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [41]	validation_0-rmse:5.88937
# [14:27:17] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=4
# [42]	validation_0-rmse:5.90299
# [14:27:17] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [43]	validation_0-rmse:5.81809
# [14:27:17] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=3
# [44]	validation_0-rmse:5.68956
# [14:27:17] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=4
# [45]	validation_0-rmse:5.48009
# [14:27:17] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=3
# [46]	validation_0-rmse:5.49902
# [14:27:17] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [47]	validation_0-rmse:5.43798
# [14:27:17] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 0 pruned nodes, max_depth=4
# [48]	validation_0-rmse:5.36121
# [14:27:17] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [49]	validation_0-rmse:5.40177
# [14:27:17] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [50]	validation_0-rmse:5.37756
# [14:27:17] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=4
# [51]	validation_0-rmse:5.42695
# [14:27:17] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [52]	validation_0-rmse:5.36417
# [14:27:17] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [53]	validation_0-rmse:5.368
# [14:27:17] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=4
# [54]	validation_0-rmse:5.41203
# [14:27:17] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [55]	validation_0-rmse:5.35204
# [14:27:17] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=3
# [56]	validation_0-rmse:5.23897
# [14:27:17] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=4
# [57]	validation_0-rmse:5.26564
# [14:27:17] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 0 pruned nodes, max_depth=4
# [58]	validation_0-rmse:5.15227
# [14:27:17] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [59]	validation_0-rmse:5.20497
# [14:27:17] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 0 pruned nodes, max_depth=4
# [60]	validation_0-rmse:5.18281
# [14:27:17] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [61]	validation_0-rmse:5.19555
# [14:27:17] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 0 pruned nodes, max_depth=4
# [62]	validation_0-rmse:5.08785
# [14:27:17] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [63]	validation_0-rmse:5.10406
# [14:27:17] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=3
# [64]	validation_0-rmse:5.02694
# [14:27:17] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=3
# [65]	validation_0-rmse:5.03055
# [14:27:17] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=4
# [66]	validation_0-rmse:5.01488
# [14:27:17] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [67]	validation_0-rmse:4.98252
# [14:27:17] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [68]	validation_0-rmse:4.88662
# [14:27:17] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=4
# [69]	validation_0-rmse:4.90276
# [14:27:17] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=4
# [70]	validation_0-rmse:4.8356
# [14:27:17] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [71]	validation_0-rmse:4.80633
# [14:27:17] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [72]	validation_0-rmse:4.77065
# [14:27:17] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 0 pruned nodes, max_depth=4
# [73]	validation_0-rmse:4.76292
# [14:27:17] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=4
# [74]	validation_0-rmse:4.76208
# [14:27:17] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [75]	validation_0-rmse:4.78457
# [14:27:17] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=3
# [76]	validation_0-rmse:4.8995
# [14:27:17] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 0 pruned nodes, max_depth=4
# [77]	validation_0-rmse:4.93074
# [14:27:17] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 0 pruned nodes, max_depth=5
# [78]	validation_0-rmse:4.93944
# [14:27:17] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [79]	validation_0-rmse:4.89821
# [14:27:17] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [80]	validation_0-rmse:4.91341
# [14:27:17] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=3
# [81]	validation_0-rmse:4.93496
# [14:27:17] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [82]	validation_0-rmse:4.9817
# [14:27:17] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [83]	validation_0-rmse:4.98519
# [14:27:17] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [84]	validation_0-rmse:5.01069
# [14:27:17] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [85]	validation_0-rmse:4.99231
# [14:27:17] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=4
# [86]	validation_0-rmse:5.00193
# [14:27:17] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=4
# [87]	validation_0-rmse:5.02361
# [14:27:17] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 0 pruned nodes, max_depth=3
# [88]	validation_0-rmse:5.03446
# [14:27:17] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [89]	validation_0-rmse:5.00769
# [14:27:17] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [90]	validation_0-rmse:4.99338
# [14:27:17] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=3
# [91]	validation_0-rmse:5.07062
# [14:27:17] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [92]	validation_0-rmse:5.11556
# [14:27:17] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [93]	validation_0-rmse:5.16913
# [14:27:17] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=3
# [94]	validation_0-rmse:5.16657
# [14:27:17] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=4
# [95]	validation_0-rmse:5.18723
# [14:27:17] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=4
# [96]	validation_0-rmse:5.15145
# [14:27:17] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=3
# [97]	validation_0-rmse:5.15254
# [14:27:17] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=3
# [98]	validation_0-rmse:5.11415
# [14:27:17] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=4
# [99]	validation_0-rmse:5.08249
# [14:27:17] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=3
# [100]	validation_0-rmse:5.0301
# [14:27:17] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [101]	validation_0-rmse:5.01522
# [14:27:17] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 0 pruned nodes, max_depth=5
# [102]	validation_0-rmse:5.03047
# [14:27:17] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [103]	validation_0-rmse:5.04124
# [14:27:17] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [104]	validation_0-rmse:5.04237
# [14:27:17] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=3
# [105]	validation_0-rmse:5.05805
# [14:27:17] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=3
# [106]	validation_0-rmse:5.05114
# [14:27:17] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=4
# [107]	validation_0-rmse:5.05147
# [14:27:17] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=3
# [108]	validation_0-rmse:5.00757
# [14:27:17] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=4
# [109]	validation_0-rmse:5.00814
# [14:27:17] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=3
# [110]	validation_0-rmse:5.03606
# [14:27:17] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=4
# [111]	validation_0-rmse:5.06291
# [14:27:17] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [112]	validation_0-rmse:5.06694
# [14:27:17] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 0 pruned nodes, max_depth=5
# [113]	validation_0-rmse:5.09388
# [14:27:17] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [114]	validation_0-rmse:5.10783
# [14:27:17] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [115]	validation_0-rmse:5.11191
# [14:27:17] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [116]	validation_0-rmse:5.09289
# [14:27:17] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=4
# [117]	validation_0-rmse:5.09629
# [14:27:17] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [118]	validation_0-rmse:5.11134
# [14:27:17] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 0 pruned nodes, max_depth=4
# [119]	validation_0-rmse:5.10902
# [14:27:17] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [120]	validation_0-rmse:5.1042
# [14:27:17] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=4
# [121]	validation_0-rmse:5.09571
# [14:27:17] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=4
# [122]	validation_0-rmse:5.08688
# [14:27:17] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [123]	validation_0-rmse:5.08124
# [14:27:17] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [124]	validation_0-rmse:5.10798
# [14:27:17] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [125]	validation_0-rmse:5.07877
# [14:27:17] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=3
# [126]	validation_0-rmse:5.08879
# [14:27:17] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=3
# [127]	validation_0-rmse:5.0744
# [14:27:17] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=4
# [128]	validation_0-rmse:5.08471
# [14:27:17] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 0 pruned nodes, max_depth=4
# [129]	validation_0-rmse:5.11092
# [14:27:17] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 0 pruned nodes, max_depth=4
# [130]	validation_0-rmse:5.08172
# [14:27:17] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=3
# [131]	validation_0-rmse:5.09858
# [14:27:17] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=5
# [132]	validation_0-rmse:5.10812
# [14:27:17] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=3
# [133]	validation_0-rmse:5.1293
# [14:27:17] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [134]	validation_0-rmse:5.15026
# [14:27:17] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [135]	validation_0-rmse:5.16849
# [14:27:17] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [136]	validation_0-rmse:5.1704
# [14:27:17] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [137]	validation_0-rmse:5.16599
# [14:27:17] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=3
# [138]	validation_0-rmse:5.19336
# [14:27:17] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 0 pruned nodes, max_depth=5
# [139]	validation_0-rmse:5.1931
# [14:27:17] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [140]	validation_0-rmse:5.20159
# [14:27:17] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [141]	validation_0-rmse:5.19444
# [14:27:17] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 0 pruned nodes, max_depth=5
# [142]	validation_0-rmse:5.20206
# [14:27:17] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=4
# [143]	validation_0-rmse:5.20574
# [14:27:17] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=3
# [144]	validation_0-rmse:5.20124
# [14:27:17] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=3
# [145]	validation_0-rmse:5.21338
# [14:27:17] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=3
# [146]	validation_0-rmse:5.2247
# [14:27:17] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=3
# [147]	validation_0-rmse:5.22574
# [14:27:17] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [148]	validation_0-rmse:5.24002
# [14:27:17] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [149]	validation_0-rmse:5.22365
# [14:27:17] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 0 pruned nodes, max_depth=4
# [150]	validation_0-rmse:5.23834
# [14:27:17] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 0 pruned nodes, max_depth=4
# [151]	validation_0-rmse:5.23426
# [14:27:17] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [152]	validation_0-rmse:5.23471
# [14:27:17] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [153]	validation_0-rmse:5.23045
# [14:27:17] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [154]	validation_0-rmse:5.24604
# [14:27:17] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=3
# [155]	validation_0-rmse:5.24523
# [14:27:17] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=4
# [156]	validation_0-rmse:5.23502
# [14:27:17] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [157]	validation_0-rmse:5.23454
# [14:27:17] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=3
# [158]	validation_0-rmse:5.23829
# [14:27:17] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 0 pruned nodes, max_depth=4
# [159]	validation_0-rmse:5.24582
# [14:27:17] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [160]	validation_0-rmse:5.25447
# [14:27:17] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [161]	validation_0-rmse:5.25063
# [14:27:17] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 0 pruned nodes, max_depth=3
# [162]	validation_0-rmse:5.26553
# [14:27:17] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=3
# [163]	validation_0-rmse:5.26611
# [14:27:17] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=4
# [164]	validation_0-rmse:5.28149
# [14:27:17] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=3
# [165]	validation_0-rmse:5.28361
# [14:27:17] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [166]	validation_0-rmse:5.29104
# [14:27:17] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=4
# [167]	validation_0-rmse:5.27853
# [14:27:17] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [168]	validation_0-rmse:5.27515
# [14:27:17] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=3
# [169]	validation_0-rmse:5.27807
# [14:27:17] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=3
# [170]	validation_0-rmse:5.26943
# [14:27:17] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [171]	validation_0-rmse:5.27355
# [14:27:17] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=4
# [172]	validation_0-rmse:5.29018
# [14:27:17] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=3
# [173]	validation_0-rmse:5.29589
# [14:27:17] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=3
# [174]	validation_0-rmse:5.28806
# [14:27:17] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [175]	validation_0-rmse:5.28622
# [14:27:17] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 0 pruned nodes, max_depth=5
# [176]	validation_0-rmse:5.28511
# [14:27:17] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=5
# [177]	validation_0-rmse:5.29893
# [14:27:17] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=3
# [178]	validation_0-rmse:5.28865
# [14:27:17] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [179]	validation_0-rmse:5.27936
# [14:27:17] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [180]	validation_0-rmse:5.27053
# [14:27:17] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 0 pruned nodes, max_depth=4
# [181]	validation_0-rmse:5.25968
# [14:27:17] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 0 pruned nodes, max_depth=4
# [182]	validation_0-rmse:5.2504
# [14:27:17] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=3
# [183]	validation_0-rmse:5.26286
# [14:27:17] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [184]	validation_0-rmse:5.27357
# [14:27:17] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [185]	validation_0-rmse:5.27209
# [14:27:17] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [186]	validation_0-rmse:5.27353
# [14:27:17] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [187]	validation_0-rmse:5.27414
# [14:27:17] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [188]	validation_0-rmse:5.28298
# [14:27:17] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [189]	validation_0-rmse:5.27749
# [14:27:17] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=3
# [190]	validation_0-rmse:5.27939
# [14:27:17] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [191]	validation_0-rmse:5.29176
# [14:27:17] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [192]	validation_0-rmse:5.2852
# [14:27:17] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=4
# [193]	validation_0-rmse:5.28316
# [14:27:17] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [194]	validation_0-rmse:5.27731
# [14:27:17] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [195]	validation_0-rmse:5.27601
# [14:27:17] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=3
# [196]	validation_0-rmse:5.28752
# [14:27:17] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=3
# [197]	validation_0-rmse:5.28839
# [14:27:17] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=4
# [198]	validation_0-rmse:5.27878
# [14:27:17] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=3
# [199]	validation_0-rmse:5.27089
# [14:27:17] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=4
# [200]	validation_0-rmse:5.26872
# [14:27:17] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [201]	validation_0-rmse:5.26752
# [14:27:17] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [202]	validation_0-rmse:5.27488
# [14:27:17] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [203]	validation_0-rmse:5.27547
# [14:27:17] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=3
# [204]	validation_0-rmse:5.2831
# [14:27:17] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [205]	validation_0-rmse:5.27586
# [14:27:17] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=4
# [206]	validation_0-rmse:5.27131
# [14:27:17] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=4
# [207]	validation_0-rmse:5.27592
# [14:27:17] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=6
# [208]	validation_0-rmse:5.28994
# [14:27:17] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [209]	validation_0-rmse:5.29281
# [14:27:17] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [210]	validation_0-rmse:5.29562
# [14:27:17] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=4
# [211]	validation_0-rmse:5.29666
# [14:27:17] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 0 pruned nodes, max_depth=4
# [212]	validation_0-rmse:5.29717
# [14:27:17] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [213]	validation_0-rmse:5.29045
# [14:27:17] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 0 pruned nodes, max_depth=4
# [214]	validation_0-rmse:5.29338
# [14:27:17] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=3
# [215]	validation_0-rmse:5.31067
# [14:27:17] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=3
# [216]	validation_0-rmse:5.31776
# ...
# [14:27:21] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 2 extra nodes, 0 pruned nodes, max_depth=1
# [927]	validation_0-rmse:5.3654
# [14:27:21] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [928]	validation_0-rmse:5.36542
# [14:27:21] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=4
# [929]	validation_0-rmse:5.36542
# [14:27:21] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [930]	validation_0-rmse:5.36543
# [14:27:21] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 2 extra nodes, 0 pruned nodes, max_depth=1
# [931]	validation_0-rmse:5.36542
# [14:27:21] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [932]	validation_0-rmse:5.36541
# [14:27:21] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 2 extra nodes, 0 pruned nodes, max_depth=1
# [933]	validation_0-rmse:5.3654
# [14:27:21] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [934]	validation_0-rmse:5.3654
# [14:27:21] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [935]	validation_0-rmse:5.36539
# [14:27:21] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [936]	validation_0-rmse:5.36539
# [14:27:21] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [937]	validation_0-rmse:5.3654
# [14:27:21] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [938]	validation_0-rmse:5.3654
# [14:27:21] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 2 extra nodes, 0 pruned nodes, max_depth=1
# [939]	validation_0-rmse:5.36541
# [14:27:21] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [940]	validation_0-rmse:5.3654
# [14:27:21] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [941]	validation_0-rmse:5.3654
# [14:27:21] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 2 extra nodes, 0 pruned nodes, max_depth=1
# [942]	validation_0-rmse:5.36541
# [14:27:21] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 2 extra nodes, 0 pruned nodes, max_depth=1
# [943]	validation_0-rmse:5.3654
# [14:27:21] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [944]	validation_0-rmse:5.36541
# [14:27:21] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [945]	validation_0-rmse:5.3654
# [14:27:21] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 2 extra nodes, 0 pruned nodes, max_depth=1
# [946]	validation_0-rmse:5.3654
# [14:27:21] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [947]	validation_0-rmse:5.36539
# [14:27:21] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 2 extra nodes, 0 pruned nodes, max_depth=1
# [948]	validation_0-rmse:5.36537
# [14:27:21] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [949]	validation_0-rmse:5.36537
# [14:27:21] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [950]	validation_0-rmse:5.36538
# [14:27:21] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [951]	validation_0-rmse:5.36538
# [14:27:21] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [952]	validation_0-rmse:5.36538
# [14:27:21] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [953]	validation_0-rmse:5.36539
# [14:27:21] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [954]	validation_0-rmse:5.3654
# [14:27:21] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 2 extra nodes, 0 pruned nodes, max_depth=1
# [955]	validation_0-rmse:5.36539
# [14:27:21] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [956]	validation_0-rmse:5.36539
# [14:27:21] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [957]	validation_0-rmse:5.3654
# [14:27:21] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [958]	validation_0-rmse:5.36538
# [14:27:21] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 2 extra nodes, 0 pruned nodes, max_depth=1
# [959]	validation_0-rmse:5.36539
# [14:27:21] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 2 extra nodes, 0 pruned nodes, max_depth=1
# [960]	validation_0-rmse:5.3654
# [14:27:21] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [961]	validation_0-rmse:5.3654
# [14:27:21] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [962]	validation_0-rmse:5.36541
# [14:27:21] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [963]	validation_0-rmse:5.36542
# [14:27:21] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 2 extra nodes, 0 pruned nodes, max_depth=1
# [964]	validation_0-rmse:5.36542
# [14:27:21] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [965]	validation_0-rmse:5.3654
# [14:27:21] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [966]	validation_0-rmse:5.36541
# [14:27:21] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 2 extra nodes, 0 pruned nodes, max_depth=1
# [967]	validation_0-rmse:5.3654
# [14:27:21] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 2 extra nodes, 0 pruned nodes, max_depth=1
# [968]	validation_0-rmse:5.3654
# [14:27:21] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [969]	validation_0-rmse:5.3654
# [14:27:21] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 2 extra nodes, 0 pruned nodes, max_depth=1
# [970]	validation_0-rmse:5.36542
# [14:27:21] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 2 extra nodes, 0 pruned nodes, max_depth=1
# [971]	validation_0-rmse:5.36542
# [14:27:21] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 2 extra nodes, 0 pruned nodes, max_depth=1
# [972]	validation_0-rmse:5.36542
# [14:27:21] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 2 extra nodes, 0 pruned nodes, max_depth=1
# [973]	validation_0-rmse:5.36541
# [14:27:21] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [974]	validation_0-rmse:5.3654
# [14:27:21] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [975]	validation_0-rmse:5.3654
# [14:27:21] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [976]	validation_0-rmse:5.36539
# [14:27:21] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [977]	validation_0-rmse:5.3654
# [14:27:21] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 2 extra nodes, 0 pruned nodes, max_depth=1
# [978]	validation_0-rmse:5.3654
# [14:27:21] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [979]	validation_0-rmse:5.36542
# [14:27:21] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [980]	validation_0-rmse:5.36541
# [14:27:21] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 2 extra nodes, 0 pruned nodes, max_depth=1
# [981]	validation_0-rmse:5.3654
# [14:27:21] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 2 extra nodes, 0 pruned nodes, max_depth=1
# [982]	validation_0-rmse:5.36539
# [14:27:21] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [983]	validation_0-rmse:5.36539
# [14:27:21] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 2 extra nodes, 0 pruned nodes, max_depth=1
# [984]	validation_0-rmse:5.36538
# [14:27:21] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 2 extra nodes, 0 pruned nodes, max_depth=1
# [985]	validation_0-rmse:5.36539
# [14:27:21] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 2 extra nodes, 0 pruned nodes, max_depth=1
# [986]	validation_0-rmse:5.36538
# [14:27:21] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [987]	validation_0-rmse:5.36538
# [14:27:21] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 2 extra nodes, 0 pruned nodes, max_depth=1
# [988]	validation_0-rmse:5.36538
# [14:27:21] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 2 extra nodes, 0 pruned nodes, max_depth=1
# [989]	validation_0-rmse:5.36539
# [14:27:21] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [990]	validation_0-rmse:5.36539
# [14:27:21] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [991]	validation_0-rmse:5.36538
# [14:27:21] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 2 extra nodes, 0 pruned nodes, max_depth=1
# [992]	validation_0-rmse:5.36538
# [14:27:21] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [993]	validation_0-rmse:5.36538
# [14:27:21] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [994]	validation_0-rmse:5.36537
# [14:27:21] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [995]	validation_0-rmse:5.36538
# [14:27:21] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 2 extra nodes, 0 pruned nodes, max_depth=1
# [996]	validation_0-rmse:5.36538
# [14:27:21] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [997]	validation_0-rmse:5.36537
# [14:27:21] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [998]	validation_0-rmse:5.36537
# [14:27:21] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 2 extra nodes, 0 pruned nodes, max_depth=1
# [999]	validation_0-rmse:5.36537
# Duration: 4.76772928237915s

# %%
# Plot feature importance
figsize=(7,7)
fig, ax = plt.subplots(1,1,figsize=figsize)
plot_importance(model, ax=ax,height = 1)

# %%
# predict sales in test dataset
test_predictions = model.predict(X_test).flatten()

# scatter plot of True vs Predicted values
plt.scatter(y_test, test_predictions)
plt.xlabel('True Values $')
plt.ylabel('Predictions $')
plt.axis('equal')
plt.axis('square')
plt.xlim([100,plt.xlim()[1]])
plt.ylim([100,plt.ylim()[1]])
_ = plt.plot([0, 1000], [0, 1000])

# %%
# Histogram of error values
error = test_predictions - y_test
plt.hist(error, bins = 25)
plt.xlabel("Prediction Error $")
_ = plt.ylabel("Count")

# %% [markdown]
# # Anomaly detection approach
#
# Loss > Threshold ise = anomaly > bubble mi demek?

# %%
# Data normalization
scaler = MinMaxScaler(feature_range=(0, 1))
X_train = scaler.fit_transform(df_train[:-5]) # Healthy/normal data
X_test = scaler.fit_transform(df_train[-5:]) # Unhealthy/anomaly data

# %%
X_train.shape
# Out:
# (46, 11)

# %%
# Reshape for LSTM
X_train = X_train.reshape(X_train.shape[0], 1, X_train.shape[1])
X_test = X_test.reshape(X_test.shape[0], 1, X_test.shape[1])

# %%
# define the autoencoder network model
def autoencoder_model(X):
    inputs = Input(shape=(X.shape[1], X.shape[2]))
    L1 = LSTM(16, activation='relu', return_sequences=True, 
              kernel_regularizer=regularizers.l2(0.00))(inputs)
    L2 = LSTM(4, activation='relu', return_sequences=False)(L1)
    L3 = RepeatVector(X.shape[1])(L2)
    L4 = LSTM(4, activation='relu', return_sequences=True)(L3)
    L5 = LSTM(16, activation='relu', return_sequences=True)(L4)
    output = TimeDistributed(Dense(X.shape[2]))(L5)    
    model = Model(inputs=inputs, outputs=output)
    return model

# %%
# create the autoencoder model
model = autoencoder_model(X_train)
model.compile(optimizer='adam', loss='mae')
model.summary()
# Out:
# WARNING:tensorflow:From /home/ipcvlab/anaconda2/envs/data_science/lib/python3.6/site-packages/tensorflow/python/ops/resource_variable_ops.py:435: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 1, 11)             0
# _________________________________________________________________
# lstm (LSTM)                  (None, 1, 16)             1792
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 4)                 336
# _________________________________________________________________
# repeat_vector (RepeatVector) (None, 1, 4)              0
# _________________________________________________________________
# lstm_2 (LSTM)                (None, 1, 4)              144
# _________________________________________________________________
# lstm_3 (LSTM)                (None, 1, 16)             1344
# _________________________________________________________________
# time_distributed (TimeDistri (None, 1, 11)             187
# =================================================================
# Total params: 3,803
# Trainable params: 3,803
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = model.fit(X_train, X_train, epochs=100, batch_size=10,
                    validation_split=0.05).history
# Out:
# Train on 43 samples, validate on 3 samples
# WARNING:tensorflow:From /home/ipcvlab/anaconda2/envs/data_science/lib/python3.6/site-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Epoch 1/100
# 43/43 [==============================] - 7s 173ms/sample - loss: 0.3349 - val_loss: 0.7738
# Epoch 2/100
# 43/43 [==============================] - 0s 2ms/sample - loss: 0.3300 - val_loss: 0.7685
# Epoch 3/100
# 43/43 [==============================] - 0s 2ms/sample - loss: 0.3251 - val_loss: 0.7632
# Epoch 4/100
# 43/43 [==============================] - 0s 2ms/sample - loss: 0.3203 - val_loss: 0.7579
# Epoch 5/100
# 43/43 [==============================] - 0s 3ms/sample - loss: 0.3155 - val_loss: 0.7527
# Epoch 6/100
# 43/43 [==============================] - 0s 2ms/sample - loss: 0.3110 - val_loss: 0.7474
# Epoch 7/100
# 43/43 [==============================] - 0s 2ms/sample - loss: 0.3063 - val_loss: 0.7421
# Epoch 8/100
# 43/43 [==============================] - 0s 2ms/sample - loss: 0.3017 - val_loss: 0.7366
# Epoch 9/100
# 43/43 [==============================] - 0s 2ms/sample - loss: 0.2972 - val_loss: 0.7310
# Epoch 10/100
# 43/43 [==============================] - 0s 2ms/sample - loss: 0.2928 - val_loss: 0.7254
# Epoch 11/100
# 43/43 [==============================] - 0s 2ms/sample - loss: 0.2882 - val_loss: 0.7201
# Epoch 12/100
# 43/43 [==============================] - 0s 2ms/sample - loss: 0.2842 - val_loss: 0.7145
# Epoch 13/100
# 43/43 [==============================] - 0s 2ms/sample - loss: 0.2801 - val_loss: 0.7087
# Epoch 14/100
# 43/43 [==============================] - 0s 3ms/sample - loss: 0.2757 - val_loss: 0.7029
# Epoch 15/100
# 43/43 [==============================] - 0s 2ms/sample - loss: 0.2717 - val_loss: 0.6967
# Epoch 16/100
# 43/43 [==============================] - 0s 3ms/sample - loss: 0.2676 - val_loss: 0.6900
# Epoch 17/100
# 43/43 [==============================] - 0s 3ms/sample - loss: 0.2635 - val_loss: 0.6829
# Epoch 18/100
# 43/43 [==============================] - 0s 2ms/sample - loss: 0.2597 - val_loss: 0.6751
# Epoch 19/100
# 43/43 [==============================] - 0s 2ms/sample - loss: 0.2555 - val_loss: 0.6667
# Epoch 20/100
# 43/43 [==============================] - 0s 7ms/sample - loss: 0.2513 - val_loss: 0.6565
# Epoch 21/100
# 43/43 [==============================] - 0s 2ms/sample - loss: 0.2469 - val_loss: 0.6429
# Epoch 22/100
# 43/43 [==============================] - 0s 2ms/sample - loss: 0.2421 - val_loss: 0.6237
# Epoch 23/100
# 43/43 [==============================] - 0s 2ms/sample - loss: 0.2365 - val_loss: 0.5947
# Epoch 24/100
# 43/43 [==============================] - 0s 3ms/sample - loss: 0.2301 - val_loss: 0.5429
# Epoch 25/100
# 43/43 [==============================] - 0s 2ms/sample - loss: 0.2217 - val_loss: 0.4447
# Epoch 26/100
# 43/43 [==============================] - 0s 2ms/sample - loss: 0.2120 - val_loss: 0.3001
# Epoch 27/100
# 43/43 [==============================] - 0s 2ms/sample - loss: 0.1971 - val_loss: 0.2648
# Epoch 28/100
# 43/43 [==============================] - 0s 2ms/sample - loss: 0.1871 - val_loss: 0.5035
# Epoch 29/100
# 43/43 [==============================] - 0s 2ms/sample - loss: 0.1749 - val_loss: 0.7540
# Epoch 30/100
# 43/43 [==============================] - 0s 4ms/sample - loss: 0.1689 - val_loss: 0.7197
# Epoch 31/100
# 43/43 [==============================] - 0s 4ms/sample - loss: 0.1579 - val_loss: 0.5687
# Epoch 32/100
# 43/43 [==============================] - 0s 5ms/sample - loss: 0.1522 - val_loss: 0.5043
# Epoch 33/100
# 43/43 [==============================] - 0s 2ms/sample - loss: 0.1469 - val_loss: 0.6269
# Epoch 34/100
# 43/43 [==============================] - 0s 3ms/sample - loss: 0.1413 - val_loss: 0.6714
# Epoch 35/100
# 43/43 [==============================] - 0s 2ms/sample - loss: 0.1394 - val_loss: 0.7059
# Epoch 36/100
# 43/43 [==============================] - 0s 7ms/sample - loss: 0.1371 - val_loss: 0.6067
# Epoch 37/100
# 43/43 [==============================] - 0s 3ms/sample - loss: 0.1340 - val_loss: 0.5878
# Epoch 38/100
# 43/43 [==============================] - 0s 2ms/sample - loss: 0.1326 - val_loss: 0.5883
# Epoch 39/100
# 43/43 [==============================] - 0s 2ms/sample - loss: 0.1311 - val_loss: 0.5850
# Epoch 40/100
# 43/43 [==============================] - 0s 2ms/sample - loss: 0.1300 - val_loss: 0.5839
# Epoch 41/100
# 43/43 [==============================] - 0s 2ms/sample - loss: 0.1286 - val_loss: 0.5764
# Epoch 42/100
# 43/43 [==============================] - 0s 2ms/sample - loss: 0.1276 - val_loss: 0.4917
# Epoch 43/100
# 43/43 [==============================] - 0s 2ms/sample - loss: 0.1270 - val_loss: 0.4598
# Epoch 44/100
# 43/43 [==============================] - 0s 3ms/sample - loss: 0.1254 - val_loss: 0.5189
# Epoch 45/100
# 43/43 [==============================] - 0s 2ms/sample - loss: 0.1249 - val_loss: 0.5732
# Epoch 46/100
# 43/43 [==============================] - 0s 2ms/sample - loss: 0.1236 - val_loss: 0.5512
# Epoch 47/100
# 43/43 [==============================] - 0s 2ms/sample - loss: 0.1224 - val_loss: 0.5286
# Epoch 48/100
# 43/43 [==============================] - 0s 2ms/sample - loss: 0.1214 - val_loss: 0.4838
# Epoch 49/100
# 43/43 [==============================] - 0s 3ms/sample - loss: 0.1202 - val_loss: 0.4736
# Epoch 50/100
# 43/43 [==============================] - 0s 2ms/sample - loss: 0.1194 - val_loss: 0.4847
# Epoch 51/100
# 43/43 [==============================] - 0s 2ms/sample - loss: 0.1181 - val_loss: 0.4492
# Epoch 52/100
# 43/43 [==============================] - 0s 3ms/sample - loss: 0.1176 - val_loss: 0.4435
# Epoch 53/100
# 43/43 [==============================] - 0s 2ms/sample - loss: 0.1165 - val_loss: 0.4636
# Epoch 54/100
# 43/43 [==============================] - 0s 2ms/sample - loss: 0.1160 - val_loss: 0.4152
# Epoch 55/100
# 43/43 [==============================] - 0s 7ms/sample - loss: 0.1147 - val_loss: 0.4244
# Epoch 56/100
# 43/43 [==============================] - 0s 2ms/sample - loss: 0.1141 - val_loss: 0.4559
# Epoch 57/100
# 43/43 [==============================] - 0s 2ms/sample - loss: 0.1127 - val_loss: 0.4359
# Epoch 58/100
# 43/43 [==============================] - 0s 2ms/sample - loss: 0.1116 - val_loss: 0.4245
# Epoch 59/100
# 43/43 [==============================] - 0s 2ms/sample - loss: 0.1107 - val_loss: 0.3963
# Epoch 60/100
# 43/43 [==============================] - 0s 2ms/sample - loss: 0.1098 - val_loss: 0.3982
# Epoch 61/100
# 43/43 [==============================] - 0s 3ms/sample - loss: 0.1089 - val_loss: 0.3947
# Epoch 62/100
# 43/43 [==============================] - 0s 2ms/sample - loss: 0.1077 - val_loss: 0.3803
# Epoch 63/100
# 43/43 [==============================] - 0s 2ms/sample - loss: 0.1069 - val_loss: 0.3885
# Epoch 64/100
# 43/43 [==============================] - 0s 2ms/sample - loss: 0.1057 - val_loss: 0.3865
# Epoch 65/100
# 43/43 [==============================] - 0s 2ms/sample - loss: 0.1047 - val_loss: 0.3877
# Epoch 66/100
# 43/43 [==============================] - 0s 3ms/sample - loss: 0.1040 - val_loss: 0.3983
# Epoch 67/100
# 43/43 [==============================] - 0s 3ms/sample - loss: 0.1031 - val_loss: 0.3599
# Epoch 68/100
# 43/43 [==============================] - 0s 2ms/sample - loss: 0.1022 - val_loss: 0.3733
# Epoch 69/100
# 43/43 [==============================] - 0s 3ms/sample - loss: 0.1010 - val_loss: 0.3702
# Epoch 70/100
# 43/43 [==============================] - 0s 2ms/sample - loss: 0.1003 - val_loss: 0.3793
# Epoch 71/100
# 43/43 [==============================] - 0s 2ms/sample - loss: 0.0997 - val_loss: 0.3542
# Epoch 72/100
# 43/43 [==============================] - 0s 2ms/sample - loss: 0.0989 - val_loss: 0.3510
# Epoch 73/100
# 43/43 [==============================] - 0s 1ms/sample - loss: 0.0984 - val_loss: 0.3454
# Epoch 74/100
# 43/43 [==============================] - 0s 1ms/sample - loss: 0.0973 - val_loss: 0.3684
# Epoch 75/100
# 43/43 [==============================] - 0s 2ms/sample - loss: 0.0973 - val_loss: 0.3685
# Epoch 76/100
# 43/43 [==============================] - 0s 6ms/sample - loss: 0.0968 - val_loss: 0.3647
# Epoch 77/100
# 43/43 [==============================] - 0s 2ms/sample - loss: 0.0962 - val_loss: 0.3526
# Epoch 78/100
# 43/43 [==============================] - 0s 2ms/sample - loss: 0.0955 - val_loss: 0.3594
# Epoch 79/100
# 43/43 [==============================] - 0s 2ms/sample - loss: 0.0956 - val_loss: 0.3615
# Epoch 80/100
# 43/43 [==============================] - 0s 2ms/sample - loss: 0.0949 - val_loss: 0.3421
# Epoch 81/100
# 43/43 [==============================] - 0s 2ms/sample - loss: 0.0945 - val_loss: 0.3349
# Epoch 82/100
# 43/43 [==============================] - 0s 2ms/sample - loss: 0.0941 - val_loss: 0.3356
# Epoch 83/100
# 43/43 [==============================] - 0s 2ms/sample - loss: 0.0937 - val_loss: 0.3306
# Epoch 84/100
# 43/43 [==============================] - 0s 2ms/sample - loss: 0.0933 - val_loss: 0.3293
# Epoch 85/100
# 43/43 [==============================] - 0s 3ms/sample - loss: 0.0929 - val_loss: 0.3231
# Epoch 86/100
# 43/43 [==============================] - 0s 2ms/sample - loss: 0.0927 - val_loss: 0.3196
# Epoch 87/100
# 43/43 [==============================] - 0s 2ms/sample - loss: 0.0925 - val_loss: 0.3247
# Epoch 88/100
# 43/43 [==============================] - 0s 2ms/sample - loss: 0.0921 - val_loss: 0.3062
# Epoch 89/100
# 43/43 [==============================] - 0s 2ms/sample - loss: 0.0919 - val_loss: 0.3052
# Epoch 90/100
# 43/43 [==============================] - 0s 2ms/sample - loss: 0.0916 - val_loss: 0.3227
# Epoch 91/100
# 43/43 [==============================] - 0s 2ms/sample - loss: 0.0914 - val_loss: 0.3177
# Epoch 92/100
# 43/43 [==============================] - 0s 2ms/sample - loss: 0.0909 - val_loss: 0.3148
# Epoch 93/100
# 43/43 [==============================] - 0s 2ms/sample - loss: 0.0906 - val_loss: 0.3069
# Epoch 94/100
# 43/43 [==============================] - 0s 2ms/sample - loss: 0.0903 - val_loss: 0.3081
# Epoch 95/100
# 43/43 [==============================] - 0s 2ms/sample - loss: 0.0904 - val_loss: 0.3157
# Epoch 96/100
# 43/43 [==============================] - 0s 2ms/sample - loss: 0.0903 - val_loss: 0.2897
# Epoch 97/100
# 43/43 [==============================] - 0s 3ms/sample - loss: 0.0898 - val_loss: 0.2945
# Epoch 98/100
# 43/43 [==============================] - 0s 7ms/sample - loss: 0.0894 - val_loss: 0.3005
# Epoch 99/100
# 43/43 [==============================] - 0s 2ms/sample - loss: 0.0892 - val_loss: 0.3019
# Epoch 100/100
# 43/43 [==============================] - 0s 2ms/sample - loss: 0.0888 - val_loss: 0.2969

# %%
# plot the training losses
fig, ax = plt.subplots(figsize=(14, 6), dpi=80)
ax.plot(history['loss'], 'b', label='Train', linewidth=2)
ax.plot(history['val_loss'], 'r', label='Validation', linewidth=2)
ax.set_title('Model loss', fontsize=16)
ax.set_ylabel('Loss (mae)')
ax.set_xlabel('Epoch')
ax.legend(loc='upper right')
plt.show()

# %%
# plot the loss distribution of the training set
X_pred = model.predict(X_train)
X_pred = X_pred.reshape(X_pred.shape[0], X_pred.shape[2])
X_pred = pd.DataFrame(X_pred, columns=df_train.columns)
X_pred.index = df_train[:-5].index

scored = pd.DataFrame(index=df_train[:-5].index)
Xtrain = X_train.reshape(X_train.shape[0], X_train.shape[2])
scored['Loss_mae'] = np.mean(np.abs(X_pred-Xtrain), axis = 1)
plt.figure(figsize=(16,9), dpi=80)
plt.title('Loss Distribution', fontsize=16)
sns.distplot(scored['Loss_mae'], bins = 20, kde= True, color = 'blue');
plt.xlim([0.0,.5])

#Out[17]:
#(0.0, 0.5)
# Out:
# (0.0, 0.5)

# %%
# calculate the loss on the test set
X_pred = model.predict(X_test)
X_pred = X_pred.reshape(X_pred.shape[0], X_pred.shape[2])
X_pred = pd.DataFrame(X_pred, columns=df_train.columns)
X_pred.index = df_train[-5:].index

scored = pd.DataFrame(index=df_train[-5:].index)
Xtest = X_test.reshape(X_test.shape[0], X_test.shape[2])
scored['Loss_mae'] = np.mean(np.abs(X_pred-Xtest), axis = 1)
scored['Threshold'] = 0.2
scored['Anomaly'] = scored['Loss_mae'] > scored['Threshold']
scored.head()
# Out:
#          Loss_mae  Threshold  Anomaly
# Date
# 2018-12  0.272923        0.2     True
# 2019-03  0.291459        0.2     True
# 2019-06  0.410188        0.2     True
# 2019-09  0.215513        0.2     True
# 2019-12  0.314937        0.2     True

# %%
# calculate the same metrics for the training set 
# and merge all data in a single dataframe for plotting
X_pred_train = model.predict(X_train)
X_pred_train = X_pred_train.reshape(X_pred_train.shape[0], X_pred_train.shape[2])
X_pred_train = pd.DataFrame(X_pred_train, columns=df_train[:-5].columns)
X_pred_train.index = df_train[:-5].index

scored_train = pd.DataFrame(index=df_train[:-5].index)
scored_train['Loss_mae'] = np.mean(np.abs(X_pred_train-Xtrain), axis = 1)
scored_train['Threshold'] = 0.2
scored_train['Anomaly'] = scored_train['Loss_mae'] > scored_train['Threshold']
scored = pd.concat([scored_train, scored])
scored
scored.to_csv("/home/ipcvlab/Desktop/output.csv")

# %%
# plot bearing failure time plot
scored.plot(logy=True,  figsize=(16,9), ylim=[1e-2,1e2], color=['blue','red'])
