# %%
import time
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

#plotting
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
sns.set_style("whitegrid")

# %%
from sklearn.model_selection import KFold, GridSearchCV, cross_val_score, train_test_split # Model evaluation
from sklearn.preprocessing import MinMaxScaler # Data normalization
from xgboost import XGBRegressor, DMatrix, plot_importance # XGBoost

# %%
# pip install tensorflow==2
import tensorflow as tf
from tensorflow.keras.layers import Input, Dropout, Dense, LSTM, TimeDistributed, RepeatVector
from tensorflow.keras.models import Model
from tensorflow.keras import regularizers
# Out:
# /home/ipcvlab/anaconda2/envs/data_science/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /home/ipcvlab/anaconda2/envs/data_science/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /home/ipcvlab/anaconda2/envs/data_science/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:528: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /home/ipcvlab/anaconda2/envs/data_science/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:529: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /home/ipcvlab/anaconda2/envs/data_science/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:530: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /home/ipcvlab/anaconda2/envs/data_science/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:535: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %%
df_train = pd.read_excel("/home/ipcvlab/Downloads/ilceler/yıllık-ilk-calısma/cekmekoy_tum_veriler.xlsx", index_col = 0) 
cols_list = list(df_train.columns)

# %%
df_train.head()
# Out:
#          HouseEndex      bist   USD/TRY  Aylık_Mevduat_Faizi   Konut_Kredisi  \
# Tarih
# 2003-01       65.55  11032.03  1.663822               47.4880        44.0280
# 2003-02       66.21  11574.44  1.631060               47.9525        43.3100
# 2003-03       67.24   9475.09  1.663371               48.4425        45.8475
# 2003-04       68.15  11509.95  1.635045               48.0475        50.3050
# 2003-05       68.69  11381.41  1.497566               44.4780        45.3620
#
#          ic_borc_maliyet  tufe_endeks  guven_endeksi
# Tarih
# 2003-01        56.824577        94.77            NaN
# 2003-02        55.323955        96.23            NaN
# 2003-03        59.930634        98.12            NaN
# 2003-04        57.498830        99.09            NaN
# 2003-05        51.079707       100.04            NaN

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 204 entries, 2003-01 to 2019-12
# Data columns (total 8 columns):
# HouseEndex              204 non-null float64
# bist                    204 non-null float64
# USD/TRY                 204 non-null float64
# Aylık_Mevduat_Faizi     204 non-null float64
# Konut_Kredisi           204 non-null float64
# ic_borc_maliyet         204 non-null float64
# tufe_endeks             204 non-null float64
# guven_endeksi           192 non-null float64
# dtypes: float64(8)
# memory usage: 14.3+ KB

# %%
df_train.describe()
# Out:
#        HouseEndex           bist     USD/TRY  Aylık_Mevduat_Faizi   \
# count  204.000000     204.000000  204.000000            204.000000
# mean   138.306324   60357.147696    2.286973             13.975219
# std     64.795413   27993.177820    1.294062              8.225539
# min     65.550000    9475.090000    1.176086              5.264000
# 25%     88.725000   38159.450000    1.436319              8.498000
# 50%    103.450000   61571.040000    1.688293             10.970000
# 75%    203.000000   80379.620000    2.857129             17.523750
# max    251.600000  119528.790000    6.378340             48.442500
#
#        Konut_Kredisi  ic_borc_maliyet  tufe_endeks  guven_endeksi
# count     204.000000       204.000000   204.000000     192.000000
# mean       16.954001        15.440405   211.077549      73.889131
# std         7.843219         9.362502    89.697329       9.657939
# min         8.297500         5.685006    94.770000      55.136536
# 25%        11.836875         9.246844   138.420000      67.456996
# 50%        14.162250        12.149540   188.375000      73.808016
# 75%        18.941750        18.722633   264.132500      79.307277
# max        50.305000        59.930634   440.500000      98.677315

# %% [markdown]
# ### display Missing values

# %%
label_nas = []
for col in df_train.columns.tolist():
    if np.sum(df_train[col].isnull() ) != 0:
        label_nas.append(col)
    else:
        label_nas.append("")

plt.figure(figsize=(12,7))
plt.suptitle('Missing Values in the Training Set')
sns.heatmap(df_train.isnull(), yticklabels=False, xticklabels=label_nas ,cbar = False, cmap='viridis')
plt.show()

# %%
replace = True # True: replace null in guven_endeksi with average. False: guven_endeksi kullanmadan
if replace:
    df_train = df_train.fillna(df_train.mean())
else:
    df_train.drop('guven_endeksi', axis=1, inplace=True)

# %%
# Correlation matrix
corr_mat = df_train.corr().abs()
# Find most important features relative to target
corr_mat.sort_values(by=["HouseEndex"], ascending = False, inplace = True)
print(corr_mat.HouseEndex)
# Out:
# HouseEndex              1.000000
# tufe_endeks             0.938245
# USD/TRY                 0.896264
# bist                    0.875104
# guven_endeksi           0.580349
# Konut_Kredisi           0.305519
# ic_borc_maliyet         0.265238
# Aylık_Mevduat_Faizi     0.253678
# Name: HouseEndex, dtype: float64

# %%
#Correlation matrix between features
corr_mat = df_train.corr().abs()

# %%
#Plot the heatmap with seaborn
plt.figure(figsize=(7,7)) 

mask = np.zeros_like(corr_mat)
mask[np.triu_indices_from(mask)] = True

sns.heatmap(corr_mat, mask=mask,
        xticklabels=corr_mat.columns,
        yticklabels=corr_mat.columns)

# %%
#List the highly correlated columns
corr_tmp = corr_mat.unstack()
corr_tmp = corr_tmp.sort_values(kind="quicksort")

print(corr_tmp[-len(corr_mat)-10:-len(corr_mat)])
# Out:
# tufe_endeks           HouseEndex              0.938245
# HouseEndex            tufe_endeks             0.938245
# USD/TRY               tufe_endeks             0.942730
# tufe_endeks           USD/TRY                 0.942730
# ic_borc_maliyet       Konut_Kredisi           0.953954
# Konut_Kredisi         ic_borc_maliyet         0.953954
# Aylık_Mevduat_Faizi   Konut_Kredisi           0.964143
# Konut_Kredisi         Aylık_Mevduat_Faizi     0.964143
# ic_borc_maliyet       Aylık_Mevduat_Faizi     0.982354
# Aylık_Mevduat_Faizi   ic_borc_maliyet         0.982354
# dtype: float64

# %%
# Find most important features relative to target
corr_mat.sort_values(["HouseEndex"], ascending = False, inplace = True)
print(corr_mat.HouseEndex)
# Out:
# HouseEndex              1.000000
# tufe_endeks             0.938245
# USD/TRY                 0.896264
# bist                    0.875104
# guven_endeksi           0.580349
# Konut_Kredisi           0.305519
# ic_borc_maliyet         0.265238
# Aylık_Mevduat_Faizi     0.253678
# Name: HouseEndex, dtype: float64

# %% [markdown]
# # Skewness

# %%
#Check the skewness of HouseEndeks
for col in cols_list:
    plt.figure(figsize=(10, 5))
    skewness = df_train[col].skew()
    df_train[col].plot.hist(edgecolor='white', bins=30, 
                                    label=col + ' skew =' + str(round(skewness,2)))
    plt.suptitle("{} distribution".format(col))
    plt.legend()
    plt.show()

# %% [markdown]
# # Box plots

# %%
for col in cols_list:
    plt.figure(figsize=(10, 5))
    # Create the boxplot
    ax = sns.boxplot(x=col, data=df_train)
    # Set the `xlim`
    #ax.set(xlim=(0, 100))
    # Add title
    ax.set_title(col)
    # Show the plot
    plt.show()

# %%
for col in cols_list:    
    y_axis = col
    count = df_train[y_axis].count()
    value=df_train[y_axis]

    plt.figure(figsize=(10, 5))
    sns.regplot(np.linspace(0, count, count), df_train[y_axis], fit_reg=True,
                scatter_kws={'facecolors':np.where( value==True , "red", 'darkviolet'),
               'edgecolor':np.where(value==True , "red", 'darkviolet')},
               line_kws = {'color': 'darkblue'})
    plt.title(col, fontsize=24)
    plt.xlabel('-', fontsize=18)
    plt.ylabel(col, fontsize=18)
    # plt.savefig('figures/Standardised_SalePrice_GrLivArea.png')

# %% [markdown]
# # HouseEndex vs other

# %% [markdown]
# - Kirmizi: bubble fiyatlari iceren regresyon cizgi
# - Mavi: bubble fiyatlari iceren regresyon cizgi
#
# mavi ve kirmizi cizgi arasinda buyuk bir fark varsa, bubble/anomaly mi demek?

# %%
# Displays A Scatter Plot with Regression Line + Outliers in Red

for col in cols_list:
    x_axis = col
    y_axis = 'HouseEndex'
    value=(df_train[y_axis] > 107)
    value2=(df_train[y_axis][:-15] > 107)

    plt.figure(figsize=(10, 5))
    sns.regplot(df_train[x_axis], df_train[y_axis], fit_reg=True,
                scatter_kws={'facecolors':np.where( value==True , "red", 'darkviolet'),
               'edgecolor':np.where(value==True , "red", 'darkviolet')},
               line_kws = {'color': 'darkred'})
    
    sns.regplot(df_train[x_axis][:-15], df_train[y_axis][:-15], fit_reg=True,
                scatter_kws={'facecolors':np.where( value2==True , "red", 'darkviolet'),
               'edgecolor':np.where(value2==True , "red", 'darkviolet')},
               line_kws = {'color': 'darkblue'})
    
    plt.title('HouseEndex vs. {}'.format(x_axis), fontsize=24)
    plt.xlabel(x_axis, fontsize=18)
    plt.ylabel('HouseEndex', fontsize=18)
    # plt.savefig('figures/Standardised_SalePrice_GrLivArea.png')

# %% [markdown]
# # XGBoost
#
# hiç faydası yok bu konuda, eğitimde kullandığımız verileri göre sonuç veriyor, ama şişik olup olmadığını gösteremez

# %%
#y_full = df_train['HouseEndex']
#X_full = df_train.drop(columns=["HouseEndex"])

y_full = df_train['HouseEndex'][:-15]
X_full = df_train.drop(columns=["HouseEndex"])[:-15]

y_test = df_train['HouseEndex'][-15:]
X_test = df_train.drop(columns=["HouseEndex"])[-15:]

X_train, X_val, y_train, y_val = train_test_split(X_full, y_full, test_size=0.2, random_state=123)

# %%
# final model with tuned parameters
model = XGBRegressor(max_depth=6, #dflt 6
                     learning_rate=0.1, #dflt 100
                     n_estimators=1000, #dflt 0.1
                     verbosity = 3,
                     objective='reg:linear',
                     n_jobs=-1,
                     gamma=0, #dflt: 0
                     min_child_weight=3, #0 dflt: 1
                     subsample=0.5,
                     colsample_bytree=1,
                     reg_lambda=0.99994, #dflt: 1
                     reg_alpha=0.00003, #dflt: 0
                     tree_method='exact',
                     scale_pos_weight=1, # dflt: 1
                     random_state=123)

# %%
tick=time.time()

fitted_model = model.fit(X_train, y_train,
                         eval_set=[(X_val, y_val)],
                         eval_metric='rmse', # Equivalent to RMSLE since we have log1p(SalePrice)
                         early_stopping_rounds=1000,
                         verbose=True)

print("Duration: {}s".format(time.time()-tick))
# Out:
# [14:30:29] WARNING: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [14:30:29] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [0]	validation_0-rmse:132.266
# Will train until validation_0-rmse hasn't improved in 1000 rounds.
# [14:30:29] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [1]	validation_0-rmse:119.446
# [14:30:29] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [2]	validation_0-rmse:107.557
# [14:30:29] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [3]	validation_0-rmse:97.0838
# [14:30:29] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [4]	validation_0-rmse:87.5249
# [14:30:30] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [5]	validation_0-rmse:79.0314
# [14:30:30] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [6]	validation_0-rmse:71.255
# [14:30:30] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [7]	validation_0-rmse:64.3698
# [14:30:30] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [8]	validation_0-rmse:58.2727
# [14:30:30] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [9]	validation_0-rmse:52.5631
# [14:30:30] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [10]	validation_0-rmse:47.8012
# [14:30:30] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [11]	validation_0-rmse:43.373
# [14:30:30] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [12]	validation_0-rmse:39.1406
# [14:30:30] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [13]	validation_0-rmse:35.3291
# [14:30:30] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [14]	validation_0-rmse:31.8888
# [14:30:30] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [15]	validation_0-rmse:28.9175
# [14:30:30] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 0 pruned nodes, max_depth=3
# [16]	validation_0-rmse:26.2956
# [14:30:30] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=3
# [17]	validation_0-rmse:23.733
# /home/ipcvlab/anaconda2/envs/data_science/lib/python3.6/site-packages/xgboost/core.py:587: FutureWarning: Series.base is deprecated and will be removed in a future version
#   if getattr(data, 'base', None) is not None and \
# [14:30:30] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [18]	validation_0-rmse:21.5543
# [14:30:30] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=4
# [19]	validation_0-rmse:19.4625
# [14:30:30] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=5
# [20]	validation_0-rmse:17.5684
# [14:30:30] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 0 pruned nodes, max_depth=4
# [21]	validation_0-rmse:16.017
# [14:30:30] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=4
# [22]	validation_0-rmse:14.668
# [14:30:30] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=3
# [23]	validation_0-rmse:13.4736
# [14:30:30] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 0 pruned nodes, max_depth=5
# [24]	validation_0-rmse:12.2591
# [14:30:30] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=5
# [25]	validation_0-rmse:11.3457
# [14:30:30] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 0 pruned nodes, max_depth=5
# [26]	validation_0-rmse:10.3841
# [14:30:30] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=5
# [27]	validation_0-rmse:9.56538
# [14:30:30] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=5
# [28]	validation_0-rmse:8.78254
# [14:30:30] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=4
# [29]	validation_0-rmse:8.23026
# [14:30:30] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 0 pruned nodes, max_depth=5
# [30]	validation_0-rmse:7.7197
# [14:30:30] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 0 pruned nodes, max_depth=5
# [31]	validation_0-rmse:7.33391
# [14:30:30] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=6
# [32]	validation_0-rmse:6.89621
# [14:30:30] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 0 pruned nodes, max_depth=6
# [33]	validation_0-rmse:6.61816
# [14:30:30] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 0 pruned nodes, max_depth=6
# [34]	validation_0-rmse:6.31997
# [14:30:30] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 0 pruned nodes, max_depth=6
# [35]	validation_0-rmse:6.09688
# [14:30:30] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 0 pruned nodes, max_depth=6
# [36]	validation_0-rmse:5.8636
# [14:30:30] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 26 extra nodes, 0 pruned nodes, max_depth=6
# [37]	validation_0-rmse:5.68218
# [14:30:30] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 0 pruned nodes, max_depth=6
# [38]	validation_0-rmse:5.5599
# [14:30:30] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 0 pruned nodes, max_depth=5
# [39]	validation_0-rmse:5.43151
# [14:30:30] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 0 pruned nodes, max_depth=5
# [40]	validation_0-rmse:5.36148
# [14:30:30] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 0 pruned nodes, max_depth=6
# [41]	validation_0-rmse:5.27643
# [14:30:30] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 0 pruned nodes, max_depth=6
# [42]	validation_0-rmse:5.19053
# [14:30:30] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 0 pruned nodes, max_depth=6
# [43]	validation_0-rmse:5.14945
# [14:30:30] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 32 extra nodes, 0 pruned nodes, max_depth=6
# [44]	validation_0-rmse:5.09718
# [14:30:30] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 0 pruned nodes, max_depth=6
# [45]	validation_0-rmse:5.06478
# [14:30:30] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 26 extra nodes, 0 pruned nodes, max_depth=5
# [46]	validation_0-rmse:4.98037
# [14:30:30] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 26 extra nodes, 0 pruned nodes, max_depth=6
# [47]	validation_0-rmse:4.93554
# [14:30:30] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=6
# [48]	validation_0-rmse:4.93453
# [14:30:30] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 0 pruned nodes, max_depth=6
# [49]	validation_0-rmse:4.9031
# [14:30:30] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 28 extra nodes, 0 pruned nodes, max_depth=6
# [50]	validation_0-rmse:4.89539
# [14:30:30] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 0 pruned nodes, max_depth=6
# [51]	validation_0-rmse:4.89955
# [14:30:30] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 0 pruned nodes, max_depth=6
# [52]	validation_0-rmse:4.9101
# [14:30:30] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 0 pruned nodes, max_depth=6
# [53]	validation_0-rmse:4.89391
# [14:30:30] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 0 pruned nodes, max_depth=6
# [54]	validation_0-rmse:4.86717
# [14:30:30] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 32 extra nodes, 0 pruned nodes, max_depth=6
# [55]	validation_0-rmse:4.86211
# [14:30:30] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 0 pruned nodes, max_depth=6
# [56]	validation_0-rmse:4.88158
# [14:30:30] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 0 pruned nodes, max_depth=6
# [57]	validation_0-rmse:4.89351
# [14:30:30] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 26 extra nodes, 0 pruned nodes, max_depth=6
# [58]	validation_0-rmse:4.9047
# [14:30:30] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 0 pruned nodes, max_depth=6
# [59]	validation_0-rmse:4.91329
# [14:30:30] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 0 pruned nodes, max_depth=6
# [60]	validation_0-rmse:4.9126
# [14:30:30] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 32 extra nodes, 0 pruned nodes, max_depth=6
# [61]	validation_0-rmse:4.90816
# [14:30:30] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 36 extra nodes, 0 pruned nodes, max_depth=6
# [62]	validation_0-rmse:4.8892
# [14:30:30] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 28 extra nodes, 0 pruned nodes, max_depth=6
# [63]	validation_0-rmse:4.89654
# [14:30:30] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 0 pruned nodes, max_depth=6
# [64]	validation_0-rmse:4.87678
# [14:30:30] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 0 pruned nodes, max_depth=6
# [65]	validation_0-rmse:4.85421
# [14:30:30] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 26 extra nodes, 0 pruned nodes, max_depth=6
# [66]	validation_0-rmse:4.8479
# [14:30:30] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 38 extra nodes, 0 pruned nodes, max_depth=6
# [67]	validation_0-rmse:4.8325
# [14:30:30] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 0 pruned nodes, max_depth=6
# [68]	validation_0-rmse:4.82575
# [14:30:30] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 28 extra nodes, 0 pruned nodes, max_depth=6
# [69]	validation_0-rmse:4.81861
# [14:30:30] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 26 extra nodes, 0 pruned nodes, max_depth=6
# [70]	validation_0-rmse:4.8157
# [14:30:30] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 0 pruned nodes, max_depth=6
# [71]	validation_0-rmse:4.82051
# [14:30:30] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 28 extra nodes, 0 pruned nodes, max_depth=6
# [72]	validation_0-rmse:4.81447
# [14:30:30] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 28 extra nodes, 0 pruned nodes, max_depth=6
# [73]	validation_0-rmse:4.82341
# [14:30:30] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 32 extra nodes, 0 pruned nodes, max_depth=6
# [74]	validation_0-rmse:4.81682
# [14:30:30] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 0 pruned nodes, max_depth=6
# [75]	validation_0-rmse:4.81384
# [14:30:30] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 0 pruned nodes, max_depth=6
# [76]	validation_0-rmse:4.80503
# [14:30:30] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 0 pruned nodes, max_depth=6
# [77]	validation_0-rmse:4.80215
# [14:30:30] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 0 pruned nodes, max_depth=6
# [78]	validation_0-rmse:4.80445
# [14:30:30] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 32 extra nodes, 0 pruned nodes, max_depth=6
# [79]	validation_0-rmse:4.79068
# [14:30:30] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 34 extra nodes, 0 pruned nodes, max_depth=6
# [80]	validation_0-rmse:4.79496
# [14:30:30] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 0 pruned nodes, max_depth=6
# [81]	validation_0-rmse:4.79075
# [14:30:30] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 32 extra nodes, 0 pruned nodes, max_depth=6
# [82]	validation_0-rmse:4.7985
# [14:30:30] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 0 pruned nodes, max_depth=6
# [83]	validation_0-rmse:4.79025
# [14:30:30] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 0 pruned nodes, max_depth=6
# [84]	validation_0-rmse:4.77754
# [14:30:30] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 0 pruned nodes, max_depth=6
# [85]	validation_0-rmse:4.76882
# [14:30:30] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 34 extra nodes, 0 pruned nodes, max_depth=6
# [86]	validation_0-rmse:4.76993
# [14:30:30] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 32 extra nodes, 0 pruned nodes, max_depth=6
# [87]	validation_0-rmse:4.74468
# [14:30:30] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 0 pruned nodes, max_depth=6
# [88]	validation_0-rmse:4.74255
# [14:30:30] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 34 extra nodes, 0 pruned nodes, max_depth=6
# [89]	validation_0-rmse:4.75057
# [14:30:30] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 0 pruned nodes, max_depth=6
# [90]	validation_0-rmse:4.73902
# [14:30:30] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 0 pruned nodes, max_depth=6
# [91]	validation_0-rmse:4.73512
# [14:30:30] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 32 extra nodes, 0 pruned nodes, max_depth=6
# [92]	validation_0-rmse:4.71666
# [14:30:30] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 28 extra nodes, 0 pruned nodes, max_depth=6
# [93]	validation_0-rmse:4.71265
# [14:30:30] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 0 pruned nodes, max_depth=6
# [94]	validation_0-rmse:4.70482
# [14:30:30] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 0 pruned nodes, max_depth=6
# [95]	validation_0-rmse:4.71148
# [14:30:30] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 0 pruned nodes, max_depth=6
# [96]	validation_0-rmse:4.72635
# [14:30:30] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 0 pruned nodes, max_depth=6
# [97]	validation_0-rmse:4.73318
# [14:30:30] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 28 extra nodes, 0 pruned nodes, max_depth=6
# [98]	validation_0-rmse:4.72551
# [14:30:30] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=6
# [99]	validation_0-rmse:4.70984
# [14:30:30] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 28 extra nodes, 0 pruned nodes, max_depth=6
# [100]	validation_0-rmse:4.69753
# [14:30:30] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 0 pruned nodes, max_depth=6
# [101]	validation_0-rmse:4.68598
# [14:30:30] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 0 pruned nodes, max_depth=6
# [102]	validation_0-rmse:4.69698
# [14:30:30] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 0 pruned nodes, max_depth=6
# [103]	validation_0-rmse:4.69199
# [14:30:30] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 0 pruned nodes, max_depth=6
# [104]	validation_0-rmse:4.68161
# [14:30:30] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 32 extra nodes, 0 pruned nodes, max_depth=6
# [105]	validation_0-rmse:4.67012
# [14:30:30] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 26 extra nodes, 0 pruned nodes, max_depth=6
# [106]	validation_0-rmse:4.66334
# [14:30:30] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 36 extra nodes, 0 pruned nodes, max_depth=6
# [107]	validation_0-rmse:4.65053
# [14:30:30] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 0 pruned nodes, max_depth=6
# [108]	validation_0-rmse:4.65127
# [14:30:30] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 28 extra nodes, 0 pruned nodes, max_depth=6
# [109]	validation_0-rmse:4.65105
# [14:30:30] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 36 extra nodes, 0 pruned nodes, max_depth=6
# [110]	validation_0-rmse:4.65723
# [14:30:30] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 32 extra nodes, 0 pruned nodes, max_depth=6
# [111]	validation_0-rmse:4.65462
# [14:30:30] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 0 pruned nodes, max_depth=6
# [112]	validation_0-rmse:4.65814
# [14:30:30] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 32 extra nodes, 0 pruned nodes, max_depth=6
# [113]	validation_0-rmse:4.6485
# [14:30:30] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 0 pruned nodes, max_depth=6
# [114]	validation_0-rmse:4.65463
# [14:30:30] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 28 extra nodes, 0 pruned nodes, max_depth=6
# [115]	validation_0-rmse:4.64302
# [14:30:30] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 28 extra nodes, 0 pruned nodes, max_depth=6
# [116]	validation_0-rmse:4.62634
# [14:30:30] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 0 pruned nodes, max_depth=6
# [117]	validation_0-rmse:4.62288
# [14:30:30] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 0 pruned nodes, max_depth=6
# [118]	validation_0-rmse:4.62242
# [14:30:30] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 32 extra nodes, 0 pruned nodes, max_depth=6
# [119]	validation_0-rmse:4.6193
# [14:30:30] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 36 extra nodes, 0 pruned nodes, max_depth=6
# [120]	validation_0-rmse:4.61014
# [14:30:30] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 26 extra nodes, 0 pruned nodes, max_depth=6
# [121]	validation_0-rmse:4.59616
# [14:30:30] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 40 extra nodes, 0 pruned nodes, max_depth=6
# [122]	validation_0-rmse:4.60437
# [14:30:30] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 0 pruned nodes, max_depth=6
# [123]	validation_0-rmse:4.60627
# [14:30:30] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 0 pruned nodes, max_depth=6
# [124]	validation_0-rmse:4.61692
# [14:30:30] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 34 extra nodes, 0 pruned nodes, max_depth=6
# [125]	validation_0-rmse:4.62206
# [14:30:30] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 38 extra nodes, 0 pruned nodes, max_depth=6
# [126]	validation_0-rmse:4.62251
# [14:30:30] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 28 extra nodes, 0 pruned nodes, max_depth=6
# [127]	validation_0-rmse:4.62652
# [14:30:30] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 0 pruned nodes, max_depth=6
# [128]	validation_0-rmse:4.63347
# [14:30:30] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 26 extra nodes, 0 pruned nodes, max_depth=6
# [129]	validation_0-rmse:4.63613
# [14:30:30] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 0 pruned nodes, max_depth=6
# [130]	validation_0-rmse:4.63197
# [14:30:30] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 0 pruned nodes, max_depth=6
# [131]	validation_0-rmse:4.63343
# [14:30:30] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 0 pruned nodes, max_depth=6
# [132]	validation_0-rmse:4.6306
# [14:30:30] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 36 extra nodes, 0 pruned nodes, max_depth=6
# [133]	validation_0-rmse:4.62795
# [14:30:30] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 0 pruned nodes, max_depth=6
# [134]	validation_0-rmse:4.62081
# [14:30:30] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 36 extra nodes, 0 pruned nodes, max_depth=6
# [135]	validation_0-rmse:4.61381
# [14:30:30] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 28 extra nodes, 0 pruned nodes, max_depth=6
# [136]	validation_0-rmse:4.60529
# [14:30:30] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 0 pruned nodes, max_depth=6
# [137]	validation_0-rmse:4.60081
# [14:30:30] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 28 extra nodes, 0 pruned nodes, max_depth=6
# [138]	validation_0-rmse:4.5917
# [14:30:30] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 0 pruned nodes, max_depth=6
# [139]	validation_0-rmse:4.59023
# [14:30:31] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 0 pruned nodes, max_depth=6
# [140]	validation_0-rmse:4.58765
# [14:30:31] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 0 pruned nodes, max_depth=6
# [141]	validation_0-rmse:4.58908
# [14:30:31] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 0 pruned nodes, max_depth=6
# [142]	validation_0-rmse:4.59014
# [14:30:31] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 0 pruned nodes, max_depth=6
# [143]	validation_0-rmse:4.5933
# [14:30:31] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 0 pruned nodes, max_depth=6
# [144]	validation_0-rmse:4.58583
# [14:30:31] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 0 pruned nodes, max_depth=6
# [145]	validation_0-rmse:4.59065
# [14:30:31] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 32 extra nodes, 0 pruned nodes, max_depth=6
# [146]	validation_0-rmse:4.58277
# [14:30:31] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 0 pruned nodes, max_depth=6
# [147]	validation_0-rmse:4.58245
# [14:30:31] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 28 extra nodes, 0 pruned nodes, max_depth=6
# [148]	validation_0-rmse:4.5833
# [14:30:31] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 36 extra nodes, 0 pruned nodes, max_depth=6
# [149]	validation_0-rmse:4.58945
# [14:30:31] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 32 extra nodes, 0 pruned nodes, max_depth=6
# [150]	validation_0-rmse:4.58171
# [14:30:31] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 34 extra nodes, 0 pruned nodes, max_depth=6
# [151]	validation_0-rmse:4.5867
# [14:30:31] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 34 extra nodes, 0 pruned nodes, max_depth=6
# [152]	validation_0-rmse:4.57336
# [14:30:31] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 32 extra nodes, 0 pruned nodes, max_depth=6
# [153]	validation_0-rmse:4.56946
# [14:30:31] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 26 extra nodes, 0 pruned nodes, max_depth=6
# [154]	validation_0-rmse:4.57001
# [14:30:31] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 0 pruned nodes, max_depth=6
# [155]	validation_0-rmse:4.56578
# [14:30:31] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 32 extra nodes, 0 pruned nodes, max_depth=6
# [156]	validation_0-rmse:4.56186
# [14:30:31] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 0 pruned nodes, max_depth=6
# [157]	validation_0-rmse:4.56063
# [14:30:31] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=6
# [158]	validation_0-rmse:4.56457
# [14:30:31] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 26 extra nodes, 0 pruned nodes, max_depth=6
# [159]	validation_0-rmse:4.56534
# [14:30:31] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 28 extra nodes, 0 pruned nodes, max_depth=6
# [160]	validation_0-rmse:4.55757
# [14:30:31] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 28 extra nodes, 0 pruned nodes, max_depth=6
# [161]	validation_0-rmse:4.55707
# [14:30:31] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 26 extra nodes, 0 pruned nodes, max_depth=6
# [162]	validation_0-rmse:4.55812
# [14:30:31] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 28 extra nodes, 0 pruned nodes, max_depth=6
# [163]	validation_0-rmse:4.55478
# [14:30:31] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 0 pruned nodes, max_depth=6
# [164]	validation_0-rmse:4.55631
# [14:30:31] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 0 pruned nodes, max_depth=6
# [165]	validation_0-rmse:4.55276
# [14:30:31] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 32 extra nodes, 0 pruned nodes, max_depth=6
# [166]	validation_0-rmse:4.5517
# [14:30:31] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 36 extra nodes, 0 pruned nodes, max_depth=6
# [167]	validation_0-rmse:4.55328
# [14:30:31] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 26 extra nodes, 0 pruned nodes, max_depth=6
# [168]	validation_0-rmse:4.55086
# [14:30:31] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 38 extra nodes, 0 pruned nodes, max_depth=6
# [169]	validation_0-rmse:4.55119
# [14:30:31] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 40 extra nodes, 0 pruned nodes, max_depth=6
# [170]	validation_0-rmse:4.55066
# [14:30:31] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 26 extra nodes, 0 pruned nodes, max_depth=6
# [171]	validation_0-rmse:4.54383
# [14:30:31] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 34 extra nodes, 0 pruned nodes, max_depth=6
# [172]	validation_0-rmse:4.54673
# [14:30:31] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 26 extra nodes, 0 pruned nodes, max_depth=6
# [173]	validation_0-rmse:4.54697
# [14:30:31] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 34 extra nodes, 0 pruned nodes, max_depth=6
# [174]	validation_0-rmse:4.54831
# [14:30:31] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 0 pruned nodes, max_depth=6
# [175]	validation_0-rmse:4.54729
# [14:30:31] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 34 extra nodes, 0 pruned nodes, max_depth=6
# [176]	validation_0-rmse:4.53626
# [14:30:31] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 26 extra nodes, 0 pruned nodes, max_depth=6
# [177]	validation_0-rmse:4.53425
# [14:30:31] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 0 pruned nodes, max_depth=6
# [178]	validation_0-rmse:4.53275
# [14:30:31] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 0 pruned nodes, max_depth=6
# [179]	validation_0-rmse:4.53815
# [14:30:31] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 0 pruned nodes, max_depth=6
# [180]	validation_0-rmse:4.53747
# [14:30:31] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 0 pruned nodes, max_depth=6
# [181]	validation_0-rmse:4.53885
# [14:30:31] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 28 extra nodes, 0 pruned nodes, max_depth=6
# [182]	validation_0-rmse:4.53476
# [14:30:31] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 36 extra nodes, 0 pruned nodes, max_depth=6
# [183]	validation_0-rmse:4.53191
# [14:30:31] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 0 pruned nodes, max_depth=6
# [184]	validation_0-rmse:4.53049
# [14:30:31] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 0 pruned nodes, max_depth=6
# [185]	validation_0-rmse:4.52858
# [14:30:31] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 32 extra nodes, 0 pruned nodes, max_depth=6
# [186]	validation_0-rmse:4.52704
# [14:30:31] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 0 pruned nodes, max_depth=6
# [187]	validation_0-rmse:4.52261
# [14:30:31] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 26 extra nodes, 0 pruned nodes, max_depth=6
# [188]	validation_0-rmse:4.52426
# [14:30:31] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 28 extra nodes, 0 pruned nodes, max_depth=6
# [189]	validation_0-rmse:4.51788
# [14:30:31] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 28 extra nodes, 0 pruned nodes, max_depth=6
# [190]	validation_0-rmse:4.51858
# [14:30:31] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 0 pruned nodes, max_depth=6
# [191]	validation_0-rmse:4.52033
# [14:30:31] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 0 pruned nodes, max_depth=6
# [192]	validation_0-rmse:4.52049
# [14:30:31] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 26 extra nodes, 0 pruned nodes, max_depth=6
# [193]	validation_0-rmse:4.51813
# [14:30:31] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 26 extra nodes, 0 pruned nodes, max_depth=6
# [194]	validation_0-rmse:4.51819
# [14:30:31] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 34 extra nodes, 0 pruned nodes, max_depth=6
# [195]	validation_0-rmse:4.51632
# [14:30:31] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 26 extra nodes, 0 pruned nodes, max_depth=6
# [196]	validation_0-rmse:4.51685
# [14:30:31] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 26 extra nodes, 0 pruned nodes, max_depth=6
# [197]	validation_0-rmse:4.51416
# [14:30:31] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 32 extra nodes, 0 pruned nodes, max_depth=6
# [198]	validation_0-rmse:4.51157
# [14:30:31] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 0 pruned nodes, max_depth=6
# [199]	validation_0-rmse:4.51288
# [14:30:31] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 34 extra nodes, 0 pruned nodes, max_depth=6
# [200]	validation_0-rmse:4.51356
# [14:30:31] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 0 pruned nodes, max_depth=6
# [201]	validation_0-rmse:4.51249
# [14:30:31] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 42 extra nodes, 0 pruned nodes, max_depth=6
# [202]	validation_0-rmse:4.51327
# [14:30:31] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 0 pruned nodes, max_depth=6
# [203]	validation_0-rmse:4.50963
# [14:30:31] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 32 extra nodes, 0 pruned nodes, max_depth=6
# [204]	validation_0-rmse:4.51133
# [14:30:31] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 0 pruned nodes, max_depth=6
# [205]	validation_0-rmse:4.51459
# [14:30:31] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 34 extra nodes, 0 pruned nodes, max_depth=6
# [206]	validation_0-rmse:4.51196
# [14:30:31] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 0 pruned nodes, max_depth=6
# [207]	validation_0-rmse:4.51014
# [14:30:31] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 0 pruned nodes, max_depth=6
# [208]	validation_0-rmse:4.51144
# [14:30:31] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 0 pruned nodes, max_depth=6
# [209]	validation_0-rmse:4.5129
# [14:30:31] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 0 pruned nodes, max_depth=6
# [210]	validation_0-rmse:4.51146
# [14:30:31] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 0 pruned nodes, max_depth=6
# [211]	validation_0-rmse:4.5141
# [14:30:31] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 26 extra nodes, 0 pruned nodes, max_depth=6
# [212]	validation_0-rmse:4.51255
# [14:30:31] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 34 extra nodes, 0 pruned nodes, max_depth=6
# [213]	validation_0-rmse:4.51153
# [14:30:31] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 32 extra nodes, 0 pruned nodes, max_depth=6
# [214]	validation_0-rmse:4.51068
# [14:30:31] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 26 extra nodes, 0 pruned nodes, max_depth=6
# [215]	validation_0-rmse:4.51102
# ...
# [927]	validation_0-rmse:4.49179
# [14:30:34] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [928]	validation_0-rmse:4.49179
# [14:30:34] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=6
# [929]	validation_0-rmse:4.49178
# [14:30:34] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=5
# [930]	validation_0-rmse:4.49178
# [14:30:34] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=6
# [931]	validation_0-rmse:4.49177
# [14:30:34] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=3
# [932]	validation_0-rmse:4.49177
# [14:30:34] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=6
# [933]	validation_0-rmse:4.49178
# [14:30:34] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 0 pruned nodes, max_depth=4
# [934]	validation_0-rmse:4.49178
# [14:30:34] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 0 pruned nodes, max_depth=4
# [935]	validation_0-rmse:4.49178
# [14:30:34] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=5
# [936]	validation_0-rmse:4.49178
# [14:30:34] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [937]	validation_0-rmse:4.49178
# [14:30:34] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=5
# [938]	validation_0-rmse:4.49178
# [14:30:34] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=6
# [939]	validation_0-rmse:4.49179
# [14:30:34] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 0 pruned nodes, max_depth=5
# [940]	validation_0-rmse:4.49178
# [14:30:34] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=4
# [941]	validation_0-rmse:4.49179
# [14:30:34] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=4
# [942]	validation_0-rmse:4.49179
# [14:30:34] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=4
# [943]	validation_0-rmse:4.49179
# [14:30:34] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=6
# [944]	validation_0-rmse:4.49179
# [14:30:34] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 0 pruned nodes, max_depth=5
# [945]	validation_0-rmse:4.49179
# [14:30:34] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=4
# [946]	validation_0-rmse:4.49179
# [14:30:34] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=4
# [947]	validation_0-rmse:4.49179
# [14:30:34] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=4
# [948]	validation_0-rmse:4.49179
# [14:30:34] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [949]	validation_0-rmse:4.49179
# [14:30:34] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=4
# [950]	validation_0-rmse:4.4918
# [14:30:34] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 0 pruned nodes, max_depth=3
# [951]	validation_0-rmse:4.4918
# [14:30:34] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 0 pruned nodes, max_depth=6
# [952]	validation_0-rmse:4.4918
# [14:30:34] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=6
# [953]	validation_0-rmse:4.4918
# [14:30:34] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 0 pruned nodes, max_depth=4
# [954]	validation_0-rmse:4.4918
# [14:30:34] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=5
# [955]	validation_0-rmse:4.4918
# [14:30:34] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=4
# [956]	validation_0-rmse:4.4918
# [14:30:34] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=6
# [957]	validation_0-rmse:4.49181
# [14:30:34] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=5
# [958]	validation_0-rmse:4.4918
# [14:30:34] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=6
# [959]	validation_0-rmse:4.4918
# [14:30:34] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=3
# [960]	validation_0-rmse:4.4918
# [14:30:34] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=3
# [961]	validation_0-rmse:4.4918
# [14:30:34] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=4
# [962]	validation_0-rmse:4.4918
# [14:30:34] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=6
# [963]	validation_0-rmse:4.4918
# [14:30:34] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=5
# [964]	validation_0-rmse:4.4918
# [14:30:34] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 0 pruned nodes, max_depth=4
# [965]	validation_0-rmse:4.4918
# [14:30:34] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [966]	validation_0-rmse:4.49179
# [14:30:34] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 0 pruned nodes, max_depth=5
# [967]	validation_0-rmse:4.4918
# [14:30:34] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [968]	validation_0-rmse:4.49179
# [14:30:34] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=5
# [969]	validation_0-rmse:4.49179
# [14:30:34] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=4
# [970]	validation_0-rmse:4.4918
# [14:30:34] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=5
# [971]	validation_0-rmse:4.49179
# [14:30:34] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [972]	validation_0-rmse:4.4918
# [14:30:34] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=6
# [973]	validation_0-rmse:4.49179
# [14:30:34] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [974]	validation_0-rmse:4.49179
# [14:30:34] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=6
# [975]	validation_0-rmse:4.49179
# [14:30:34] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [976]	validation_0-rmse:4.49179
# [14:30:34] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=4
# [977]	validation_0-rmse:4.49179
# [14:30:34] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [978]	validation_0-rmse:4.49179
# [14:30:34] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [979]	validation_0-rmse:4.49179
# [14:30:34] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [980]	validation_0-rmse:4.49178
# [14:30:34] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [981]	validation_0-rmse:4.49178
# [14:30:34] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=3
# [982]	validation_0-rmse:4.49178
# [14:30:34] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 0 pruned nodes, max_depth=5
# [983]	validation_0-rmse:4.49178
# [14:30:34] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 0 pruned nodes, max_depth=6
# [984]	validation_0-rmse:4.49179
# [14:30:34] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 0 pruned nodes, max_depth=4
# [985]	validation_0-rmse:4.49179
# [14:30:34] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=6
# [986]	validation_0-rmse:4.49179
# [14:30:34] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [987]	validation_0-rmse:4.49179
# [14:30:34] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 2 extra nodes, 0 pruned nodes, max_depth=1
# [988]	validation_0-rmse:4.49179
# [14:30:34] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [989]	validation_0-rmse:4.49179
# [14:30:34] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [990]	validation_0-rmse:4.49179
# [14:30:34] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 0 pruned nodes, max_depth=4
# [991]	validation_0-rmse:4.49179
# [14:30:34] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [992]	validation_0-rmse:4.49178
# [14:30:34] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=5
# [993]	validation_0-rmse:4.49179
# [14:30:34] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [994]	validation_0-rmse:4.49179
# [14:30:34] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [995]	validation_0-rmse:4.49179
# [14:30:34] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=4
# [996]	validation_0-rmse:4.49179
# [14:30:34] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [997]	validation_0-rmse:4.49178
# [14:30:34] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=5
# [998]	validation_0-rmse:4.49178
# [14:30:34] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=4
# [999]	validation_0-rmse:4.49178
# Duration: 5.0471954345703125s

# %%
# Plot feature importance
figsize=(7,7)
fig, ax = plt.subplots(1,1,figsize=figsize)
plot_importance(model, ax=ax,height = 1)

# %%
# predict sales in test dataset
test_predictions = model.predict(X_test).flatten()

# scatter plot of True vs Predicted values
plt.scatter(y_test, test_predictions)
plt.xlabel('True Values $')
plt.ylabel('Predictions $')
plt.axis('equal')
plt.axis('square')
plt.xlim([100,plt.xlim()[1]])
plt.ylim([100,plt.ylim()[1]])
_ = plt.plot([0, 1000], [0, 1000])

# %%
# Histogram of error values
error = test_predictions - y_test
plt.hist(error, bins = 25)
plt.xlabel("Prediction Error $")
_ = plt.ylabel("Count")

# %% [markdown]
# # Anomaly detection approach
#
# Loss > Threshold ise = anomaly > bubble mi demek?

# %%
# Data normalization
scaler = MinMaxScaler(feature_range=(0, 1))
X_train = scaler.fit_transform(df_train[:-15]) # Healthy/normal data
X_test = scaler.fit_transform(df_train[-15:]) # Unhealthy/anomaly data

# %%
X_train.shape
# Out:
# (189, 8)

# %%
# Reshape for LSTM
X_train = X_train.reshape(X_train.shape[0], 1, X_train.shape[1])
X_test = X_test.reshape(X_test.shape[0], 1, X_test.shape[1])

# %%
# define the autoencoder network model
def autoencoder_model(X):
    inputs = Input(shape=(X.shape[1], X.shape[2]))
    L1 = LSTM(16, activation='relu', return_sequences=True, 
              kernel_regularizer=regularizers.l2(0.00))(inputs)
    L2 = LSTM(4, activation='relu', return_sequences=False)(L1)
    L3 = RepeatVector(X.shape[1])(L2)
    L4 = LSTM(4, activation='relu', return_sequences=True)(L3)
    L5 = LSTM(16, activation='relu', return_sequences=True)(L4)
    output = TimeDistributed(Dense(X.shape[2]))(L5)    
    model = Model(inputs=inputs, outputs=output)
    return model

# %%
# create the autoencoder model
model = autoencoder_model(X_train)
model.compile(optimizer='adam', loss='mae')
model.summary()
# Out:
# WARNING:tensorflow:From /home/ipcvlab/anaconda2/envs/data_science/lib/python3.6/site-packages/tensorflow/python/ops/resource_variable_ops.py:435: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 1, 8)              0
# _________________________________________________________________
# lstm (LSTM)                  (None, 1, 16)             1600
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 4)                 336
# _________________________________________________________________
# repeat_vector (RepeatVector) (None, 1, 4)              0
# _________________________________________________________________
# lstm_2 (LSTM)                (None, 1, 4)              144
# _________________________________________________________________
# lstm_3 (LSTM)                (None, 1, 16)             1344
# _________________________________________________________________
# time_distributed (TimeDistri (None, 1, 8)              136
# =================================================================
# Total params: 3,560
# Trainable params: 3,560
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = model.fit(X_train, X_train, epochs=100, batch_size=10,
                    validation_split=0.05).history
# Out:
# Train on 179 samples, validate on 10 samples
# WARNING:tensorflow:From /home/ipcvlab/anaconda2/envs/data_science/lib/python3.6/site-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Epoch 1/100
# 179/179 [==============================] - 6s 32ms/sample - loss: 0.2658 - val_loss: 0.5141
# Epoch 2/100
# 179/179 [==============================] - 0s 2ms/sample - loss: 0.2476 - val_loss: 0.4942
# Epoch 3/100
# 179/179 [==============================] - 0s 2ms/sample - loss: 0.2313 - val_loss: 0.4739
# Epoch 4/100
# 179/179 [==============================] - 1s 3ms/sample - loss: 0.2179 - val_loss: 0.4544
# Epoch 5/100
# 179/179 [==============================] - 0s 2ms/sample - loss: 0.2076 - val_loss: 0.4362
# Epoch 6/100
# 179/179 [==============================] - 0s 1ms/sample - loss: 0.1996 - val_loss: 0.4212
# Epoch 7/100
# 179/179 [==============================] - 0s 2ms/sample - loss: 0.1931 - val_loss: 0.4078
# Epoch 8/100
# 179/179 [==============================] - 0s 1ms/sample - loss: 0.1872 - val_loss: 0.3922
# Epoch 9/100
# 179/179 [==============================] - 0s 2ms/sample - loss: 0.1816 - val_loss: 0.3680
# Epoch 10/100
# 179/179 [==============================] - 0s 2ms/sample - loss: 0.1752 - val_loss: 0.3295
# Epoch 11/100
# 179/179 [==============================] - 0s 3ms/sample - loss: 0.1662 - val_loss: 0.2405
# Epoch 12/100
# 179/179 [==============================] - 0s 1ms/sample - loss: 0.1504 - val_loss: 0.2087
# Epoch 13/100
# 179/179 [==============================] - 0s 2ms/sample - loss: 0.1384 - val_loss: 0.3208
# Epoch 14/100
# 179/179 [==============================] - 0s 2ms/sample - loss: 0.1288 - val_loss: 0.2733
# Epoch 15/100
# 179/179 [==============================] - 0s 2ms/sample - loss: 0.1238 - val_loss: 0.1602
# Epoch 16/100
# 179/179 [==============================] - 0s 2ms/sample - loss: 0.1184 - val_loss: 0.2676
# Epoch 17/100
# 179/179 [==============================] - 0s 2ms/sample - loss: 0.1144 - val_loss: 0.1973
# Epoch 18/100
# 179/179 [==============================] - 1s 3ms/sample - loss: 0.1087 - val_loss: 0.1978
# Epoch 19/100
# 179/179 [==============================] - 0s 2ms/sample - loss: 0.1046 - val_loss: 0.1716
# Epoch 20/100
# 179/179 [==============================] - 0s 2ms/sample - loss: 0.1008 - val_loss: 0.1962
# Epoch 21/100
# 179/179 [==============================] - 0s 2ms/sample - loss: 0.0972 - val_loss: 0.1606
# Epoch 22/100
# 179/179 [==============================] - 0s 2ms/sample - loss: 0.0936 - val_loss: 0.1569
# Epoch 23/100
# 179/179 [==============================] - 0s 2ms/sample - loss: 0.0898 - val_loss: 0.1476
# Epoch 24/100
# 179/179 [==============================] - 1s 3ms/sample - loss: 0.0858 - val_loss: 0.1366
# Epoch 25/100
# 179/179 [==============================] - 0s 2ms/sample - loss: 0.0817 - val_loss: 0.1193
# Epoch 26/100
# 179/179 [==============================] - 0s 2ms/sample - loss: 0.0775 - val_loss: 0.1126
# Epoch 27/100
# 179/179 [==============================] - 0s 2ms/sample - loss: 0.0741 - val_loss: 0.1163
# Epoch 28/100
# 179/179 [==============================] - 0s 2ms/sample - loss: 0.0717 - val_loss: 0.1104
# Epoch 29/100
# 179/179 [==============================] - 0s 2ms/sample - loss: 0.0686 - val_loss: 0.1089
# Epoch 30/100
# 179/179 [==============================] - 1s 3ms/sample - loss: 0.0663 - val_loss: 0.1051
# Epoch 31/100
# 179/179 [==============================] - 0s 2ms/sample - loss: 0.0637 - val_loss: 0.1078
# Epoch 32/100
# 179/179 [==============================] - 0s 2ms/sample - loss: 0.0607 - val_loss: 0.1081
# Epoch 33/100
# 179/179 [==============================] - 0s 2ms/sample - loss: 0.0573 - val_loss: 0.1032
# Epoch 34/100
# 179/179 [==============================] - 0s 2ms/sample - loss: 0.0556 - val_loss: 0.1157
# Epoch 35/100
# 179/179 [==============================] - 1s 3ms/sample - loss: 0.0543 - val_loss: 0.1086
# Epoch 36/100
# 179/179 [==============================] - 0s 2ms/sample - loss: 0.0529 - val_loss: 0.1046
# Epoch 37/100
# 179/179 [==============================] - 0s 2ms/sample - loss: 0.0519 - val_loss: 0.1075
# Epoch 38/100
# 179/179 [==============================] - 0s 2ms/sample - loss: 0.0518 - val_loss: 0.1114
# Epoch 39/100
# 179/179 [==============================] - 0s 2ms/sample - loss: 0.0512 - val_loss: 0.1042
# Epoch 40/100
# 179/179 [==============================] - 0s 2ms/sample - loss: 0.0506 - val_loss: 0.1089
# Epoch 41/100
# 179/179 [==============================] - 1s 3ms/sample - loss: 0.0508 - val_loss: 0.1046
# Epoch 42/100
# 179/179 [==============================] - 0s 2ms/sample - loss: 0.0501 - val_loss: 0.0998
# Epoch 43/100
# 179/179 [==============================] - 0s 3ms/sample - loss: 0.0498 - val_loss: 0.1071
# Epoch 44/100
# 179/179 [==============================] - 0s 2ms/sample - loss: 0.0493 - val_loss: 0.0971
# Epoch 45/100
# 179/179 [==============================] - 0s 2ms/sample - loss: 0.0487 - val_loss: 0.1030
# Epoch 46/100
# 179/179 [==============================] - 1s 3ms/sample - loss: 0.0483 - val_loss: 0.0987
# Epoch 47/100
# 179/179 [==============================] - 0s 2ms/sample - loss: 0.0480 - val_loss: 0.0968
# Epoch 48/100
# 179/179 [==============================] - 0s 2ms/sample - loss: 0.0476 - val_loss: 0.1031
# Epoch 49/100
# 179/179 [==============================] - 0s 2ms/sample - loss: 0.0471 - val_loss: 0.0986
# Epoch 50/100
# 179/179 [==============================] - 0s 1ms/sample - loss: 0.0470 - val_loss: 0.1020
# Epoch 51/100
# 179/179 [==============================] - 0s 2ms/sample - loss: 0.0466 - val_loss: 0.0977
# Epoch 52/100
# 179/179 [==============================] - 0s 2ms/sample - loss: 0.0464 - val_loss: 0.0989
# Epoch 53/100
# 179/179 [==============================] - 1s 3ms/sample - loss: 0.0473 - val_loss: 0.0938
# Epoch 54/100
# 179/179 [==============================] - 0s 2ms/sample - loss: 0.0460 - val_loss: 0.0957
# Epoch 55/100
# 179/179 [==============================] - 0s 1ms/sample - loss: 0.0455 - val_loss: 0.1017
# Epoch 56/100
# 179/179 [==============================] - 0s 2ms/sample - loss: 0.0453 - val_loss: 0.1014
# Epoch 57/100
# 179/179 [==============================] - 0s 1ms/sample - loss: 0.0453 - val_loss: 0.0989
# Epoch 58/100
# 179/179 [==============================] - 0s 2ms/sample - loss: 0.0448 - val_loss: 0.1024
# Epoch 59/100
# 179/179 [==============================] - 1s 3ms/sample - loss: 0.0445 - val_loss: 0.1030
# Epoch 60/100
# 179/179 [==============================] - 0s 2ms/sample - loss: 0.0446 - val_loss: 0.1035
# Epoch 61/100
# 179/179 [==============================] - 0s 2ms/sample - loss: 0.0442 - val_loss: 0.1059
# Epoch 62/100
# 179/179 [==============================] - 0s 2ms/sample - loss: 0.0441 - val_loss: 0.1027
# Epoch 63/100
# 179/179 [==============================] - 0s 2ms/sample - loss: 0.0438 - val_loss: 0.1000
# Epoch 64/100
# 179/179 [==============================] - 0s 2ms/sample - loss: 0.0438 - val_loss: 0.1028
# Epoch 65/100
# 179/179 [==============================] - 1s 3ms/sample - loss: 0.0437 - val_loss: 0.1009
# Epoch 66/100
# 179/179 [==============================] - 0s 1ms/sample - loss: 0.0435 - val_loss: 0.1018
# Epoch 67/100
# 179/179 [==============================] - 0s 1ms/sample - loss: 0.0432 - val_loss: 0.1014
# Epoch 68/100
# 179/179 [==============================] - 0s 2ms/sample - loss: 0.0431 - val_loss: 0.1034
# Epoch 69/100
# 179/179 [==============================] - 0s 2ms/sample - loss: 0.0430 - val_loss: 0.1026
# Epoch 70/100
# 179/179 [==============================] - 0s 1ms/sample - loss: 0.0430 - val_loss: 0.1051
# Epoch 71/100
# 179/179 [==============================] - 0s 1ms/sample - loss: 0.0430 - val_loss: 0.1010
# Epoch 72/100
# 179/179 [==============================] - 0s 1ms/sample - loss: 0.0429 - val_loss: 0.1023
# Epoch 73/100
# 179/179 [==============================] - 1s 3ms/sample - loss: 0.0424 - val_loss: 0.1037
# Epoch 74/100
# 179/179 [==============================] - 0s 2ms/sample - loss: 0.0423 - val_loss: 0.1019
# Epoch 75/100
# 179/179 [==============================] - 0s 2ms/sample - loss: 0.0424 - val_loss: 0.0999
# Epoch 76/100
# 179/179 [==============================] - 0s 2ms/sample - loss: 0.0426 - val_loss: 0.1012
# Epoch 77/100
# 179/179 [==============================] - 0s 2ms/sample - loss: 0.0421 - val_loss: 0.1004
# Epoch 78/100
# 179/179 [==============================] - 0s 2ms/sample - loss: 0.0421 - val_loss: 0.1005
# Epoch 79/100
# 179/179 [==============================] - 0s 2ms/sample - loss: 0.0419 - val_loss: 0.1018
# Epoch 80/100
# 179/179 [==============================] - 0s 1ms/sample - loss: 0.0418 - val_loss: 0.0985
# Epoch 81/100
# 179/179 [==============================] - 0s 2ms/sample - loss: 0.0416 - val_loss: 0.1019
# Epoch 82/100
# 179/179 [==============================] - 0s 2ms/sample - loss: 0.0418 - val_loss: 0.1032
# Epoch 83/100
# 179/179 [==============================] - 0s 2ms/sample - loss: 0.0417 - val_loss: 0.0999
# Epoch 84/100
# 179/179 [==============================] - 0s 1ms/sample - loss: 0.0414 - val_loss: 0.0993
# Epoch 85/100
# 179/179 [==============================] - 0s 1ms/sample - loss: 0.0417 - val_loss: 0.1001
# Epoch 86/100
# 179/179 [==============================] - 0s 1ms/sample - loss: 0.0415 - val_loss: 0.1003
# Epoch 87/100
# 179/179 [==============================] - 0s 3ms/sample - loss: 0.0413 - val_loss: 0.1003
# Epoch 88/100
# 179/179 [==============================] - 0s 2ms/sample - loss: 0.0412 - val_loss: 0.0995
# Epoch 89/100
# 179/179 [==============================] - 0s 2ms/sample - loss: 0.0411 - val_loss: 0.0983
# Epoch 90/100
# 179/179 [==============================] - 0s 1ms/sample - loss: 0.0412 - val_loss: 0.0984
# Epoch 91/100
# 179/179 [==============================] - 0s 1ms/sample - loss: 0.0411 - val_loss: 0.0993
# Epoch 92/100
# 179/179 [==============================] - 0s 1ms/sample - loss: 0.0410 - val_loss: 0.0979
# Epoch 93/100
# 179/179 [==============================] - 0s 1ms/sample - loss: 0.0409 - val_loss: 0.0965
# Epoch 94/100
# 179/179 [==============================] - 0s 3ms/sample - loss: 0.0407 - val_loss: 0.0986
# Epoch 95/100
# 179/179 [==============================] - 0s 1ms/sample - loss: 0.0407 - val_loss: 0.0964
# Epoch 96/100
# 179/179 [==============================] - 0s 1ms/sample - loss: 0.0409 - val_loss: 0.0995
# Epoch 97/100
# 179/179 [==============================] - 0s 1ms/sample - loss: 0.0407 - val_loss: 0.0989
# Epoch 98/100
# 179/179 [==============================] - 0s 2ms/sample - loss: 0.0407 - val_loss: 0.0955
# Epoch 99/100
# 179/179 [==============================] - 0s 2ms/sample - loss: 0.0405 - val_loss: 0.0965
# Epoch 100/100
# 179/179 [==============================] - 0s 1ms/sample - loss: 0.0406 - val_loss: 0.0992

# %%
# plot the training losses
fig, ax = plt.subplots(figsize=(14, 6), dpi=80)
ax.plot(history['loss'], 'b', label='Train', linewidth=2)
ax.plot(history['val_loss'], 'r', label='Validation', linewidth=2)
ax.set_title('Model loss', fontsize=16)
ax.set_ylabel('Loss (mae)')
ax.set_xlabel('Epoch')
ax.legend(loc='upper right')
plt.show()

# %%
# plot the loss distribution of the training set
X_pred = model.predict(X_train)
X_pred = X_pred.reshape(X_pred.shape[0], X_pred.shape[2])
X_pred = pd.DataFrame(X_pred, columns=df_train.columns)
X_pred.index = df_train[:-15].index

scored = pd.DataFrame(index=df_train[:-15].index)
Xtrain = X_train.reshape(X_train.shape[0], X_train.shape[2])
scored['Loss_mae'] = np.mean(np.abs(X_pred-Xtrain), axis = 1)
plt.figure(figsize=(16,9), dpi=80)
plt.title('Loss Distribution', fontsize=16)
sns.distplot(scored['Loss_mae'], bins = 20, kde= True, color = 'blue');
plt.xlim([0.0,.5])

#Out[17]:
#(0.0, 0.5)
# Out:
# (0.0, 0.5)

# %%
# calculate the loss on the test set
X_pred = model.predict(X_test)
X_pred = X_pred.reshape(X_pred.shape[0], X_pred.shape[2])
X_pred = pd.DataFrame(X_pred, columns=df_train.columns)
X_pred.index = df_train[-15:].index

scored = pd.DataFrame(index=df_train[-15:].index)
Xtest = X_test.reshape(X_test.shape[0], X_test.shape[2])
scored['Loss_mae'] = np.mean(np.abs(X_pred-Xtest), axis = 1)
scored['Threshold'] = 0.2
scored['Anomaly'] = scored['Loss_mae'] > scored['Threshold']
scored.head()
# Out:
#          Loss_mae  Threshold  Anomaly
# Tarih
# 2018-10  0.232540        0.2     True
# 2018-11  0.184396        0.2    False
# 2018-12  0.136858        0.2    False
# 2019-01  0.174522        0.2    False
# 2019-02  0.140638        0.2    False

# %%
# calculate the same metrics for the training set 
# and merge all data in a single dataframe for plotting
X_pred_train = model.predict(X_train)
X_pred_train = X_pred_train.reshape(X_pred_train.shape[0], X_pred_train.shape[2])
X_pred_train = pd.DataFrame(X_pred_train, columns=df_train[:-15].columns)
X_pred_train.index = df_train[:-15].index

scored_train = pd.DataFrame(index=df_train[:-15].index)
scored_train['Loss_mae'] = np.mean(np.abs(X_pred_train-Xtrain), axis = 1)
scored_train['Threshold'] = 0.2
scored_train['Anomaly'] = scored_train['Loss_mae'] > scored_train['Threshold']
scored = pd.concat([scored_train, scored])
scored
scored.to_csv("/home/ipcvlab/Desktop/output.csv")

# %%
# plot bearing failure time plot
scored.plot(logy=True,  figsize=(16,9), ylim=[1e-2,1e2], color=['blue','red'])
