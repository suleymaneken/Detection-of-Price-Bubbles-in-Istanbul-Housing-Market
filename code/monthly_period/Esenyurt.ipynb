# %%
import time
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

#plotting
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
sns.set_style("whitegrid")

# %%
from sklearn.model_selection import KFold, GridSearchCV, cross_val_score, train_test_split # Model evaluation
from sklearn.preprocessing import MinMaxScaler # Data normalization
from xgboost import XGBRegressor, DMatrix, plot_importance # XGBoost

# %%
# pip install tensorflow==2
import tensorflow as tf
from tensorflow.keras.layers import Input, Dropout, Dense, LSTM, TimeDistributed, RepeatVector
from tensorflow.keras.models import Model
from tensorflow.keras import regularizers
# Out:
# /home/ipcvlab/anaconda2/envs/data_science/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /home/ipcvlab/anaconda2/envs/data_science/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /home/ipcvlab/anaconda2/envs/data_science/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:528: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /home/ipcvlab/anaconda2/envs/data_science/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:529: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /home/ipcvlab/anaconda2/envs/data_science/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:530: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /home/ipcvlab/anaconda2/envs/data_science/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:535: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %%
df_train = pd.read_excel("/home/ipcvlab/Downloads/ilceler/yıllık-ilk-calısma/esenyurt_tum_veriler.xlsx", index_col = 0) 
cols_list = list(df_train.columns)

# %%
df_train.head()
# Out:
#          HouseEndex      bist   USD/TRY  Aylık_Mevduat_Faizi   Konut_Kredisi  \
# Tarih
# 2007-06       100.0  47093.67  1.321548                17.588        18.0320
# 2007-07       100.8  52824.89  1.282132                17.520        17.4275
# 2007-08       102.3  50198.60  1.314595                17.452        17.1200
# 2007-09       103.6  54044.22  1.267385                17.335        17.5825
# 2007-10       104.6  57615.72  1.202367                16.905        17.2675
#
#          ic_borc_maliyet  tufe_endeks  guven_endeksi  kira endex
# Tarih
# 2007-06        18.420723       139.69      80.949646       100.0
# 2007-07        17.401225       138.67      82.270595       100.0
# 2007-08        19.052940       138.70      85.024409       100.4
# 2007-09        18.250570       140.13      83.885017       101.1
# 2007-10        16.323523       142.67      82.975294       102.2

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 151 entries, 2007-06 to 2019-12
# Data columns (total 9 columns):
# HouseEndex              151 non-null float64
# bist                    151 non-null float64
# USD/TRY                 151 non-null float64
# Aylık_Mevduat_Faizi     151 non-null float64
# Konut_Kredisi           151 non-null float64
# ic_borc_maliyet         151 non-null float64
# tufe_endeks             151 non-null float64
# guven_endeksi           151 non-null float64
# kira endex              151 non-null float64
# dtypes: float64(9)
# memory usage: 11.8+ KB

# %%
df_train.describe()
# Out:
#        HouseEndex           bist     USD/TRY  Aylık_Mevduat_Faizi   \
# count  151.000000     151.000000  151.000000            151.000000
# mean   139.675563   71935.466291    2.589480             10.870206
# std     54.714237   22202.415236    1.381563              4.363666
# min     82.300000   24026.590000    1.176086              5.264000
# 25%     92.130000   55799.800000    1.560281              7.537500
# 50%    113.400000   73995.200000    1.993883              9.265000
# 75%    188.500000   86107.350000    3.173407             12.277500
# max    258.900000  119528.790000    6.378340             22.852500
#
#        Konut_Kredisi  ic_borc_maliyet  tufe_endeks  guven_endeksi  kira endex
# count     151.000000       151.000000   151.000000     151.000000  151.000000
# mean       13.967113        12.049846   244.453444      70.423582  118.678079
# std         3.984043         4.551850    80.716599       7.192777   31.722948
# min         8.297500         5.685006   138.670000      55.136536   77.900000
# 25%        11.297500         8.949530   178.360000      65.648253   92.750000
# 50%        12.868000        10.428706   223.910000      71.309231  105.100000
# 75%        16.129000        14.648636   287.070000      75.903437  149.600000
# max        28.947500        25.808845   440.500000      85.024409  193.300000

# %% [markdown]
# ### display Missing values

# %%
label_nas = []
for col in df_train.columns.tolist():
    if np.sum(df_train[col].isnull() ) != 0:
        label_nas.append(col)
    else:
        label_nas.append("")

plt.figure(figsize=(12,7))
plt.suptitle('Missing Values in the Training Set')
sns.heatmap(df_train.isnull(), yticklabels=False, xticklabels=label_nas ,cbar = False, cmap='viridis')
plt.show()

# %%
replace = True # True: replace null in guven_endeksi with average. False: guven_endeksi kullanmadan
if replace:
    df_train = df_train.fillna(df_train.mean())
else:
    df_train.drop('guven_endeksi', axis=1, inplace=True)

# %%
# Correlation matrix
corr_mat = df_train.corr().abs()
# Find most important features relative to target
corr_mat.sort_values(by=["HouseEndex"], ascending = False, inplace = True)
print(corr_mat.HouseEndex)
# Out:
# HouseEndex              1.000000
# kira endex              0.991063
# tufe_endeks             0.955078
# USD/TRY                 0.944461
# bist                    0.826460
# guven_endeksi           0.530032
# Aylık_Mevduat_Faizi     0.425495
# ic_borc_maliyet         0.378074
# Konut_Kredisi           0.287593
# Name: HouseEndex, dtype: float64

# %%
#Correlation matrix between features
corr_mat = df_train.corr().abs()

# %%
#Plot the heatmap with seaborn
plt.figure(figsize=(7,7)) 

mask = np.zeros_like(corr_mat)
mask[np.triu_indices_from(mask)] = True

sns.heatmap(corr_mat, mask=mask,
        xticklabels=corr_mat.columns,
        yticklabels=corr_mat.columns)

# %%
#List the highly correlated columns
corr_tmp = corr_mat.unstack()
corr_tmp = corr_tmp.sort_values(kind="quicksort")

print(corr_tmp[-len(corr_mat)-10:-len(corr_mat)])
# Out:
# HouseEndex            USD/TRY                 0.944461
# USD/TRY               HouseEndex              0.944461
# Aylık_Mevduat_Faizi   ic_borc_maliyet         0.954900
# ic_borc_maliyet       Aylık_Mevduat_Faizi     0.954900
# HouseEndex            tufe_endeks             0.955078
# tufe_endeks           HouseEndex              0.955078
# USD/TRY               tufe_endeks             0.978278
# tufe_endeks           USD/TRY                 0.978278
# kira endex            HouseEndex              0.991063
# HouseEndex            kira endex              0.991063
# dtype: float64

# %%
# Find most important features relative to target
corr_mat.sort_values(["HouseEndex"], ascending = False, inplace = True)
print(corr_mat.HouseEndex)
# Out:
# HouseEndex              1.000000
# kira endex              0.991063
# tufe_endeks             0.955078
# USD/TRY                 0.944461
# bist                    0.826460
# guven_endeksi           0.530032
# Aylık_Mevduat_Faizi     0.425495
# ic_borc_maliyet         0.378074
# Konut_Kredisi           0.287593
# Name: HouseEndex, dtype: float64

# %% [markdown]
# # Skewness

# %%
#Check the skewness of HouseEndeks
for col in cols_list:
    plt.figure(figsize=(10, 5))
    skewness = df_train[col].skew()
    df_train[col].plot.hist(edgecolor='white', bins=30, 
                                    label=col + ' skew =' + str(round(skewness,2)))
    plt.suptitle("{} distribution".format(col))
    plt.legend()
    plt.show()

# %% [markdown]
# # Box plots

# %%
for col in cols_list:
    plt.figure(figsize=(10, 5))
    # Create the boxplot
    ax = sns.boxplot(x=col, data=df_train)
    # Set the `xlim`
    #ax.set(xlim=(0, 100))
    # Add title
    ax.set_title(col)
    # Show the plot
    plt.show()

# %%
for col in cols_list:    
    y_axis = col
    count = df_train[y_axis].count()
    value=df_train[y_axis]

    plt.figure(figsize=(10, 5))
    sns.regplot(np.linspace(0, count, count), df_train[y_axis], fit_reg=True,
                scatter_kws={'facecolors':np.where( value==True , "red", 'darkviolet'),
               'edgecolor':np.where(value==True , "red", 'darkviolet')},
               line_kws = {'color': 'darkblue'})
    plt.title(col, fontsize=24)
    plt.xlabel('-', fontsize=18)
    plt.ylabel(col, fontsize=18)
    # plt.savefig('figures/Standardised_SalePrice_GrLivArea.png')

# %% [markdown]
# # HouseEndex vs other

# %% [markdown]
# - Kirmizi: bubble fiyatlari iceren regresyon cizgi
# - Mavi: bubble fiyatlari iceren regresyon cizgi
#
# mavi ve kirmizi cizgi arasinda buyuk bir fark varsa, bubble/anomaly mi demek?

# %%
# Displays A Scatter Plot with Regression Line + Outliers in Red

for col in cols_list:
    x_axis = col
    y_axis = 'HouseEndex'
    value=(df_train[y_axis] > 107)
    value2=(df_train[y_axis][:-15] > 107)

    plt.figure(figsize=(10, 5))
    sns.regplot(df_train[x_axis], df_train[y_axis], fit_reg=True,
                scatter_kws={'facecolors':np.where( value==True , "red", 'darkviolet'),
               'edgecolor':np.where(value==True , "red", 'darkviolet')},
               line_kws = {'color': 'darkred'})
    
    sns.regplot(df_train[x_axis][:-15], df_train[y_axis][:-15], fit_reg=True,
                scatter_kws={'facecolors':np.where( value2==True , "red", 'darkviolet'),
               'edgecolor':np.where(value2==True , "red", 'darkviolet')},
               line_kws = {'color': 'darkblue'})
    
    plt.title('HouseEndex vs. {}'.format(x_axis), fontsize=24)
    plt.xlabel(x_axis, fontsize=18)
    plt.ylabel('HouseEndex', fontsize=18)
    # plt.savefig('figures/Standardised_SalePrice_GrLivArea.png')

# %% [markdown]
# # XGBoost
#
# hiç faydası yok bu konuda, eğitimde kullandığımız verileri göre sonuç veriyor, ama şişik olup olmadığını gösteremez

# %%
#y_full = df_train['HouseEndex']
#X_full = df_train.drop(columns=["HouseEndex"])

y_full = df_train['HouseEndex'][:-15]
X_full = df_train.drop(columns=["HouseEndex"])[:-15]

y_test = df_train['HouseEndex'][-15:]
X_test = df_train.drop(columns=["HouseEndex"])[-15:]

X_train, X_val, y_train, y_val = train_test_split(X_full, y_full, test_size=0.2, random_state=123)

# %%
# final model with tuned parameters
model = XGBRegressor(max_depth=6, #dflt 6
                     learning_rate=0.1, #dflt 100
                     n_estimators=1000, #dflt 0.1
                     verbosity = 3,
                     objective='reg:linear',
                     n_jobs=-1,
                     gamma=0, #dflt: 0
                     min_child_weight=3, #0 dflt: 1
                     subsample=0.5,
                     colsample_bytree=1,
                     reg_lambda=0.99994, #dflt: 1
                     reg_alpha=0.00003, #dflt: 0
                     tree_method='exact',
                     scale_pos_weight=1, # dflt: 1
                     random_state=123)

# %%
tick=time.time()

fitted_model = model.fit(X_train, y_train,
                         eval_set=[(X_val, y_val)],
                         eval_metric='rmse', # Equivalent to RMSLE since we have log1p(SalePrice)
                         early_stopping_rounds=1000,
                         verbose=True)

print("Duration: {}s".format(time.time()-tick))
# Out:
# [21:27:53] WARNING: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [21:27:53] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 2 extra nodes, 0 pruned nodes, max_depth=1
# [0]	validation_0-rmse:127.432
# Will train until validation_0-rmse hasn't improved in 1000 rounds.
# [21:27:53] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 2 extra nodes, 0 pruned nodes, max_depth=1
# [1]	validation_0-rmse:115.73
# [21:27:53] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 2 extra nodes, 0 pruned nodes, max_depth=1
# [2]	validation_0-rmse:105.268
# [21:27:53] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [3]	validation_0-rmse:95.7103
# [21:27:53] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [4]	validation_0-rmse:87.0562
# [21:27:53] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 2 extra nodes, 0 pruned nodes, max_depth=1
# [5]	validation_0-rmse:79.6157
# [21:27:53] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [6]	validation_0-rmse:72.3912
# [21:27:53] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [7]	validation_0-rmse:65.8841
# [21:27:53] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [8]	validation_0-rmse:60.0296
# [21:27:53] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [9]	validation_0-rmse:54.8996
# [21:27:53] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [10]	validation_0-rmse:50.2054
# [21:27:53] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [11]	validation_0-rmse:46.0042
# [21:27:53] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [12]	validation_0-rmse:41.9515
# [21:27:53] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [13]	validation_0-rmse:38.3166
# [21:27:53] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 2 extra nodes, 0 pruned nodes, max_depth=1
# [14]	validation_0-rmse:35.3396
# [21:27:53] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [15]	validation_0-rmse:32.2633
# [21:27:53] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [16]	validation_0-rmse:29.8411
# [21:27:53] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [17]	validation_0-rmse:27.3634
# [21:27:53] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [18]	validation_0-rmse:24.8757
# [21:27:53] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [19]	validation_0-rmse:22.7826
# [21:27:53] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [20]	validation_0-rmse:20.5894
# [21:27:53] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [21]	validation_0-rmse:18.8476
# [21:27:53] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [22]	validation_0-rmse:17.2425
# [21:27:53] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=3
# [23]	validation_0-rmse:15.8204
# [21:27:53] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [24]	validation_0-rmse:14.5245
# [21:27:53] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=4
# [25]	validation_0-rmse:13.252
# [21:27:53] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=4
# [26]	validation_0-rmse:12.0629
# [21:27:53] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=4
# [27]	validation_0-rmse:10.9924
# [21:27:53] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 0 pruned nodes, max_depth=3
# [28]	validation_0-rmse:10.2064
# [21:27:53] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 0 pruned nodes, max_depth=5
# [29]	validation_0-rmse:9.3525
# [21:27:53] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 0 pruned nodes, max_depth=4
# [30]	validation_0-rmse:8.55273
# [21:27:53] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=3
# [31]	validation_0-rmse:7.87811
# [21:27:53] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=4
# [32]	validation_0-rmse:7.23489
# [21:27:53] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 0 pruned nodes, max_depth=4
# [33]	validation_0-rmse:6.71473
# [21:27:53] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=5
# [34]	validation_0-rmse:6.2598
# [21:27:53] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=3
# [35]	validation_0-rmse:5.75708
# [21:27:53] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 0 pruned nodes, max_depth=6
# [36]	validation_0-rmse:5.2696
# [21:27:53] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 0 pruned nodes, max_depth=6
# [37]	validation_0-rmse:4.91057
# [21:27:53] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=5
# [38]	validation_0-rmse:4.54667
# [21:27:53] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 0 pruned nodes, max_depth=6
# [39]	validation_0-rmse:4.31476
# [21:27:53] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 0 pruned nodes, max_depth=6
# [40]	validation_0-rmse:4.0346
# [21:27:53] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=6
# [41]	validation_0-rmse:3.73379
# [21:27:53] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 0 pruned nodes, max_depth=6
# [42]	validation_0-rmse:3.50922
# [21:27:53] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 0 pruned nodes, max_depth=6
# [43]	validation_0-rmse:3.3581
# [21:27:53] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 0 pruned nodes, max_depth=6
# [44]	validation_0-rmse:3.1681
# [21:27:53] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 0 pruned nodes, max_depth=6
# [45]	validation_0-rmse:3.01115
# [21:27:53] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 0 pruned nodes, max_depth=6
# [46]	validation_0-rmse:2.85377
# [21:27:53] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 0 pruned nodes, max_depth=6
# [47]	validation_0-rmse:2.7556
# [21:27:53] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 0 pruned nodes, max_depth=6
# [48]	validation_0-rmse:2.70045
# [21:27:53] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 0 pruned nodes, max_depth=6
# [49]	validation_0-rmse:2.61422
# [21:27:53] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 0 pruned nodes, max_depth=6
# [50]	validation_0-rmse:2.51243
# [21:27:53] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 0 pruned nodes, max_depth=6
# [51]	validation_0-rmse:2.45386
# [21:27:53] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 0 pruned nodes, max_depth=6
# [52]	validation_0-rmse:2.38486
# [21:27:53] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 26 extra nodes, 0 pruned nodes, max_depth=6
# [53]	validation_0-rmse:2.32242
# [21:27:53] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 26 extra nodes, 0 pruned nodes, max_depth=6
# [54]	validation_0-rmse:2.27935
# [21:27:53] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 0 pruned nodes, max_depth=6
# [55]	validation_0-rmse:2.20427
# [21:27:53] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 0 pruned nodes, max_depth=6
# [56]	validation_0-rmse:2.1614
# [21:27:53] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 0 pruned nodes, max_depth=6
# [57]	validation_0-rmse:2.11507
# [21:27:53] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 0 pruned nodes, max_depth=6
# [58]	validation_0-rmse:2.08274
# [21:27:53] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 28 extra nodes, 0 pruned nodes, max_depth=6
# [59]	validation_0-rmse:2.02404
# [21:27:53] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 0 pruned nodes, max_depth=6
# [60]	validation_0-rmse:1.99203
# [21:27:53] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 0 pruned nodes, max_depth=6
# [61]	validation_0-rmse:1.95109
# [21:27:53] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 0 pruned nodes, max_depth=6
# [62]	validation_0-rmse:1.94606
# [21:27:53] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 0 pruned nodes, max_depth=6
# [63]	validation_0-rmse:1.90668
# [21:27:53] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 0 pruned nodes, max_depth=5
# [64]	validation_0-rmse:1.90015
# /home/ipcvlab/anaconda2/envs/data_science/lib/python3.6/site-packages/xgboost/core.py:587: FutureWarning: Series.base is deprecated and will be removed in a future version
#   if getattr(data, 'base', None) is not None and \
# [21:27:53] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 0 pruned nodes, max_depth=6
# [65]	validation_0-rmse:1.89376
# [21:27:53] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 0 pruned nodes, max_depth=6
# [66]	validation_0-rmse:1.86954
# [21:27:53] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 0 pruned nodes, max_depth=6
# [67]	validation_0-rmse:1.85298
# [21:27:53] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 28 extra nodes, 0 pruned nodes, max_depth=6
# [68]	validation_0-rmse:1.83191
# [21:27:53] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 28 extra nodes, 0 pruned nodes, max_depth=6
# [69]	validation_0-rmse:1.82425
# [21:27:53] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 28 extra nodes, 0 pruned nodes, max_depth=6
# [70]	validation_0-rmse:1.81763
# [21:27:53] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 0 pruned nodes, max_depth=6
# [71]	validation_0-rmse:1.8192
# [21:27:53] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 28 extra nodes, 0 pruned nodes, max_depth=6
# [72]	validation_0-rmse:1.81021
# [21:27:53] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 0 pruned nodes, max_depth=6
# [73]	validation_0-rmse:1.78682
# [21:27:53] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 0 pruned nodes, max_depth=6
# [74]	validation_0-rmse:1.77505
# [21:27:53] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 26 extra nodes, 0 pruned nodes, max_depth=6
# [75]	validation_0-rmse:1.7741
# [21:27:53] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 0 pruned nodes, max_depth=6
# [76]	validation_0-rmse:1.775
# [21:27:53] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 0 pruned nodes, max_depth=6
# [77]	validation_0-rmse:1.79113
# [21:27:53] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 26 extra nodes, 0 pruned nodes, max_depth=6
# [78]	validation_0-rmse:1.79113
# [21:27:53] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 28 extra nodes, 0 pruned nodes, max_depth=6
# [79]	validation_0-rmse:1.78439
# [21:27:53] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 0 pruned nodes, max_depth=6
# [80]	validation_0-rmse:1.77518
# [21:27:53] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 0 pruned nodes, max_depth=6
# [81]	validation_0-rmse:1.76758
# [21:27:53] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 28 extra nodes, 0 pruned nodes, max_depth=6
# [82]	validation_0-rmse:1.76618
# [21:27:53] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 0 pruned nodes, max_depth=6
# [83]	validation_0-rmse:1.75805
# [21:27:53] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 0 pruned nodes, max_depth=6
# [84]	validation_0-rmse:1.76273
# [21:27:53] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 26 extra nodes, 0 pruned nodes, max_depth=6
# [85]	validation_0-rmse:1.75966
# [21:27:53] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 26 extra nodes, 0 pruned nodes, max_depth=6
# [86]	validation_0-rmse:1.74494
# [21:27:53] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 0 pruned nodes, max_depth=5
# [87]	validation_0-rmse:1.73734
# [21:27:53] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 0 pruned nodes, max_depth=6
# [88]	validation_0-rmse:1.74068
# [21:27:53] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 0 pruned nodes, max_depth=6
# [89]	validation_0-rmse:1.72816
# [21:27:53] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 0 pruned nodes, max_depth=6
# [90]	validation_0-rmse:1.73897
# [21:27:53] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 0 pruned nodes, max_depth=6
# [91]	validation_0-rmse:1.73476
# [21:27:53] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 0 pruned nodes, max_depth=6
# [92]	validation_0-rmse:1.7421
# [21:27:53] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 0 pruned nodes, max_depth=6
# [93]	validation_0-rmse:1.73784
# [21:27:53] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 0 pruned nodes, max_depth=6
# [94]	validation_0-rmse:1.72845
# [21:27:53] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 0 pruned nodes, max_depth=6
# [95]	validation_0-rmse:1.73432
# [21:27:53] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 0 pruned nodes, max_depth=6
# [96]	validation_0-rmse:1.74297
# [21:27:53] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 0 pruned nodes, max_depth=6
# [97]	validation_0-rmse:1.75669
# [21:27:53] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 0 pruned nodes, max_depth=6
# [98]	validation_0-rmse:1.75947
# [21:27:53] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 0 pruned nodes, max_depth=6
# [99]	validation_0-rmse:1.75839
# [21:27:53] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 0 pruned nodes, max_depth=5
# [100]	validation_0-rmse:1.75218
# [21:27:53] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 26 extra nodes, 0 pruned nodes, max_depth=6
# [101]	validation_0-rmse:1.75127
# [21:27:53] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 0 pruned nodes, max_depth=6
# [102]	validation_0-rmse:1.74606
# [21:27:53] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 0 pruned nodes, max_depth=6
# [103]	validation_0-rmse:1.74941
# [21:27:53] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 0 pruned nodes, max_depth=6
# [104]	validation_0-rmse:1.74855
# [21:27:53] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 0 pruned nodes, max_depth=6
# [105]	validation_0-rmse:1.7516
# [21:27:53] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 0 pruned nodes, max_depth=6
# [106]	validation_0-rmse:1.75646
# [21:27:53] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 0 pruned nodes, max_depth=6
# [107]	validation_0-rmse:1.74862
# [21:27:53] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 0 pruned nodes, max_depth=6
# [108]	validation_0-rmse:1.75276
# [21:27:53] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 0 pruned nodes, max_depth=6
# [109]	validation_0-rmse:1.75048
# [21:27:53] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 26 extra nodes, 0 pruned nodes, max_depth=6
# [110]	validation_0-rmse:1.743
# [21:27:53] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 0 pruned nodes, max_depth=6
# [111]	validation_0-rmse:1.74438
# [21:27:53] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 26 extra nodes, 0 pruned nodes, max_depth=6
# [112]	validation_0-rmse:1.73989
# [21:27:53] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 0 pruned nodes, max_depth=6
# [113]	validation_0-rmse:1.73992
# [21:27:53] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 0 pruned nodes, max_depth=6
# [114]	validation_0-rmse:1.73912
# [21:27:53] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 26 extra nodes, 0 pruned nodes, max_depth=6
# [115]	validation_0-rmse:1.74409
# [21:27:53] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 0 pruned nodes, max_depth=6
# [116]	validation_0-rmse:1.74808
# [21:27:53] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 0 pruned nodes, max_depth=6
# [117]	validation_0-rmse:1.75068
# [21:27:53] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 0 pruned nodes, max_depth=6
# [118]	validation_0-rmse:1.74867
# [21:27:53] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 0 pruned nodes, max_depth=6
# [119]	validation_0-rmse:1.74645
# [21:27:53] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 0 pruned nodes, max_depth=6
# [120]	validation_0-rmse:1.74121
# [21:27:53] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 0 pruned nodes, max_depth=6
# [121]	validation_0-rmse:1.7431
# [21:27:53] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 0 pruned nodes, max_depth=6
# [122]	validation_0-rmse:1.74689
# [21:27:53] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 0 pruned nodes, max_depth=6
# [123]	validation_0-rmse:1.74377
# [21:27:53] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 0 pruned nodes, max_depth=6
# [124]	validation_0-rmse:1.7492
# [21:27:53] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 0 pruned nodes, max_depth=6
# [125]	validation_0-rmse:1.74649
# [21:27:53] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 0 pruned nodes, max_depth=6
# [126]	validation_0-rmse:1.74622
# [21:27:53] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 32 extra nodes, 0 pruned nodes, max_depth=5
# [127]	validation_0-rmse:1.74108
# [21:27:53] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=6
# [128]	validation_0-rmse:1.73603
# [21:27:53] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 0 pruned nodes, max_depth=6
# [129]	validation_0-rmse:1.7303
# [21:27:53] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=6
# [130]	validation_0-rmse:1.73064
# [21:27:53] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 0 pruned nodes, max_depth=6
# [131]	validation_0-rmse:1.73274
# [21:27:53] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=6
# [132]	validation_0-rmse:1.73353
# [21:27:53] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 0 pruned nodes, max_depth=5
# [133]	validation_0-rmse:1.7323
# [21:27:53] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 0 pruned nodes, max_depth=6
# [134]	validation_0-rmse:1.73199
# [21:27:53] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 0 pruned nodes, max_depth=6
# [135]	validation_0-rmse:1.73517
# [21:27:53] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 0 pruned nodes, max_depth=6
# [136]	validation_0-rmse:1.73142
# [21:27:53] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 0 pruned nodes, max_depth=6
# [137]	validation_0-rmse:1.73433
# [21:27:53] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 0 pruned nodes, max_depth=6
# [138]	validation_0-rmse:1.72903
# [21:27:53] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 0 pruned nodes, max_depth=6
# [139]	validation_0-rmse:1.73043
# [21:27:53] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 0 pruned nodes, max_depth=6
# [140]	validation_0-rmse:1.73156
# [21:27:53] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 26 extra nodes, 0 pruned nodes, max_depth=6
# [141]	validation_0-rmse:1.72938
# [21:27:53] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 0 pruned nodes, max_depth=6
# [142]	validation_0-rmse:1.73402
# [21:27:53] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 0 pruned nodes, max_depth=6
# [143]	validation_0-rmse:1.72986
# [21:27:53] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 0 pruned nodes, max_depth=6
# [144]	validation_0-rmse:1.72586
# [21:27:53] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 0 pruned nodes, max_depth=6
# [145]	validation_0-rmse:1.72904
# [21:27:53] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 0 pruned nodes, max_depth=6
# [146]	validation_0-rmse:1.73155
# [21:27:53] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 0 pruned nodes, max_depth=6
# [147]	validation_0-rmse:1.73541
# [21:27:53] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 0 pruned nodes, max_depth=6
# [148]	validation_0-rmse:1.73323
# [21:27:53] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 0 pruned nodes, max_depth=6
# [149]	validation_0-rmse:1.74067
# [21:27:53] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 0 pruned nodes, max_depth=6
# [150]	validation_0-rmse:1.74006
# [21:27:53] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 0 pruned nodes, max_depth=6
# [151]	validation_0-rmse:1.74258
# [21:27:53] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 0 pruned nodes, max_depth=6
# [152]	validation_0-rmse:1.73648
# [21:27:53] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 0 pruned nodes, max_depth=6
# [153]	validation_0-rmse:1.7314
# [21:27:53] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 0 pruned nodes, max_depth=6
# [154]	validation_0-rmse:1.73226
# [21:27:53] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 0 pruned nodes, max_depth=6
# [155]	validation_0-rmse:1.7322
# [21:27:53] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 28 extra nodes, 0 pruned nodes, max_depth=6
# [156]	validation_0-rmse:1.73365
# [21:27:53] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 0 pruned nodes, max_depth=6
# [157]	validation_0-rmse:1.73378
# [21:27:53] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 0 pruned nodes, max_depth=6
# [158]	validation_0-rmse:1.73297
# [21:27:53] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 26 extra nodes, 0 pruned nodes, max_depth=6
# [159]	validation_0-rmse:1.7321
# [21:27:53] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 26 extra nodes, 0 pruned nodes, max_depth=6
# [160]	validation_0-rmse:1.73287
# [21:27:53] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 0 pruned nodes, max_depth=6
# [161]	validation_0-rmse:1.73392
# [21:27:53] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 0 pruned nodes, max_depth=6
# [162]	validation_0-rmse:1.73432
# [21:27:53] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 26 extra nodes, 0 pruned nodes, max_depth=6
# [163]	validation_0-rmse:1.73364
# [21:27:53] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 0 pruned nodes, max_depth=6
# [164]	validation_0-rmse:1.7371
# [21:27:53] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 0 pruned nodes, max_depth=6
# [165]	validation_0-rmse:1.73307
# [21:27:53] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 26 extra nodes, 0 pruned nodes, max_depth=5
# [166]	validation_0-rmse:1.73245
# [21:27:53] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 0 pruned nodes, max_depth=6
# [167]	validation_0-rmse:1.73293
# [21:27:53] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 0 pruned nodes, max_depth=6
# [168]	validation_0-rmse:1.73145
# [21:27:53] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 0 pruned nodes, max_depth=6
# [169]	validation_0-rmse:1.73552
# [21:27:53] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 0 pruned nodes, max_depth=6
# [170]	validation_0-rmse:1.73732
# [21:27:53] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=6
# [171]	validation_0-rmse:1.7395
# [21:27:53] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 0 pruned nodes, max_depth=6
# [172]	validation_0-rmse:1.73849
# [21:27:53] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 0 pruned nodes, max_depth=6
# [173]	validation_0-rmse:1.73951
# [21:27:53] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 0 pruned nodes, max_depth=6
# [174]	validation_0-rmse:1.74008
# [21:27:53] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 0 pruned nodes, max_depth=6
# [175]	validation_0-rmse:1.73978
# [21:27:54] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=6
# [176]	validation_0-rmse:1.7383
# [21:27:54] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 0 pruned nodes, max_depth=6
# [177]	validation_0-rmse:1.73749
# [21:27:54] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 0 pruned nodes, max_depth=6
# [178]	validation_0-rmse:1.73788
# [21:27:54] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 26 extra nodes, 0 pruned nodes, max_depth=6
# [179]	validation_0-rmse:1.73947
# [21:27:54] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 0 pruned nodes, max_depth=6
# [180]	validation_0-rmse:1.74069
# [21:27:54] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 0 pruned nodes, max_depth=6
# [181]	validation_0-rmse:1.74388
# [21:27:54] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 0 pruned nodes, max_depth=6
# [182]	validation_0-rmse:1.74157
# [21:27:54] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=6
# [183]	validation_0-rmse:1.74016
# [21:27:54] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 0 pruned nodes, max_depth=6
# [184]	validation_0-rmse:1.73972
# [21:27:54] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 0 pruned nodes, max_depth=6
# [185]	validation_0-rmse:1.73608
# [21:27:54] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 0 pruned nodes, max_depth=6
# [186]	validation_0-rmse:1.73803
# [21:27:54] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 0 pruned nodes, max_depth=6
# [187]	validation_0-rmse:1.73673
# [21:27:54] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 0 pruned nodes, max_depth=6
# [188]	validation_0-rmse:1.73354
# [21:27:54] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 0 pruned nodes, max_depth=6
# [189]	validation_0-rmse:1.73339
# [21:27:54] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 0 pruned nodes, max_depth=6
# [190]	validation_0-rmse:1.73172
# [21:27:54] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=6
# [191]	validation_0-rmse:1.73304
# [21:27:54] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 0 pruned nodes, max_depth=6
# [192]	validation_0-rmse:1.73379
# [21:27:54] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 0 pruned nodes, max_depth=6
# [193]	validation_0-rmse:1.73336
# [21:27:54] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 0 pruned nodes, max_depth=6
# [194]	validation_0-rmse:1.73233
# [21:27:54] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 0 pruned nodes, max_depth=6
# [195]	validation_0-rmse:1.7299
# [21:27:54] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 0 pruned nodes, max_depth=6
# [196]	validation_0-rmse:1.73077
# [21:27:54] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 0 pruned nodes, max_depth=6
# [197]	validation_0-rmse:1.7346
# [21:27:54] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 0 pruned nodes, max_depth=6
# [198]	validation_0-rmse:1.73406
# [21:27:54] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 0 pruned nodes, max_depth=6
# [199]	validation_0-rmse:1.72916
# [21:27:54] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 0 pruned nodes, max_depth=6
# [200]	validation_0-rmse:1.73125
# [21:27:54] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 0 pruned nodes, max_depth=6
# [201]	validation_0-rmse:1.7336
# [21:27:54] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 0 pruned nodes, max_depth=6
# [202]	validation_0-rmse:1.73345
# [21:27:54] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 0 pruned nodes, max_depth=6
# [203]	validation_0-rmse:1.73357
# [21:27:54] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 0 pruned nodes, max_depth=6
# [204]	validation_0-rmse:1.73151
# [21:27:54] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=6
# [205]	validation_0-rmse:1.73233
# [21:27:54] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 0 pruned nodes, max_depth=6
# [206]	validation_0-rmse:1.73421
# [21:27:54] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 0 pruned nodes, max_depth=6
# [207]	validation_0-rmse:1.73267
# [21:27:54] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 26 extra nodes, 0 pruned nodes, max_depth=6
# [208]	validation_0-rmse:1.73118
# [21:27:54] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 0 pruned nodes, max_depth=6
# [209]	validation_0-rmse:1.73127
# [21:27:54] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 0 pruned nodes, max_depth=6
# [210]	validation_0-rmse:1.73167
# [21:27:54] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 0 pruned nodes, max_depth=6
# [211]	validation_0-rmse:1.73517
# [21:27:54] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 0 pruned nodes, max_depth=6
# [212]	validation_0-rmse:1.73448
# [21:27:54] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 0 pruned nodes, max_depth=6
# [213]	validation_0-rmse:1.73539
# [21:27:54] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 0 pruned nodes, max_depth=6
# [214]	validation_0-rmse:1.73439
# [21:27:54] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 0 pruned nodes, max_depth=6
# [215]	validation_0-rmse:1.73391
# ...
# [927]	validation_0-rmse:1.7295
# [21:27:56] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [928]	validation_0-rmse:1.7295
# [21:27:56] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=3
# [929]	validation_0-rmse:1.72947
# [21:27:56] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=3
# [930]	validation_0-rmse:1.72947
# [21:27:56] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [931]	validation_0-rmse:1.72948
# [21:27:56] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=4
# [932]	validation_0-rmse:1.7295
# [21:27:56] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [933]	validation_0-rmse:1.72951
# [21:27:56] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=5
# [934]	validation_0-rmse:1.72952
# [21:27:56] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [935]	validation_0-rmse:1.72952
# [21:27:56] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=3
# [936]	validation_0-rmse:1.72952
# [21:27:56] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=4
# [937]	validation_0-rmse:1.72951
# [21:27:56] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=4
# [938]	validation_0-rmse:1.72951
# [21:27:56] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [939]	validation_0-rmse:1.72951
# [21:27:56] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [940]	validation_0-rmse:1.72951
# [21:27:56] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [941]	validation_0-rmse:1.72952
# [21:27:56] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 0 pruned nodes, max_depth=4
# [942]	validation_0-rmse:1.7295
# [21:27:56] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 2 extra nodes, 0 pruned nodes, max_depth=1
# [943]	validation_0-rmse:1.72951
# [21:27:56] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 2 extra nodes, 0 pruned nodes, max_depth=1
# [944]	validation_0-rmse:1.72951
# [21:27:56] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 0 pruned nodes, max_depth=4
# [945]	validation_0-rmse:1.72951
# [21:27:56] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [946]	validation_0-rmse:1.72951
# [21:27:56] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [947]	validation_0-rmse:1.72952
# [21:27:56] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=5
# [948]	validation_0-rmse:1.7295
# [21:27:56] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [949]	validation_0-rmse:1.72949
# [21:27:56] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=3
# [950]	validation_0-rmse:1.72948
# [21:27:56] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 2 extra nodes, 0 pruned nodes, max_depth=1
# [951]	validation_0-rmse:1.72948
# [21:27:56] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [952]	validation_0-rmse:1.72948
# [21:27:56] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=3
# [953]	validation_0-rmse:1.72947
# [21:27:56] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [954]	validation_0-rmse:1.72946
# [21:27:56] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [955]	validation_0-rmse:1.72947
# [21:27:56] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 2 extra nodes, 0 pruned nodes, max_depth=1
# [956]	validation_0-rmse:1.72947
# [21:27:56] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [957]	validation_0-rmse:1.72947
# [21:27:56] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 2 extra nodes, 0 pruned nodes, max_depth=1
# [958]	validation_0-rmse:1.72947
# [21:27:56] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=3
# [959]	validation_0-rmse:1.72947
# [21:27:56] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 2 extra nodes, 0 pruned nodes, max_depth=1
# [960]	validation_0-rmse:1.72947
# [21:27:56] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [961]	validation_0-rmse:1.72946
# [21:27:56] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [962]	validation_0-rmse:1.72946
# [21:27:56] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [963]	validation_0-rmse:1.72947
# [21:27:56] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 2 extra nodes, 0 pruned nodes, max_depth=1
# [964]	validation_0-rmse:1.72947
# [21:27:56] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [965]	validation_0-rmse:1.72947
# [21:27:56] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=3
# [966]	validation_0-rmse:1.72947
# [21:27:56] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=3
# [967]	validation_0-rmse:1.72945
# [21:27:56] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [968]	validation_0-rmse:1.72945
# [21:27:56] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [969]	validation_0-rmse:1.72945
# [21:27:56] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [970]	validation_0-rmse:1.72946
# [21:27:56] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 2 extra nodes, 0 pruned nodes, max_depth=1
# [971]	validation_0-rmse:1.72946
# [21:27:56] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 2 extra nodes, 0 pruned nodes, max_depth=1
# [972]	validation_0-rmse:1.72946
# [21:27:56] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 0 pruned nodes, max_depth=4
# [973]	validation_0-rmse:1.72945
# [21:27:56] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [974]	validation_0-rmse:1.72945
# [21:27:56] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 2 extra nodes, 0 pruned nodes, max_depth=1
# [975]	validation_0-rmse:1.72945
# [21:27:56] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=4
# [976]	validation_0-rmse:1.72944
# [21:27:56] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [977]	validation_0-rmse:1.72944
# [21:27:56] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 2 extra nodes, 0 pruned nodes, max_depth=1
# [978]	validation_0-rmse:1.72944
# [21:27:56] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=3
# [979]	validation_0-rmse:1.72944
# [21:27:56] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 0 pruned nodes, max_depth=4
# [980]	validation_0-rmse:1.72944
# [21:27:56] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [981]	validation_0-rmse:1.72945
# [21:27:56] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [982]	validation_0-rmse:1.72947
# [21:27:56] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 2 extra nodes, 0 pruned nodes, max_depth=1
# [983]	validation_0-rmse:1.72947
# [21:27:56] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=3
# [984]	validation_0-rmse:1.72948
# [21:27:56] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=3
# [985]	validation_0-rmse:1.72948
# [21:27:56] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 2 extra nodes, 0 pruned nodes, max_depth=1
# [986]	validation_0-rmse:1.72948
# [21:27:56] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 2 extra nodes, 0 pruned nodes, max_depth=1
# [987]	validation_0-rmse:1.72948
# [21:27:56] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 2 extra nodes, 0 pruned nodes, max_depth=1
# [988]	validation_0-rmse:1.72948
# [21:27:56] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 2 extra nodes, 0 pruned nodes, max_depth=1
# [989]	validation_0-rmse:1.72948
# [21:27:56] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=5
# [990]	validation_0-rmse:1.72949
# [21:27:56] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [991]	validation_0-rmse:1.72949
# [21:27:56] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [992]	validation_0-rmse:1.72949
# [21:27:56] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [993]	validation_0-rmse:1.72949
# [21:27:56] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 2 extra nodes, 0 pruned nodes, max_depth=1
# [994]	validation_0-rmse:1.72949
# [21:27:56] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=3
# [995]	validation_0-rmse:1.72948
# [21:27:56] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=4
# [996]	validation_0-rmse:1.72948
# [21:27:56] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 0 pruned nodes, max_depth=4
# [997]	validation_0-rmse:1.72947
# [21:27:56] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 0 pruned nodes, max_depth=4
# [998]	validation_0-rmse:1.72947
# [21:27:56] INFO: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 2 extra nodes, 0 pruned nodes, max_depth=1
# [999]	validation_0-rmse:1.72947
# Duration: 3.2514588832855225s

# %%
# Plot feature importance
figsize=(7,7)
fig, ax = plt.subplots(1,1,figsize=figsize)
plot_importance(model, ax=ax,height = 1)

# %%
# predict sales in test dataset
test_predictions = model.predict(X_test).flatten()

# scatter plot of True vs Predicted values
plt.scatter(y_test, test_predictions)
plt.xlabel('True Values $')
plt.ylabel('Predictions $')
plt.axis('equal')
plt.axis('square')
plt.xlim([100,plt.xlim()[1]])
plt.ylim([100,plt.ylim()[1]])
_ = plt.plot([0, 1000], [0, 1000])

# %%
# Histogram of error values
error = test_predictions - y_test
plt.hist(error, bins = 25)
plt.xlabel("Prediction Error $")
_ = plt.ylabel("Count")

# %% [markdown]
# # Anomaly detection approach
#
# Loss > Threshold ise = anomaly > bubble mi demek?

# %%
# Data normalization
scaler = MinMaxScaler(feature_range=(0, 1))
X_train = scaler.fit_transform(df_train[:-15]) # Healthy/normal data
X_test = scaler.fit_transform(df_train[-15:]) # Unhealthy/anomaly data

# %%
X_train.shape
# Out:
# (136, 9)

# %%
# Reshape for LSTM
X_train = X_train.reshape(X_train.shape[0], 1, X_train.shape[1])
X_test = X_test.reshape(X_test.shape[0], 1, X_test.shape[1])

# %%
# define the autoencoder network model
def autoencoder_model(X):
    inputs = Input(shape=(X.shape[1], X.shape[2]))
    L1 = LSTM(16, activation='relu', return_sequences=True, 
              kernel_regularizer=regularizers.l2(0.00))(inputs)
    L2 = LSTM(4, activation='relu', return_sequences=False)(L1)
    L3 = RepeatVector(X.shape[1])(L2)
    L4 = LSTM(4, activation='relu', return_sequences=True)(L3)
    L5 = LSTM(16, activation='relu', return_sequences=True)(L4)
    output = TimeDistributed(Dense(X.shape[2]))(L5)    
    model = Model(inputs=inputs, outputs=output)
    return model

# %%
# create the autoencoder model
model = autoencoder_model(X_train)
model.compile(optimizer='adam', loss='mae')
model.summary()
# Out:
# WARNING:tensorflow:From /home/ipcvlab/anaconda2/envs/data_science/lib/python3.6/site-packages/tensorflow/python/ops/resource_variable_ops.py:435: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 1, 9)              0
# _________________________________________________________________
# lstm (LSTM)                  (None, 1, 16)             1664
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 4)                 336
# _________________________________________________________________
# repeat_vector (RepeatVector) (None, 1, 4)              0
# _________________________________________________________________
# lstm_2 (LSTM)                (None, 1, 4)              144
# _________________________________________________________________
# lstm_3 (LSTM)                (None, 1, 16)             1344
# _________________________________________________________________
# time_distributed (TimeDistri (None, 1, 9)              153
# =================================================================
# Total params: 3,641
# Trainable params: 3,641
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = model.fit(X_train, X_train, epochs=100, batch_size=10,
                    validation_split=0.05).history
# Out:
# Train on 129 samples, validate on 7 samples
# WARNING:tensorflow:From /home/ipcvlab/anaconda2/envs/data_science/lib/python3.6/site-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Epoch 1/100
# 129/129 [==============================] - 5s 41ms/sample - loss: 0.3287 - val_loss: 0.7122
# Epoch 2/100
# 129/129 [==============================] - 0s 891us/sample - loss: 0.3162 - val_loss: 0.6990
# Epoch 3/100
# 129/129 [==============================] - 0s 1ms/sample - loss: 0.3041 - val_loss: 0.6857
# Epoch 4/100
# 129/129 [==============================] - 0s 1ms/sample - loss: 0.2924 - val_loss: 0.6723
# Epoch 5/100
# 129/129 [==============================] - 0s 2ms/sample - loss: 0.2808 - val_loss: 0.6587
# Epoch 6/100
# 129/129 [==============================] - 0s 2ms/sample - loss: 0.2698 - val_loss: 0.6450
# Epoch 7/100
# 129/129 [==============================] - 0s 2ms/sample - loss: 0.2592 - val_loss: 0.6314
# Epoch 8/100
# 129/129 [==============================] - 0s 2ms/sample - loss: 0.2490 - val_loss: 0.6179
# Epoch 9/100
# 129/129 [==============================] - 0s 1ms/sample - loss: 0.2393 - val_loss: 0.6045
# Epoch 10/100
# 129/129 [==============================] - 0s 3ms/sample - loss: 0.2301 - val_loss: 0.5912
# Epoch 11/100
# 129/129 [==============================] - 0s 1ms/sample - loss: 0.2217 - val_loss: 0.5777
# Epoch 12/100
# 129/129 [==============================] - 0s 2ms/sample - loss: 0.2142 - val_loss: 0.5640
# Epoch 13/100
# 129/129 [==============================] - 0s 1ms/sample - loss: 0.2073 - val_loss: 0.5490
# Epoch 14/100
# 129/129 [==============================] - 0s 1ms/sample - loss: 0.2007 - val_loss: 0.5289
# Epoch 15/100
# 129/129 [==============================] - 0s 1ms/sample - loss: 0.1938 - val_loss: 0.4898
# Epoch 16/100
# 129/129 [==============================] - 0s 1ms/sample - loss: 0.1855 - val_loss: 0.4031
# Epoch 17/100
# 129/129 [==============================] - 0s 1ms/sample - loss: 0.1739 - val_loss: 0.3921
# Epoch 18/100
# 129/129 [==============================] - 0s 1ms/sample - loss: 0.1637 - val_loss: 0.4477
# Epoch 19/100
# 129/129 [==============================] - 0s 2ms/sample - loss: 0.1570 - val_loss: 0.3685
# Epoch 20/100
# 129/129 [==============================] - 0s 2ms/sample - loss: 0.1516 - val_loss: 0.3511
# Epoch 21/100
# 129/129 [==============================] - 0s 3ms/sample - loss: 0.1481 - val_loss: 0.3259
# Epoch 22/100
# 129/129 [==============================] - 0s 1ms/sample - loss: 0.1450 - val_loss: 0.3045
# Epoch 23/100
# 129/129 [==============================] - 0s 1ms/sample - loss: 0.1423 - val_loss: 0.2906
# Epoch 24/100
# 129/129 [==============================] - 0s 2ms/sample - loss: 0.1398 - val_loss: 0.2765
# Epoch 25/100
# 129/129 [==============================] - 0s 2ms/sample - loss: 0.1368 - val_loss: 0.2588
# Epoch 26/100
# 129/129 [==============================] - 0s 2ms/sample - loss: 0.1340 - val_loss: 0.2340
# Epoch 27/100
# 129/129 [==============================] - 0s 1ms/sample - loss: 0.1309 - val_loss: 0.2267
# Epoch 28/100
# 129/129 [==============================] - 0s 2ms/sample - loss: 0.1274 - val_loss: 0.2130
# Epoch 29/100
# 129/129 [==============================] - 0s 2ms/sample - loss: 0.1236 - val_loss: 0.2005
# Epoch 30/100
# 129/129 [==============================] - 0s 2ms/sample - loss: 0.1196 - val_loss: 0.1865
# Epoch 31/100
# 129/129 [==============================] - 0s 3ms/sample - loss: 0.1159 - val_loss: 0.1767
# Epoch 32/100
# 129/129 [==============================] - 0s 2ms/sample - loss: 0.1125 - val_loss: 0.1779
# Epoch 33/100
# 129/129 [==============================] - 0s 1ms/sample - loss: 0.1097 - val_loss: 0.1739
# Epoch 34/100
# 129/129 [==============================] - 0s 1ms/sample - loss: 0.1069 - val_loss: 0.1730
# Epoch 35/100
# 129/129 [==============================] - 0s 1ms/sample - loss: 0.1053 - val_loss: 0.1641
# Epoch 36/100
# 129/129 [==============================] - 0s 1ms/sample - loss: 0.1035 - val_loss: 0.1777
# Epoch 37/100
# 129/129 [==============================] - 0s 1ms/sample - loss: 0.1019 - val_loss: 0.1723
# Epoch 38/100
# 129/129 [==============================] - 0s 1ms/sample - loss: 0.1005 - val_loss: 0.1781
# Epoch 39/100
# 129/129 [==============================] - 0s 1ms/sample - loss: 0.0995 - val_loss: 0.1680
# Epoch 40/100
# 129/129 [==============================] - 0s 2ms/sample - loss: 0.0981 - val_loss: 0.1766
# Epoch 41/100
# 129/129 [==============================] - 0s 3ms/sample - loss: 0.0971 - val_loss: 0.1757
# Epoch 42/100
# 129/129 [==============================] - 0s 1ms/sample - loss: 0.0964 - val_loss: 0.1731
# Epoch 43/100
# 129/129 [==============================] - 0s 2ms/sample - loss: 0.0955 - val_loss: 0.1889
# Epoch 44/100
# 129/129 [==============================] - 0s 2ms/sample - loss: 0.0953 - val_loss: 0.1785
# Epoch 45/100
# 129/129 [==============================] - 0s 1ms/sample - loss: 0.0943 - val_loss: 0.1833
# Epoch 46/100
# 129/129 [==============================] - 0s 1ms/sample - loss: 0.0937 - val_loss: 0.1820
# Epoch 47/100
# 129/129 [==============================] - 0s 1ms/sample - loss: 0.0931 - val_loss: 0.1849
# Epoch 48/100
# 129/129 [==============================] - 0s 1ms/sample - loss: 0.0927 - val_loss: 0.1839
# Epoch 49/100
# 129/129 [==============================] - 0s 1ms/sample - loss: 0.0923 - val_loss: 0.1884
# Epoch 50/100
# 129/129 [==============================] - 0s 1ms/sample - loss: 0.0921 - val_loss: 0.1854
# Epoch 51/100
# 129/129 [==============================] - 0s 1ms/sample - loss: 0.0914 - val_loss: 0.1870
# Epoch 52/100
# 129/129 [==============================] - 0s 1ms/sample - loss: 0.0911 - val_loss: 0.1858
# Epoch 53/100
# 129/129 [==============================] - 0s 1ms/sample - loss: 0.0909 - val_loss: 0.1887
# Epoch 54/100
# 129/129 [==============================] - 0s 3ms/sample - loss: 0.0904 - val_loss: 0.1856
# Epoch 55/100
# 129/129 [==============================] - 0s 1ms/sample - loss: 0.0901 - val_loss: 0.1910
# Epoch 56/100
# 129/129 [==============================] - 0s 1ms/sample - loss: 0.0899 - val_loss: 0.1923
# Epoch 57/100
# 129/129 [==============================] - 0s 1ms/sample - loss: 0.0897 - val_loss: 0.1881
# Epoch 58/100
# 129/129 [==============================] - 0s 1ms/sample - loss: 0.0896 - val_loss: 0.1965
# Epoch 59/100
# 129/129 [==============================] - 0s 1ms/sample - loss: 0.0895 - val_loss: 0.1934
# Epoch 60/100
# 129/129 [==============================] - 0s 1ms/sample - loss: 0.0893 - val_loss: 0.1934
# Epoch 61/100
# 129/129 [==============================] - 0s 1ms/sample - loss: 0.0891 - val_loss: 0.1941
# Epoch 62/100
# 129/129 [==============================] - 0s 1ms/sample - loss: 0.0892 - val_loss: 0.1958
# Epoch 63/100
# 129/129 [==============================] - 0s 1ms/sample - loss: 0.0889 - val_loss: 0.1955
# Epoch 64/100
# 129/129 [==============================] - 0s 1ms/sample - loss: 0.0887 - val_loss: 0.1945
# Epoch 65/100
# 129/129 [==============================] - 0s 1ms/sample - loss: 0.0888 - val_loss: 0.2031
# Epoch 66/100
# 129/129 [==============================] - 0s 3ms/sample - loss: 0.0889 - val_loss: 0.1921
# Epoch 67/100
# 129/129 [==============================] - 0s 1ms/sample - loss: 0.0884 - val_loss: 0.1970
# Epoch 68/100
# 129/129 [==============================] - 0s 2ms/sample - loss: 0.0885 - val_loss: 0.1983
# Epoch 69/100
# 129/129 [==============================] - 0s 2ms/sample - loss: 0.0884 - val_loss: 0.1912
# Epoch 70/100
# 129/129 [==============================] - 0s 2ms/sample - loss: 0.0886 - val_loss: 0.2001
# Epoch 71/100
# 129/129 [==============================] - 0s 1ms/sample - loss: 0.0883 - val_loss: 0.1915
# Epoch 72/100
# 129/129 [==============================] - 0s 1ms/sample - loss: 0.0881 - val_loss: 0.1974
# Epoch 73/100
# 129/129 [==============================] - 0s 2ms/sample - loss: 0.0881 - val_loss: 0.1888
# Epoch 74/100
# 129/129 [==============================] - 0s 1ms/sample - loss: 0.0881 - val_loss: 0.2043
# Epoch 75/100
# 129/129 [==============================] - 0s 1ms/sample - loss: 0.0878 - val_loss: 0.1928
# Epoch 76/100
# 129/129 [==============================] - 0s 1ms/sample - loss: 0.0879 - val_loss: 0.1945
# Epoch 77/100
# 129/129 [==============================] - 0s 3ms/sample - loss: 0.0877 - val_loss: 0.1925
# Epoch 78/100
# 129/129 [==============================] - 0s 1ms/sample - loss: 0.0877 - val_loss: 0.1935
# Epoch 79/100
# 129/129 [==============================] - 0s 2ms/sample - loss: 0.0876 - val_loss: 0.1943
# Epoch 80/100
# 129/129 [==============================] - 0s 3ms/sample - loss: 0.0877 - val_loss: 0.1933
# Epoch 81/100
# 129/129 [==============================] - 0s 2ms/sample - loss: 0.0876 - val_loss: 0.1971
# Epoch 82/100
# 129/129 [==============================] - 0s 1ms/sample - loss: 0.0874 - val_loss: 0.1923
# Epoch 83/100
# 129/129 [==============================] - 0s 2ms/sample - loss: 0.0873 - val_loss: 0.1944
# Epoch 84/100
# 129/129 [==============================] - 0s 2ms/sample - loss: 0.0873 - val_loss: 0.1943
# Epoch 85/100
# 129/129 [==============================] - 0s 1ms/sample - loss: 0.0873 - val_loss: 0.1933
# Epoch 86/100
# 129/129 [==============================] - 0s 3ms/sample - loss: 0.0872 - val_loss: 0.1947
# Epoch 87/100
# 129/129 [==============================] - 0s 1ms/sample - loss: 0.0872 - val_loss: 0.1928
# Epoch 88/100
# 129/129 [==============================] - 0s 1ms/sample - loss: 0.0870 - val_loss: 0.1944
# Epoch 89/100
# 129/129 [==============================] - 0s 1ms/sample - loss: 0.0870 - val_loss: 0.1927
# Epoch 90/100
# 129/129 [==============================] - 0s 1ms/sample - loss: 0.0870 - val_loss: 0.1871
# Epoch 91/100
# 129/129 [==============================] - 0s 2ms/sample - loss: 0.0870 - val_loss: 0.1914
# Epoch 92/100
# 129/129 [==============================] - 0s 2ms/sample - loss: 0.0869 - val_loss: 0.1904
# Epoch 93/100
# 129/129 [==============================] - 0s 1ms/sample - loss: 0.0868 - val_loss: 0.1943
# Epoch 94/100
# 129/129 [==============================] - 0s 1ms/sample - loss: 0.0867 - val_loss: 0.1916
# Epoch 95/100
# 129/129 [==============================] - 0s 1ms/sample - loss: 0.0866 - val_loss: 0.1910
# Epoch 96/100
# 129/129 [==============================] - 0s 1ms/sample - loss: 0.0866 - val_loss: 0.1902
# Epoch 97/100
# 129/129 [==============================] - 0s 3ms/sample - loss: 0.0865 - val_loss: 0.1927
# Epoch 98/100
# 129/129 [==============================] - 0s 1ms/sample - loss: 0.0867 - val_loss: 0.1874
# Epoch 99/100
# 129/129 [==============================] - 0s 1ms/sample - loss: 0.0865 - val_loss: 0.1933
# Epoch 100/100
# 129/129 [==============================] - 0s 1ms/sample - loss: 0.0865 - val_loss: 0.1904

# %%
# plot the training losses
fig, ax = plt.subplots(figsize=(14, 6), dpi=80)
ax.plot(history['loss'], 'b', label='Train', linewidth=2)
ax.plot(history['val_loss'], 'r', label='Validation', linewidth=2)
ax.set_title('Model loss', fontsize=16)
ax.set_ylabel('Loss (mae)')
ax.set_xlabel('Epoch')
ax.legend(loc='upper right')
plt.show()

# %%
# plot the loss distribution of the training set
X_pred = model.predict(X_train)
X_pred = X_pred.reshape(X_pred.shape[0], X_pred.shape[2])
X_pred = pd.DataFrame(X_pred, columns=df_train.columns)
X_pred.index = df_train[:-15].index

scored = pd.DataFrame(index=df_train[:-15].index)
Xtrain = X_train.reshape(X_train.shape[0], X_train.shape[2])
scored['Loss_mae'] = np.mean(np.abs(X_pred-Xtrain), axis = 1)
plt.figure(figsize=(16,9), dpi=80)
plt.title('Loss Distribution', fontsize=16)
sns.distplot(scored['Loss_mae'], bins = 20, kde= True, color = 'blue');
plt.xlim([0.0,.5])

#Out[17]:
#(0.0, 0.5)
# Out:
# (0.0, 0.5)

# %%
# calculate the loss on the test set
X_pred = model.predict(X_test)
X_pred = X_pred.reshape(X_pred.shape[0], X_pred.shape[2])
X_pred = pd.DataFrame(X_pred, columns=df_train.columns)
X_pred.index = df_train[-15:].index

scored = pd.DataFrame(index=df_train[-15:].index)
Xtest = X_test.reshape(X_test.shape[0], X_test.shape[2])
scored['Loss_mae'] = np.mean(np.abs(X_pred-Xtest), axis = 1)
scored['Threshold'] = 0.2
scored['Anomaly'] = scored['Loss_mae'] > scored['Threshold']
scored.head()
# Out:
#          Loss_mae  Threshold  Anomaly
# Tarih
# 2018-10  0.403749        0.2     True
# 2018-11  0.240039        0.2     True
# 2018-12  0.261560        0.2     True
# 2019-01  0.249518        0.2     True
# 2019-02  0.230347        0.2     True

# %%
# calculate the same metrics for the training set 
# and merge all data in a single dataframe for plotting
X_pred_train = model.predict(X_train)
X_pred_train = X_pred_train.reshape(X_pred_train.shape[0], X_pred_train.shape[2])
X_pred_train = pd.DataFrame(X_pred_train, columns=df_train[:-15].columns)
X_pred_train.index = df_train[:-15].index

scored_train = pd.DataFrame(index=df_train[:-15].index)
scored_train['Loss_mae'] = np.mean(np.abs(X_pred_train-Xtrain), axis = 1)
scored_train['Threshold'] = 0.2
scored_train['Anomaly'] = scored_train['Loss_mae'] > scored_train['Threshold']
scored = pd.concat([scored_train, scored])
scored
scored.to_csv("/home/ipcvlab/Desktop/output.csv")

# %%
# plot bearing failure time plot
scored.plot(logy=True,  figsize=(16,9), ylim=[1e-2,1e2], color=['blue','red'])
